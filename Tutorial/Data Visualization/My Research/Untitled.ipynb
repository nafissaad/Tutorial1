# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import linear_model
plt.style.use('fivethirtyeight')

# %%
df=pd.read_excel('C:\\Users\\nafissaad\\Downloads\\2017-3-30-062.xlsx',"Data2015",skiprows=1)
df
# Out:
#                                 Country  Life expectancy at birth  \
# 0                                 Qatar                    78.323
# 1                             Singapore                    83.209
# 2                                Kuwait                    74.549
# 3                         Liechtenstein                    80.161
# 4                     Brunei Darussalam                    79.019
# ..                                  ...                       ...
# 183                               Niger                    61.936
# 184                             Burundi                    57.118
# 185                             Liberia                    61.188
# 186  Congo (Democratic Republic of the)                    59.057
# 187            Central African Republic                    51.458
#
#      Health Index  Expected years of schooling   \
# 0        0.897277                     13.406100
# 1        0.972446                     15.400000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 188 non-null    object
#  1   Life expectancy at birth                188 non-null    float64
#  2   Health Index                            188 non-null    float64
#  3   Expected years of schooling             188 non-null    float64
#  4   Expected years of schooling Index       188 non-null    float64
#  5   Mean years of schooling                 188 non-null    float64
#  6   Mean years of schooling Index           188 non-null    float64
#  7   Education index                         188 non-null    float64
#  8   Gross national income (GNI) per capita  188 non-null    float64
#  9   Income index                            188 non-null    float64
# ...

# %%
df=df[['Per capita GNI rank','HDI rank']]
Test=pd.DataFrame(data={
    'values':[0,25,50,75,100,125,150,175],
})
Test
# Out:
#    values
# 0       0
# 1      25
# 2      50
# 3      75
# 4     100
# 5     125
# 6     150
# 7     175

# %%
reg= linear_model.LinearRegression()
fit=reg.fit(df[['HDI rank']].values,df['Per capita GNI rank'])
fit.coef_
# Out:
# array([0.95060745])

# %%
plt.figure(figsize=(12.2,6.4))
plt.scatter(x=df['Per capita GNI rank'],y=df['HDI rank'],color='green')
plt.plot(np.array(Test.values),reg.predict(Test.values),color='red')
plt.xlabel('Per Capita GNI Rank')
plt.ylabel('HDI Rank')
plt.title('Per Capita GNI Rank Vs HDI Rank')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.figure(figsize=(18,18))
sns.lmplot(x='Per capita GNI rank',y='HDI rank',data=df)
