# %%
import pandas as pd
df= pd.read_csv('Breast_cancer.csv')
print(df.shape)
df.head()
# Out:
# (569, 33)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df['Outcome']=df['diagnosis'].map({'M':1,'B':0})

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.iloc[:,[2]]
# Out:
#      radius_mean
# 0          17.99
# 1          20.57
# 2          19.69
# 3          11.42
# 4          20.29
# ..           ...
# 564        21.56
# 565        20.13
# 566        16.60
# 567        20.60
# 568         7.76
#
# [569 rows x 1 columns]

# %%
x=df.iloc[:,[2]]
y=df.Outcome

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
y_predict=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict))
pd.crosstab(y_test,y_predict)
# Out:
# 0.8947368421052632
# col_0      0   1
# Outcome
# 0        105   7
# 1         11  48

# %%
#vertival Outcome Actuals
#horizontal Outcomes are predicted

# %%
model.predict_proba(X_test)#right possitive probability left negative probabilit
# Out:
# array([[3.20743497e-01, 6.79256503e-01],
#        [9.96331697e-01, 3.66830317e-03],
#        [7.47519132e-01, 2.52480868e-01],
#        [1.57966917e-01, 8.42033083e-01],
#        [9.76094506e-01, 2.39054937e-02],
#        [9.94467455e-01, 5.53254484e-03],
#        [9.82374061e-01, 1.76259390e-02],
#        [8.20690633e-01, 1.79309367e-01],
#        [7.27865895e-02, 9.27213410e-01],
#        [6.38034182e-01, 3.61965818e-01],
#        [8.83833512e-01, 1.16166488e-01],
#        [8.92084994e-01, 1.07915006e-01],
#        [8.35449181e-01, 1.64550819e-01],
#        [6.77686491e-01, 3.22313509e-01],
#        [1.26449287e-01, 8.73550713e-01],
#        [6.54523546e-02, 9.34547645e-01],
#        [9.62784299e-01, 3.72157012e-02],
#        [7.89841836e-01, 2.10158164e-01],
#        [9.34106036e-01, 6.58939636e-02],
#        [3.80822472e-02, 9.61917753e-01],
#        [1.70782898e-01, 8.29217102e-01],
#        [4.68029110e-01, 5.31970890e-01],
#        [9.94328802e-01, 5.67119819e-03],
# ...

# %%
model.predict_proba(X_test)[:,1]
# Out:
# array([0.6792565 , 0.0036683 , 0.25248087, 0.84203308, 0.02390549,
#        0.00553254, 0.01762594, 0.17930937, 0.92721341, 0.36196582,
#        0.11616649, 0.10791501, 0.16455082, 0.32231351, 0.87355071,
#        0.93454765, 0.0372157 , 0.21015816, 0.06589396, 0.96191775,
#        0.8292171 , 0.53197089, 0.0056712 , 0.56789338, 0.9857301 ,
#        0.99212992, 0.16031785, 0.99739198, 0.02955085, 0.1001832 ,
#        0.11405363, 0.01195329, 0.98992794, 0.06783521, 0.41361585,
#        0.2171274 , 0.29144773, 0.00184956, 0.24665376, 0.07687409,
#        0.0254014 , 0.00229149, 0.00115817, 0.022044  , 0.068494  ,
#        0.87916887, 0.18084071, 0.07687409, 0.2564159 , 0.00267895,
#        0.21889557, 0.04070867, 0.6792565 , 0.04770642, 0.08063588,
#        0.99984753, 0.89277589, 0.18084071, 0.17033379, 0.01310748,
#        0.99927791, 0.10495593, 0.51126937, 0.04540497, 0.02342622,
#        0.36918212, 0.05529278, 0.01658014, 0.23714475, 0.36918212,
# ...

# %%
model.predict_proba(X_test)[:,0]
# Out:
# array([3.20743497e-01, 9.96331697e-01, 7.47519132e-01, 1.57966917e-01,
#        9.76094506e-01, 9.94467455e-01, 9.82374061e-01, 8.20690633e-01,
#        7.27865895e-02, 6.38034182e-01, 8.83833512e-01, 8.92084994e-01,
#        8.35449181e-01, 6.77686491e-01, 1.26449287e-01, 6.54523546e-02,
#        9.62784299e-01, 7.89841836e-01, 9.34106036e-01, 3.80822472e-02,
#        1.70782898e-01, 4.68029110e-01, 9.94328802e-01, 4.32106619e-01,
#        1.42698954e-02, 7.87007862e-03, 8.39682149e-01, 2.60802077e-03,
#        9.70449151e-01, 8.99816798e-01, 8.85946365e-01, 9.88046706e-01,
#        1.00720641e-02, 9.32164787e-01, 5.86384153e-01, 7.82872604e-01,
#        7.08552265e-01, 9.98150436e-01, 7.53346240e-01, 9.23125911e-01,
#        9.74598596e-01, 9.97708515e-01, 9.98841827e-01, 9.77956002e-01,
#        9.31506003e-01, 1.20831125e-01, 8.19159287e-01, 9.23125911e-01,
#        7.43584099e-01, 9.97321053e-01, 7.81104427e-01, 9.59291334e-01,
# ...

# %%
import numpy as np
y_predict_th3=np.where(model.predict_proba(X_test)[:,1]>0.3,1,0)#Threshold is 0.3
y_predict_th4=np.where(model.predict_proba(X_test)[:,1]>0.4,1,0)#Threshold is 0.4

# %%
pd.crosstab(y_test,y_predict_th3)
# Out:
# col_0      0   1
# Outcome
# 0        102  10
# 1          8  51

# %%
pd.crosstab(y_test,y_predict_th4)
# Out:
# col_0      0   1
# Outcome
# 0        104   8
# 1         10  49

# %%
def predict_threshold(model,x_test,threshold):
    import numpy as np
    return np.where(model.predict_proba(X_test)[:,1]>threshold,1,0)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
for thr in np.arange(0,1.0,0.1):
    y_predict = predict_threshold(model,X_test,thr)
    print("Threshold :",thr)
    print(confusion_matrix(y_test,y_predict))
# Out:
# Threshold : 0.0
# [[  0 112]
#  [  0  59]]
# Threshold : 0.1
# [[67 45]
#  [ 3 56]]
# Threshold : 0.2
# [[89 23]
#  [ 5 54]]
# Threshold : 0.30000000000000004
# [[102  10]
#  [  8  51]]
# Threshold : 0.4
# [[104   8]
#  [ 10  49]]
# Threshold : 0.5
# [[105   7]
#  [ 11  48]]
# Threshold : 0.6000000000000001
# [[108   4]
#  [ 14  45]]
# Threshold : 0.7000000000000001
# [[108   4]
#  [ 20  39]]
# Threshold : 0.8
# [[108   4]
#  [ 22  37]]
# Threshold : 0.9
# [[111   1]
#  [ 28  31]]

# %%
from sklearn.metrics import roc_curve,roc_auc_score

# %%
tpr,frp,thresholds=roc_curve(y_test,model.predict_proba(X_test)[:,1])

# %%
frp
# Out:
# array([0.        , 0.01694915, 0.40677966, 0.40677966, 0.52542373,
#        0.52542373, 0.59322034, 0.59322034, 0.61016949, 0.61016949,
#        0.6779661 , 0.71186441, 0.77966102, 0.77966102, 0.79661017,
#        0.83050847, 0.83050847, 0.84745763, 0.86440678, 0.86440678,
#        0.86440678, 0.88135593, 0.88135593, 0.89830508, 0.89830508,
#        0.91525424, 0.91525424, 0.93220339, 0.93220339, 0.93220339,
#        0.94915254, 0.94915254, 0.94915254, 0.96610169, 0.96610169,
#        0.96610169, 0.96610169, 0.98305085, 0.98305085, 0.98305085,
#        0.98305085, 1.        , 1.        ])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,roc_auc_score
# %matplotlib inline
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for breast cancer classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.plot(fpr, tpr,color='red',lw=5)
plt.show()

# %%
roc_auc_score(y_test,model.predict_proba(X_test)[:,1])#area under the curve
# Out:
# 0.9409806295399515

# %%
y_predict_th3=np.where(model.predict_proba(X_test)[:,1]>0.5,1,0)

# %%
pd.crosstab(y_test,y_predict_th3)
# Out:
# col_0      0   1
# Outcome
# 0        105   7
# 1         11  48

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
for thr in np.arange(0,1.0,0.05):
    y_predict = predict_threshold(model,X_test,thr)
    print(f'ROC Score :{roc_auc_score(y_test, np.where(model.predict_proba(X_test)[:,1]>thr,1,0))} and threshold :{thr}')
# Out:
# ROC Score :0.5 and threshold :0.0
# ROC Score :0.7241222760290557 and threshold :0.05
# ROC Score :0.7736834140435837 and threshold :0.1
# ROC Score :0.8361834140435835 and threshold :0.15000000000000002
# ROC Score :0.8549485472154964 and threshold :0.2
# ROC Score :0.87772397094431 and threshold :0.25
# ROC Score :0.8875605326876512 and threshold :0.30000000000000004
# ROC Score :0.8920248184019369 and threshold :0.35000000000000003
# ROC Score :0.8795399515738499 and threshold :0.4
# ROC Score :0.8840042372881356 and threshold :0.45
# ROC Score :0.8755296610169492 and threshold :0.5
# ROC Score :0.863044794188862 and threshold :0.55
# ROC Score :0.8634987893462469 and threshold :0.6000000000000001
# ROC Score :0.8465496368038741 and threshold :0.65
# ROC Score :0.8126513317191283 and threshold :0.7000000000000001
# ROC Score :0.8041767554479419 and threshold :0.75
# ROC Score :0.7957021791767556 and threshold :0.8
# ROC Score :0.7792070217917675 and threshold :0.8500000000000001
# ...

# %%
x=df.drop(["id","diagnosis","Unnamed: 32","Outcome"],axis="columns")
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x.values,y,test_size=0.3,random_state=10)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=10000)
model.fit(X_train,y_train)
y_predict = model.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
for thr in np.arange(0,1.0,0.05):
    y_predict = predict_threshold(model,X_test,thr)
    print("Threshold :",thr)
    print(confusion_matrix(y_test,y_predict))
# Out:
# Threshold : 0.0
# [[  0 112]
#  [  0  59]]
# Threshold : 0.05
# [[95 17]
#  [ 0 59]]
# Threshold : 0.1
# [[100  12]
#  [  1  58]]
# Threshold : 0.15000000000000002
# [[101  11]
#  [  2  57]]
# Threshold : 0.2
# [[105   7]
#  [  2  57]]
# Threshold : 0.25
# [[105   7]
#  [  2  57]]
# Threshold : 0.30000000000000004
# [[106   6]
#  [  2  57]]
# Threshold : 0.35000000000000003
# [[106   6]
#  [  2  57]]
# Threshold : 0.4
# [[106   6]
#  [  2  57]]
# Threshold : 0.45
# [[106   6]
#  [  2  57]]
# Threshold : 0.5
# [[106   6]
#  [  2  57]]
# Threshold : 0.55
# [[106   6]
#  [  2  57]]
# Threshold : 0.6000000000000001
# [[107   5]
#  [  3  56]]
# Threshold : 0.65
# [[107   5]
#  [  3  56]]
# Threshold : 0.7000000000000001
# [[107   5]
#  [  4  55]]
# Threshold : 0.75
# [[107   5]
#  [  4  55]]
# Threshold : 0.8
# [[107   5]
#  [  5  54]]
# Threshold : 0.8500000000000001
# [[108   4]
#  [  5  54]]
# Threshold : 0.9
# [[108   4]
#  [  7  52]]
# Threshold : 0.9500000000000001
# [[110   2]
# ...

# %%
tpr,fpr,thresholds=roc_curve(y_test,model.predict_proba(X_test)[:,1])

# %%
fpr
# Out:
# array([0.        , 0.08474576, 0.88135593, 0.88135593, 0.91525424,
#        0.91525424, 0.96610169, 0.96610169, 0.98305085, 0.98305085,
#        1.        , 1.        ])

# %%
tpr
# Out:
# array([0.        , 0.        , 0.        , 0.03571429, 0.03571429,
#        0.04464286, 0.04464286, 0.09821429, 0.09821429, 0.10714286,
#        0.10714286, 1.        ])

# %%
thresholds
# Out:
# array([2.00000000e+00, 1.00000000e+00, 9.91896777e-01, 9.00812717e-01,
#        8.59849984e-01, 8.15217082e-01, 5.89287124e-01, 1.55324051e-01,
#        1.38626087e-01, 1.10746615e-01, 7.10252772e-02, 6.40144196e-08])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve,roc_auc_score
# %matplotlib inline
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for breast cancer classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.plot(fpr, tpr,color='red',lw=5)
plt.show()

# %%
roc_auc_score(y_test, model.predict_proba(X_test)[:,1])#AUc area under the curve
# Out:
# 0.9930387409200969

# %%
import numpy as np
y_predict_th3=np.where(model.predict_proba(X_test)[:,1]>0.04,1,0)

# %%
pd.crosstab(y_test,y_predict_th3)
# Out:
# col_0     0   1
# Outcome
# 0        94  18
# 1         0  59

# %%
roc_auc_score(y_test, np.where(model.predict_proba(X_test)[:,1]>0.2,1,0))#close to 1 is better
# Out:
# 0.9518008474576272

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
for thr in np.arange(0,1.0,0.05):
    y_predict = predict_threshold(model,X_test,thr)
    print(f'ROC Score :{roc_auc_score(y_test, np.where(model.predict_proba(X_test)[:,1]>thr,1,0))} and threshold :{thr}')
# Out:
# ROC Score :0.5 and threshold :0.0
# ROC Score :0.9241071428571428 and threshold :0.05
# ROC Score :0.9379539951573851 and threshold :0.1
# ROC Score :0.9339437046004844 and threshold :0.15000000000000002
# ROC Score :0.9518008474576272 and threshold :0.2
# ROC Score :0.9518008474576272 and threshold :0.25
# ROC Score :0.9562651331719129 and threshold :0.30000000000000004
# ROC Score :0.9562651331719129 and threshold :0.35000000000000003
# ROC Score :0.9562651331719129 and threshold :0.4
# ROC Score :0.9562651331719129 and threshold :0.45
# ROC Score :0.9562651331719129 and threshold :0.5
# ROC Score :0.9562651331719129 and threshold :0.55
# ROC Score :0.9522548426150123 and threshold :0.6000000000000001
# ROC Score :0.9522548426150123 and threshold :0.65
# ROC Score :0.9437802663438257 and threshold :0.7000000000000001
# ROC Score :0.9437802663438257 and threshold :0.75
# ROC Score :0.9353056900726393 and threshold :0.8
# ...
