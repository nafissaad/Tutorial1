# %%
import pandas as pd
# %matplotlib inline

# %%
df=pd.DataFrame()
df['values']=[100.12,110.5,106.7,110.2,98.5,94.2,91.1,93.12,94.02,92.12]
df['t']=[i+1 for i in range(10)]
df
# Out:
#    values   t
# 0  100.12   1
# 1  110.50   2
# 2  106.70   3
# 3  110.20   4
# 4   98.50   5
# 5   94.20   6
# 6   91.10   7
# 7   93.12   8
# 8   94.02   9
# 9   92.12  10

# %%
df.plot()

# %%
df.plot(y='values',x='t')

# %%
df.plot.area(y='values',x='t')

# %%
df.plot.bar(y='values',x='t')

# %%
df.plot.barh(y='values',x='t')

# %%
df.plot.box(y='values',x='t')

# %%
df.plot.density(y='values',x='t')

# %%
df.plot.hist(y='values',x='t')

# %%
df.plot.pie(y='values',x='t')

# %%
df.plot.scatter(y='values',x='t')
