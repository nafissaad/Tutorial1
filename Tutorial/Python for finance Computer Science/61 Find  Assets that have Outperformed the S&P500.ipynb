# %%
#Description Get assets that gave a grater annualized return than the S&P500
#import the liberies 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import yfinance as yf

# %%
def get_historical_Data(tickers):
    """This function returns a pd dataframe with all of the adjusted closing information"""
    data = pd.DataFrame()
    names = list()
    for i in tickers:
        data = pd.concat([data, pd.DataFrame(yf.download(i, start=datetime(2020, 4, 24), end=datetime(2022, 12, 21)).iloc[:,4])], axis = 1)
        names.append(i)
    data.columns = names
    return data

ticks = ["DPZ", "AAPL", "GOOG", "AMD", "GME", "SPY", "NFLX", "BA", "WMT","TWTR","GS","XOM","NKE", "Meta","BRK-B", "MSFT"] #Name of company (Dominos pizza)
d = get_historical_Data(ticks)
print(d.shape)
# Most Recent Data
d.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
d.isnull().sum()
# Out:
# DPZ       0
# AAPL      0
# GOOG      0
# AMD       0
# GME       0
# SPY       0
# NFLX      0
# BA        0
# WMT       0
# TWTR     37
# GS        0
# XOM       0
# NKE       0
# Meta      0
# BRK-B     0
# MSFT      0
# dtype: int64

# %%
d.dropna(axis=1,inplace=True)
d.isnull().sum()
# Out:
# DPZ      0
# AAPL     0
# GOOG     0
# AMD      0
# GME      0
# SPY      0
# NFLX     0
# BA       0
# WMT      0
# GS       0
# XOM      0
# NKE      0
# Meta     0
# BRK-B    0
# MSFT     0
# dtype: int64

# %%
#Get the simple daily returns
daily_simple_returns=d.pct_change(
#Show the data
)
daily_simple_returns
# Out:
#                  DPZ      AAPL      GOOG       AMD       GME       SPY  \
# Date
# 2020-04-23       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-04-24 -0.006357  0.028869  0.002351  0.005009  0.014894  0.013939
# 2020-04-27 -0.014321  0.000707 -0.002681  0.005518  0.220126  0.014418
# 2020-04-28 -0.016629 -0.016209 -0.033083 -0.017348 -0.030928 -0.004599
# 2020-04-29  0.016854  0.032845  0.087390 -0.033327  0.070922  0.026179
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-14  0.016548 -0.015536 -0.005634 -0.037962  0.002381 -0.006394
# 2022-12-15 -0.026586 -0.046854 -0.043122 -0.034818 -0.022328 -0.024462
# 2022-12-16  0.000672 -0.014579 -0.003728 -0.016834  0.010690 -0.011806
# 2022-12-19 -0.002519 -0.015910 -0.018820 -0.012536 -0.042308 -0.008480
# 2022-12-20 -0.007297 -0.000529  0.005384  0.007122  0.017068  0.001368
#
#                 NFLX        BA       WMT        GS       XOM       NKE  \
# Date
# ...

# %%
#get and Show the annualized returns
annual_returns=daily_simple_returns.mean()*252
#show the data
annual_returns
# Out:
# DPZ      0.036555
# AAPL     0.305516
# GOOG     0.177240
# AMD      0.194227
# GME      2.507644
# SPY      0.151110
# NFLX    -0.007990
# BA       0.236765
# WMT      0.083620
# GS       0.323876
# XOM      0.463101
# NKE      0.128145
# Meta    -0.054208
# BRK-B    0.203391
# MSFT     0.181700
# dtype: float64

# %%
#Show the annualized return for the S&P500
annual_returns['SPY']
# Out:
# 0.15110969134876462

# %%
#show all assets that gave a higher annualized retrun than the s&p500
for i in range(0,len(annual_returns)):
    if annual_returns[i]>annual_returns['SPY']:
        print(annual_returns.index[i], ':',annual_returns[i])
# Out:
# AAPL : 0.30551554745609544
# GOOG : 0.17724002249394274
# AMD : 0.19422683040505512
# GME : 2.5076444959147093
# BA : 0.23676526021259858
# GS : 0.3238760833149006
# XOM : 0.46310088999501386
# BRK-B : 0.20339070898414877
# MSFT : 0.18169966162609522
