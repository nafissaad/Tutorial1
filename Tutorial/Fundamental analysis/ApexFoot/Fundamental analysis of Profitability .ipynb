# %%
import pandas as pd
import numpy as np

# %%
Balance_Sheet=pd.read_csv('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\ApexFoot\\Data Cleaning\\Balance_Sheet.csv',index_col='BDT Per Billon')
Cash_flow=pd.read_csv('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\ApexFoot\\Data Cleaning\\Cash_flow.csv',index_col='BDT Per Billon')
Income_Statement=pd.read_csv('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\ApexFoot\\Data Cleaning\\Income_statement.csv',index_col='BDT Per Billon')

# %%
Cash_flow
# Out:
#                                                 2018          2019  \
# BDT Per Billon
# Net Income before Extraordinaries                NaN           NaN
# Net Income Growth                                NaN           NaN
# Depreciation, Depletion & Amortization           NaN           NaN
# Depreciation and Depletion                       NaN           NaN
# Deferred Taxes & Investment Tax Credit           NaN           NaN
# Deferred Taxes                                   NaN           NaN
# Other Funds                            -4.506100e+05 -7.086200e+05
# Funds from Operations                   4.662800e+05  2.620900e+05
# Changes in Working Capital                       NaN           NaN
# Receivables                                      NaN           NaN
# Accounts Payable                                 NaN           NaN
# Other Assets/Liabilities                         NaN           NaN
# Net Operating Cash Flow                 4.662800e+05  2.620900e+05
# ...

# %%
def profitibility(Balance_Sheet,Cash_flow,Income_Statement):
    #global profitibility_score
    #Score 1 and 2 -net income
    net_income=Income_Statement.loc['Net Income',Income_Statement.columns[4]]
    net_income_last_year=Income_Statement.loc['Net Income',Income_Statement.columns[3]]
    ni_score=1 if net_income>0 else 0
    ni_score_2=1 if net_income>net_income_last_year else 0
    
    #Score #3 -operating cash flow
    op_cf=Cash_flow.loc['Net Operating Cash Flow',Cash_flow.columns[4]]
    op_cf_score=1 if op_cf>0 else 0
    
    #Score 4 -Return on assets
    Avg_asset=(Balance_Sheet.loc['Total Assets',Balance_Sheet.columns[4]]+
               Balance_Sheet.loc['Total Assets',Balance_Sheet.columns[3]])/2
    Avg_asset_last_year=(Balance_Sheet.loc['Total Assets',Balance_Sheet.columns[2]]+
                         Balance_Sheet.loc['Total Assets',Balance_Sheet.columns[1]])/2
    ROA=net_income/Avg_asset
    ROA_last_year=net_income_last_year/Avg_asset_last_year
    ROA_score=1 if  ROA>ROA_last_year else 0
    
    #Score 5 -Accruals
    total_assets=Balance_Sheet.loc['Total Assets',Balance_Sheet.columns[4]]
    accruals=op_cf/total_assets - ROA
    ac_score=1 if accruals>0 else 0
    
    profitibility_score=ni_score+ni_score_2+op_cf_score+ROA_score+ac_score
    print(profitibility_score)

# %%
profitibility(Balance_Sheet,Cash_flow,Income_Statement)
# Out:
# 3
