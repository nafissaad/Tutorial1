# %%
import random
import numpy as np
import yfinance as yf
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import norm
import math
import scipy.stats as stats
from datetime import datetime, timedelta
# %matplotlib inline

# %%
tickers=['^GSPC']

# %%
df=yf.download(tickers,start='2014-12-31',end='2022-08-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df['Return']=df['Close'].pct_change()
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2014-12-30  2088.489990  2088.489990  2079.530029  2080.350098  2080.350098
# 2014-12-31  2082.110107  2085.580078  2057.939941  2058.899902  2058.899902
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2058.199951
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  2020.579956
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  2002.609985
# ...                 ...          ...          ...          ...          ...
# 2022-08-24  4126.549805  4156.560059  4119.970215  4140.770020  4140.770020
# 2022-08-25  4153.259766  4200.540039  4147.589844  4199.120117  4199.120117
# 2022-08-26  4198.740234  4203.040039  4057.659912  4057.659912  4057.659912
# 2022-08-29  4034.580078  4062.989990  4017.419922  4030.610107  4030.610107
# 2022-08-30  4041.250000  4044.979980  3965.209961  3986.159912  3986.159912
#
#                 Volume    Return
# Date
# 2014-12-30  2440280000       NaN
# 2014-12-31  2606070000 -0.010311
# 2015-01-02  2708700000 -0.000340
# 2015-01-05  3799120000 -0.018278
# 2015-01-06  4460110000 -0.008893
# ...                ...       ...
# 2022-08-24  3583630000  0.002916
# 2022-08-25  3566870000  0.014092
# 2022-08-26  3832750000 -0.033688
# 2022-08-29  3396510000 -0.006666
# 2022-08-30  3835860000 -0.011028
#
# [1931 rows x 7 columns]

# %%
returns=df['Return'].mean()
Volatility=df['Return'].std()
returns,Volatility
# Out:
# (0.00040568271686387266, 0.011690437336438387)

# %%
5/100
# Out:
# 0.05

# %%
import random
np.linspace(0.001,0.05,num=50,dtype='float')
# Out:
# array([0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009,
#        0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017, 0.018,
#        0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026, 0.027,
#        0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035, 0.036,
#        0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044, 0.045,
#        0.046, 0.047, 0.048, 0.049, 0.05 ])

# %%
df1=pd.DataFrame()
df1['Confidence Interval']=np.linspace(0.001,0.05,num=50,dtype='float')

# %%
df1['VaR(normal)']=[np.nan for i in range(len(df1))]
df1['VaR(average)']=[np.nan for i in range(len(df1))]
df1['VaR(Mill)']=[np.nan for i in range(len(df1))]
df1
# Out:
#     Confidence Interval  VaR(normal)  VaR(average)  VaR(Mill)
# 0                 0.001          NaN           NaN        NaN
# 1                 0.002          NaN           NaN        NaN
# 2                 0.003          NaN           NaN        NaN
# 3                 0.004          NaN           NaN        NaN
# 4                 0.005          NaN           NaN        NaN
# 5                 0.006          NaN           NaN        NaN
# 6                 0.007          NaN           NaN        NaN
# 7                 0.008          NaN           NaN        NaN
# 8                 0.009          NaN           NaN        NaN
# 9                 0.010          NaN           NaN        NaN
# 10                0.011          NaN           NaN        NaN
# 11                0.012          NaN           NaN        NaN
# 12                0.013          NaN           NaN        NaN
# 13                0.014          NaN           NaN        NaN
# 14                0.015          NaN           NaN        NaN
# 15                0.016          NaN           NaN        NaN
# 16                0.017          NaN           NaN        NaN
# 17                0.018          NaN           NaN        NaN
# 18                0.019          NaN           NaN        NaN
# 19                0.020          NaN           NaN        NaN
# 20                0.021          NaN           NaN        NaN
# 21                0.022          NaN           NaN        NaN
# 22                0.023          NaN           NaN        NaN
# 23                0.024          NaN           NaN        NaN
# 24                0.025          NaN           NaN        NaN
# 25                0.026          NaN           NaN        NaN
# 26                0.027          NaN           NaN        NaN
# 27                0.028          NaN           NaN        NaN
# 28                0.029          NaN           NaN        NaN
# 29                0.030          NaN           NaN        NaN
# 30                0.031          NaN           NaN        NaN
# 31                0.032          NaN           NaN        NaN
# 32                0.033          NaN           NaN        NaN
# 33                0.034          NaN           NaN        NaN
# 34                0.035          NaN           NaN        NaN
# 35                0.036          NaN           NaN        NaN
# 36                0.037          NaN           NaN        NaN
# 37                0.038          NaN           NaN        NaN
# 38                0.039          NaN           NaN        NaN
# 39                0.040          NaN           NaN        NaN
# 40                0.041          NaN           NaN        NaN
# 41                0.042          NaN           NaN        NaN
# 42                0.043          NaN           NaN        NaN
# 43                0.044          NaN           NaN        NaN
# 44                0.045          NaN           NaN        NaN
# 45                0.046          NaN           NaN        NaN
# 46                0.047          NaN           NaN        NaN
# 47                0.048          NaN           NaN        NaN
# 48                0.049          NaN           NaN        NaN
# 49                0.050          NaN           NaN        NaN

# %%
for i in df1.index:
    df1.loc[i,'VaR(normal)']=returns+norm.ppf(df1.loc[i,'Confidence Interval'])*0.0085#Volatility
    df1.loc[i-1,'VaR(average)']=np.mean(df1['VaR(normal)'].iloc[0:i])
    df1.loc[i,'VaR(Mill)']=returns-0.0085*(norm.pdf((df1.loc[i,'VaR(normal)']-returns)/0.0085)/norm.cdf((df1.loc[i,'VaR(normal)']-returns)/0.0085))

# %%
#pdf=measures probability density function (pdf) of the distribution
#cdf=Cumulative Density Function (CDF) for a Normal random variable at a value x
#Mills ration=daily returns-standard deviation*(pdf(VaR normal-daily returns)*standard deviation/cdf(VaR normal-daily returns)*standard deviation)
df1
# Out:
#      Confidence Interval  VaR(normal)  VaR(average)  VaR(Mill)
#  0                 0.001    -0.025861     -0.025861  -0.028215
