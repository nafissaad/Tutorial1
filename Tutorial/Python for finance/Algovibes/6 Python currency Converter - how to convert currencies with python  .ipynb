# %%
import pandas_datareader.data as reader
import datetime as dt
import matplotlib.pyplot as plt
start=dt.date(2000,1,1)
end=dt.datetime.now()
df=reader.get_data_yahoo('BDT=X',start,end)
df
# Out:
#                  High        Low       Open      Close  Volume  Adj Close
# Date
# 2002-03-31  57.500000  57.000000  57.250000  57.250000     0.0  57.250000
# 2003-01-02  58.150002  57.650002  57.900002  57.900002     0.0  57.900002
# 2003-04-20  58.450001  57.950001  58.200001  58.200001     0.0  58.200001
# 2003-12-01  56.612000  56.612000  56.612000  56.612000     0.0  56.612000
# 2003-12-02  56.706001  56.706001  56.706001  56.706001     0.0  56.706001
# ...               ...        ...        ...        ...     ...        ...
# 2022-08-01  92.894524  92.679466  92.679466  93.005493     0.0  93.005493
# 2022-08-02  93.588585  92.894859  93.588585  92.894524     0.0  92.894524
# 2022-08-03  93.165352  93.085907  93.165352  92.894859     0.0  92.894859
# 2022-08-04  92.967857  92.592392  92.592392  93.085907     0.0  93.085907
# 2022-08-05  94.699997  94.699997  94.699997  94.699997     0.0  94.699997
#
# [4862 rows x 6 columns]

# %%
df['Close'].plot(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('TK Per Dollar')
plt.show()
