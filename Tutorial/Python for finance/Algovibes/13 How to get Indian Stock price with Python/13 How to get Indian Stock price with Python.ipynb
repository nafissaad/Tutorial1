# %%
import yfinance as yf
#import numpy as np
import pandas as pd
#import datetime as dt
#from pandas.tseries.offsets import MonthEnd

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/BSE_SENSEX')[1]
df
# Out:
#      #  Exchange ticker         Symbol                        Companies  \
# 0    1           500820  ASIANPAINT.BO                     Asian Paints
# 1    2           532215    AXISBANK.BO                        Axis Bank
# 2    3           532977  BAJAJ-AUTO.BO                       Bajaj Auto
# 3    4           500034  BAJFINANCE.BO                    Bajaj Finance
# 4    5           532978  BAJAJFINSV.BO                    Bajaj Finserv
# 5    6           532454  BHARTIARTL.BO                    Bharti Airtel
# 6    7           500124     DRREDDY.BO          Dr Reddy's Laboratories
# 7    8           532281     HCLTECH.BO                 HCL Technologies
# 8    9           500010        HDFC.BO                             HDFC
# 9   10           500180    HDFCBANK.BO                        HDFC Bank
# 10  11           500696  HINDUNILVR.BO       Hindustan Unilever Limited
# 11  12           532174   ICICIBANK.BO                       ICICI Bank
# ...

# %%
df.to_csv('C:\\Users\\nafissaad\\Tutorial\\Python for finance\\Algovibes\\Indian stocks')

# %%
tickers=df['Symbol'].to_list()

# %%
tickers
# Out:
# ['ASIANPAINT.BO',
#  'AXISBANK.BO',
#  'BAJAJ-AUTO.BO',
#  'BAJFINANCE.BO',
#  'BAJAJFINSV.BO',
#  'BHARTIARTL.BO',
#  'DRREDDY.BO',
#  'HCLTECH.BO',
#  'HDFC.BO',
#  'HDFCBANK.BO',
#  'HINDUNILVR.BO',
#  'ICICIBANK.BO',
#  'INDUSINDBK.BO',
#  'INFY.BO',
#  'ITC.BO',
#  'KOTAKBANK.BO',
#  'LT.BO',
#  'M&M.BO',
#  'MARUTI.BO',
#  'NESTLEIND.BO',
#  'NTPC.BO',
#  'ONGC.BO',
#  'POWERGRID.BO',
#  'RELIANCE.BO',
#  'SBIN.BO',
#  'SUNPHARMA.BO',
#  'TCS.BO',
#  'TECHM.BO',
#  'TITAN.BO',
#  'ULTRACEMCO.BO']

# %%
yf.download('HDFC.BO')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03    30.000000    30.885000    29.305000    30.885000    20.748423
# 2000-01-04    32.299999    32.349998    29.400000    30.375000    20.405806
# 2000-01-05    29.900000    30.100000    28.000000    29.200001    19.616447
# 2000-01-06    29.500000    30.340000    29.200001    29.410000    19.757519
# 2000-01-07    29.200001    29.480000    27.930000    28.500000    19.146187
# ...                 ...          ...          ...          ...          ...
# 2022-09-01  2424.000000  2435.850098  2393.600098  2403.449951  2403.449951
# 2022-09-02  2407.199951  2450.000000  2380.649902  2445.449951  2445.449951
# 2022-09-05  2445.000000  2464.149902  2439.149902  2455.600098  2455.600098
# 2022-09-06  2460.000000  2472.649902  2442.000000  2447.649902  2447.649902
# ...

# %%
codes=[i[:-3] for i in tickers]
codes
# Out:
# ['ASIANPAINT',
#  'AXISBANK',
#  'BAJAJ-AUTO',
#  'BAJFINANCE',
#  'BAJAJFINSV',
#  'BHARTIARTL',
#  'DRREDDY',
#  'HCLTECH',
#  'HDFC',
#  'HDFCBANK',
#  'HINDUNILVR',
#  'ICICIBANK',
#  'INDUSINDBK',
#  'INFY',
#  'ITC',
#  'KOTAKBANK',
#  'LT',
#  'M&M',
#  'MARUTI',
#  'NESTLEIND',
#  'NTPC',
#  'ONGC',
#  'POWERGRID',
#  'RELIANCE',
#  'SBIN',
#  'SUNPHARMA',
#  'TCS',
#  'TECHM',
#  'TITAN',
#  'ULTRACEMCO']

# %%
india=[]
for i in codes:
    india.append(i+".BO")

# %%
india
# Out:
# ['ASIANPAINT.BO',
#  'AXISBANK.BO',
#  'BAJAJ-AUTO.BO',
#  'BAJFINANCE.BO',
#  'BAJAJFINSV.BO',
#  'BHARTIARTL.BO',
#  'DRREDDY.BO',
#  'HCLTECH.BO',
#  'HDFC.BO',
#  'HDFCBANK.BO',
#  'HINDUNILVR.BO',
#  'ICICIBANK.BO',
#  'INDUSINDBK.BO',
#  'INFY.BO',
#  'ITC.BO',
#  'KOTAKBANK.BO',
#  'LT.BO',
#  'M&M.BO',
#  'MARUTI.BO',
#  'NESTLEIND.BO',
#  'NTPC.BO',
#  'ONGC.BO',
#  'POWERGRID.BO',
#  'RELIANCE.BO',
#  'SBIN.BO',
#  'SUNPHARMA.BO',
#  'TCS.BO',
#  'TECHM.BO',
#  'TITAN.BO',
#  'ULTRACEMCO.BO']

# %%
frame=yf.download(india)
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
returns=frame['Adj Close'].pct_change()

# %%
returns=returns.dropna()

# %%
(1+returns).cumprod().plot(figsize=(10,10))

# %%
#y axis is not in percentage format so the stock has grown 300*100%
