# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
yf.Ticker('AAPL').info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 154000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. In addition, the company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; AirPods Max, an over-ear wireless headphone; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, and iPod touch. Further, it provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. Additionally, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.',
#  'city': 'Cupertino',
#  'phone': '408 996 1010',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'https://www.apple.com',
#  'maxAge': 1,
#  'address1': 'One Apple Park Way',
#  'industry': 'Consumer Electronics',
#  'ebitdaMargins': 0.3343,
#  'profitMargins': 0.25709,
#  'grossMargins': 0.43313998,
#  'operatingCashflow': 118224003072,
#  'revenueGrowth': 0.019,
#  'operatingMargins': 0.30533,
#  'ebitda': 129556996096,
#  'targetLowPrice': 130,
#  'recommendationKey': 'buy',
#  'grossProfits': 152836000000,
#  'freeCashflow': 83344621568,
#  'targetMedianPrice': 185,
#  'currentPrice': 142.45,
#  'earningsGrowth': -0.077,
#  'currentRatio': 0.865,
#  'returnOnAssets': 0.22204,
#  'numberOfAnalystOpinions': 41,
#  'targetMeanPrice': 183.5,
#  'debtToEquity': 205.984,
#  'returnOnEquity': 1.62816,
#  'targetHighPrice': 220,
#  'totalCash': 48230998016,
#  'totalDebt': 119691001856,
#  'totalRevenue': 387541991424,
#  'totalCashPerShare': 3.001,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 23.732,
#  'quickRatio': 0.697,
#  'recommendationMean': 1.9,
#  'exchange': 'NMS',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': True,
#  'gmtOffSetMilliseconds': '-14400000',
#  'underlyingSymbol': None,
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'underlyingExchangeSymbol': None,
#  'headSymbol': None,
#  'messageBoardId': 'finmb_24937',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 5.915,
#  'beta3Year': None,
#  'enterpriseToEbitda': 17.694,
#  '52WeekChange': 0.009496093,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.46,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 16070800384,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 3.61,
#  'sharesShort': 116076947,
#  'sharesPercentSharesOut': 0.0072000003,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1632528000,
#  'heldPercentInstitutions': 0.59604,
#  'netIncomeToCommon': 99632996352,
#  'trailingEps': 6.05,
#  'lastDividendValue': 0.23,
#  'SandP52WeekChange': -0.1535511,
#  'priceToBook': 39.459835,
#  'heldPercentInsiders': 0.0007,
#  'nextFiscalYearEnd': 1695600000,
#  'yield': None,
#  'mostRecentQuarter': 1656115200,
#  'shortRatio': 1.53,
#  'sharesShortPreviousMonthDate': 1660521600,
#  'floatShares': 16052270635,
#  'beta': 1.234119,
#  'enterpriseValue': 2292438007808,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '4:1',
#  'legalType': None,
#  'lastDividendDate': 1659657600,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.106,
#  'priceToSalesTrailing12Months': 5.907193,
#  'dateShortInterest': 1663200000,
#  'pegRatio': 2.46,
#  'ytdReturn': None,
#  'forwardPE': 22.051083,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0072000003,
#  'sharesShortPriorMonth': 115400891,
#  'impliedSharesOutstanding': 0,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 138.2,
#  'regularMarketOpen': 138.21,
#  'twoHundredDayAverage': 159.6774,
#  'trailingAnnualDividendYield': 0.006439942,
#  'payoutRatio': 0.1471,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 143.07,
#  'navPrice': None,
#  'averageDailyVolume10Day': 108346510,
#  'regularMarketPreviousClose': 138.2,
#  'fiftyDayAverage': 159.5014,
#  'trailingAnnualDividendRate': 0.89,
#  'open': 138.21,
#  'toCurrency': None,
#  'averageVolume10days': 108346510,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 0.92,
#  'exDividendDate': 1659657600,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 137.685,
#  'currency': 'USD',
#  'trailingPE': 23.545454,
#  'regularMarketVolume': 113578851,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2289285464064,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 79448764,
#  'dayLow': 137.685,
#  'ask': 0,
#  'askSize': 1000,
#  'volume': 113578851,
#  'fiftyTwoWeekHigh': 182.94,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.02,
#  'fiftyTwoWeekLow': 129.04,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': 0.0067000003,
#  'bidSize': 1100,
#  'dayHigh': 143.07,
#  'coinMarketCapLink': None,
#  'regularMarketPrice': 142.45,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/apple.com'}

# %%
tickers=['AAPL','MSFT','IBM']
tickers
# Out:
# ['AAPL', 'MSFT', 'IBM']

# %%
infos=[]
for i in tickers:
    infos.append(yf.Ticker(i).info)

# %%
infos
# Out:
# [{'zip': '95014',
#   'sector': 'Technology',
#   'fullTimeEmployees': 154000,
#   'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. In addition, the company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; AirPods Max, an over-ear wireless headphone; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, and iPod touch. Further, it provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. Additionally, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.',
#   'city': 'Cupertino',
#   'phone': '408 996 1010',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.apple.com',
#   'maxAge': 1,
#   'address1': 'One Apple Park Way',
#   'industry': 'Consumer Electronics',
#   'ebitdaMargins': 0.3343,
#   'profitMargins': 0.25709,
#   'grossMargins': 0.43313998,
#   'operatingCashflow': 118224003072,
#   'revenueGrowth': 0.019,
#   'operatingMargins': 0.30533,
#   'ebitda': 129556996096,
#   'targetLowPrice': 130,
#   'recommendationKey': 'buy',
#   'grossProfits': 152836000000,
#   'freeCashflow': 83344621568,
#   'targetMedianPrice': 185,
#   'currentPrice': 142.45,
#   'earningsGrowth': -0.077,
#   'currentRatio': 0.865,
#   'returnOnAssets': 0.22204,
#   'numberOfAnalystOpinions': 41,
#   'targetMeanPrice': 183.5,
#   'debtToEquity': 205.984,
#   'returnOnEquity': 1.62816,
#   'targetHighPrice': 220,
#   'totalCash': 48230998016,
#   'totalDebt': 119691001856,
#   'totalRevenue': 387541991424,
#   'totalCashPerShare': 3.001,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 23.732,
#   'quickRatio': 0.697,
#   'recommendationMean': 1.9,
#   'exchange': 'NMS',
#   'shortName': 'Apple Inc.',
#   'longName': 'Apple Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AAPL',
#   'messageBoardId': 'finmb_24937',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 5.915,
#   'beta3Year': None,
#   'enterpriseToEbitda': 17.694,
#   '52WeekChange': 0.009496093,
#   'morningStarRiskRating': None,
#   'forwardEps': 6.46,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 16070800384,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 3.61,
#   'sharesShort': 116076947,
#   'sharesPercentSharesOut': 0.0072000003,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1632528000,
#   'heldPercentInstitutions': 0.59604,
#   'netIncomeToCommon': 99632996352,
#   'trailingEps': 6.05,
#   'lastDividendValue': 0.23,
#   'SandP52WeekChange': -0.1535511,
#   'priceToBook': 39.459835,
#   'heldPercentInsiders': 0.0007,
#   'nextFiscalYearEnd': 1695600000,
#   'yield': None,
#   'mostRecentQuarter': 1656115200,
#   'shortRatio': 1.53,
#   'sharesShortPreviousMonthDate': 1660521600,
#   'floatShares': 16052270635,
#   'beta': 1.234119,
#   'enterpriseValue': 2292438007808,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1598832000,
#   'lastSplitFactor': '4:1',
#   'legalType': None,
#   'lastDividendDate': 1659657600,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.106,
#   'priceToSalesTrailing12Months': 5.907193,
#   'dateShortInterest': 1663200000,
#   'pegRatio': 2.46,
#   'ytdReturn': None,
#   'forwardPE': 22.051083,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0072000003,
#   'sharesShortPriorMonth': 115400891,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 138.2,
#   'regularMarketOpen': 138.21,
#   'twoHundredDayAverage': 159.6774,
#   'trailingAnnualDividendYield': 0.006439942,
#   'payoutRatio': 0.1471,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 143.07,
#   'navPrice': None,
#   'averageDailyVolume10Day': 108346510,
#   'regularMarketPreviousClose': 138.2,
#   'fiftyDayAverage': 159.5014,
#   'trailingAnnualDividendRate': 0.89,
#   'open': 138.21,
#   'toCurrency': None,
#   'averageVolume10days': 108346510,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 0.92,
#   'exDividendDate': 1659657600,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 137.685,
#   'currency': 'USD',
#   'trailingPE': 23.545454,
#   'regularMarketVolume': 113578851,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 2289285464064,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 79448764,
#   'dayLow': 137.685,
#   'ask': 0,
#   'askSize': 1000,
#   'volume': 113578851,
#   'fiftyTwoWeekHigh': 182.94,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.02,
#   'fiftyTwoWeekLow': 129.04,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0067000003,
#   'bidSize': 1100,
#   'dayHigh': 143.07,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 142.45,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/apple.com'},
#  {'zip': '98052-6399',
#   'sector': 'Technology',
#   'fullTimeEmployees': 221000,
#   'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. The More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; and Windows Internet of Things. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.',
#   'city': 'Redmond',
#   'phone': '425 882 8080',
#   'state': 'WA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.microsoft.com',
#   'maxAge': 1,
#   'address1': 'One Microsoft Way',
#   'fax': '425 706 7329',
#   'industry': 'Software—Infrastructure',
#   'ebitdaMargins': 0.49418998,
#   'profitMargins': 0.36686,
#   'grossMargins': 0.68402,
#   'operatingCashflow': 89034997760,
#   'revenueGrowth': 0.124,
#   'operatingMargins': 0.42055,
#   'ebitda': 97982996480,
#   'targetLowPrice': 275,
#   'recommendationKey': 'buy',
#   'grossProfits': 135620000000,
#   'freeCashflow': 49479000064,
#   'targetMedianPrice': 330,
#   'currentPrice': 240.74,
#   'earningsGrowth': 0.031,
#   'currentRatio': 1.785,
#   'returnOnAssets': 0.14919,
#   'numberOfAnalystOpinions': 44,
#   'targetMeanPrice': 332.03,
#   'debtToEquity': 47.075,
#   'returnOnEquity': 0.47151002,
#   'targetHighPrice': 411,
#   'totalCash': 104748998656,
#   'totalDebt': 78399995904,
#   'totalRevenue': 198269992960,
#   'totalCashPerShare': 14.045,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 26.45,
#   'quickRatio': 1.567,
#   'recommendationMean': 1.7,
#   'exchange': 'NMS',
#   'shortName': 'Microsoft Corporation',
#   'longName': 'Microsoft Corporation',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'MSFT',
#   'messageBoardId': 'finmb_21835',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 8.628,
#   'beta3Year': None,
#   'enterpriseToEbitda': 17.458,
#   '52WeekChange': -0.16629726,
#   'morningStarRiskRating': None,
#   'forwardEps': 11.92,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 7457889792,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 22.313,
#   'sharesShort': 42967330,
#   'sharesPercentSharesOut': 0.0058,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1656547200,
#   'heldPercentInstitutions': 0.71786004,
#   'netIncomeToCommon': 72737996800,
#   'trailingEps': 9.65,
#   'lastDividendValue': 0.62,
#   'SandP52WeekChange': -0.1535511,
#   'priceToBook': 10.789227,
#   'heldPercentInsiders': 0.00079,
#   'nextFiscalYearEnd': 1719705600,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': 1.95,
#   'sharesShortPreviousMonthDate': 1660521600,
#   'floatShares': 7450210243,
#   'beta': 0.942868,
#   'enterpriseValue': 1710594064384,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1045526400,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1660694400,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.017,
#   'priceToSalesTrailing12Months': 9.055391,
#   'dateShortInterest': 1663200000,
#   'pegRatio': 1.55,
#   'ytdReturn': None,
#   'forwardPE': 20.196308,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0058,
#   'sharesShortPriorMonth': 38084466,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 232.9,
#   'regularMarketOpen': 235.41,
#   'twoHundredDayAverage': 281.4246,
#   'trailingAnnualDividendYield': 0.010648347,
#   'payoutRatio': 0.2508,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 241.6,
#   'navPrice': None,
#   'averageDailyVolume10Day': 29621970,
#   'regularMarketPreviousClose': 232.9,
#   'fiftyDayAverage': 264.645,
#   'trailingAnnualDividendRate': 2.48,
#   'open': 235.41,
#   'toCurrency': None,
#   'averageVolume10days': 29621970,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 2.72,
#   'exDividendDate': 1668556800,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 234.66,
#   'currency': 'USD',
#   'trailingPE': 24.947151,
#   'regularMarketVolume': 28880357,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 1795412459520,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 24899106,
#   'dayLow': 234.66,
#   'ask': 0,
#   'askSize': 800,
#   'volume': 28880357,
#   'fiftyTwoWeekHigh': 349.67,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.2,
#   'fiftyTwoWeekLow': 232.73,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0117,
#   'bidSize': 1100,
#   'dayHigh': 241.6,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 240.74,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/microsoft.com'},
#  {'zip': '10504',
#   'sector': 'Technology',
#   'fullTimeEmployees': 282100,
#   'longBusinessSummary': "International Business Machines Corporation provides integrated solutions and services worldwide. The company operates through four business segments: Software, Consulting, Infrastructure, and Financing. The Software segment offers hybrid cloud platform and software solutions, such as Red Hat, an enterprise open-source solutions; software for business automation, AIOps and management, integration, and application servers; data and artificial intelligence solutions; and security software and services for threat, data, and identity. This segment also provides transaction processing software that supports clients' mission-critical and on-premise workloads in banking, airlines, and retail industries. The Consulting segment offers business transformation services, including strategy, business process design and operations, data and analytics, and system integration services; technology consulting services; and application and cloud platform services. The Infrastructure segment provides on-premises and cloud-based server and storage solutions for its clients' mission-critical and regulated workloads; and support services and solutions for hybrid cloud infrastructure, as well as remanufacturing and remarketing services for used equipment. The Financing segment offers lease, installment payment, loan financing, and short-term working capital financing services. The company was formerly known as Computing-Tabulating-Recording Co. International Business Machines Corporation was incorporated in 1911 and is headquartered in Armonk, New York.",
#   'city': 'Armonk',
#   'phone': '914 499 1900',
#   'state': 'NY',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.ibm.com',
#   'maxAge': 1,
#   'address1': 'One New Orchard Road',
#   'industry': 'Information Technology Services',
#   'ebitdaMargins': 0.20374,
#   'profitMargins': 0.09363,
#   'grossMargins': 0.54011,
#   'operatingCashflow': 9825999872,
#   'revenueGrowth': 0.093,
#   'operatingMargins': 0.11046,
#   'ebitda': 12158999552,
#   'targetLowPrice': 112,
#   'recommendationKey': 'buy',
#   'grossProfits': 31486000000,
#   'freeCashflow': 6312374784,
#   'targetMedianPrice': 145,
#   'currentPrice': 121.51,
#   'earningsGrowth': 0.041,
#   'currentRatio': 0.876,
#   'returnOnAssets': 0.03004,
#   'numberOfAnalystOpinions': 17,
#   'targetMeanPrice': 142.68,
#   'debtToEquity': 274.055,
#   'returnOnEquity': 0.2709,
#   'targetHighPrice': 163,
#   'totalCash': 7558000128,
#   'totalDebt': 53375000576,
#   'totalRevenue': 59679997952,
#   'totalCashPerShare': 8.368,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 66.383,
#   'quickRatio': 0.675,
#   'recommendationMean': 2.5,
#   'exchange': 'NYQ',
#   'shortName': 'International Business Machines',
#   'longName': 'International Business Machines Corporation',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'IBM',
#   'messageBoardId': 'finmb_112350',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.567,
#   'beta3Year': None,
#   'enterpriseToEbitda': 12.599,
#   '52WeekChange': -0.11212391,
#   'morningStarRiskRating': None,
#   'forwardEps': 10.04,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 896320000,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 21.49,
#   'sharesShort': 25758305,
#   'sharesPercentSharesOut': 0.028499998,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.57453996,
#   'netIncomeToCommon': 5626999808,
#   'trailingEps': 6.089,
#   'lastDividendValue': 1.65,
#   'SandP52WeekChange': -0.1535511,
#   'priceToBook': 5.654258,
#   'heldPercentInsiders': 0.00093000004,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': 7.55,
#   'sharesShortPreviousMonthDate': 1660521600,
#   'floatShares': 902051378,
#   'beta': 0.843787,
#   'enterpriseValue': 153190858752,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1635984000,
#   'lastSplitFactor': '1046:1000',
#   'legalType': None,
#   'lastDividendDate': 1660003200,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.051,
#   'priceToSalesTrailing12Months': 1.8249304,
#   'dateShortInterest': 1663200000,
#   'pegRatio': 1.35,
#   'ytdReturn': None,
#   'forwardPE': 12.10259,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.028499998,
#   'sharesShortPriorMonth': 22644445,
#   'impliedSharesOutstanding': None,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 118.81,
#   'regularMarketOpen': 120.16,
#   'twoHundredDayAverage': 132.0463,
#   'trailingAnnualDividendYield': 0.055382542,
#   'payoutRatio': 1.0580001,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 122.21,
#   'navPrice': None,
#   'averageDailyVolume10Day': 4199430,
#   'regularMarketPreviousClose': 118.81,
#   'fiftyDayAverage': 129.4494,
#   'trailingAnnualDividendRate': 6.58,
#   'open': 120.16,
#   'toCurrency': None,
#   'averageVolume10days': 4199430,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 6.6,
#   'exDividendDate': 1660003200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 119.6,
#   'currency': 'USD',
#   'trailingPE': 19.955658,
#   'regularMarketVolume': 3927811,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 108911845376,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 4605056,
#   'dayLow': 119.6,
#   'ask': 0,
#   'askSize': 1100,
#   'volume': 3927811,
#   'fiftyTwoWeekHigh': 144.73,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 4.78,
#   'fiftyTwoWeekLow': 114.56,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0556,
#   'bidSize': 800,
#   'dayHigh': 122.21,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 121.51,
#   'preMarketPrice': None,
#   'logo_url': 'https://logo.clearbit.com/ibm.com'}]

# %%
fundamentals=['dividendYield','marketCap','beta','forwardPE']

# %%
df=pd.DataFrame(infos)
df=df.set_index('symbol')
df
# Out:
#                zip      sector  fullTimeEmployees  \
# symbol
# AAPL         95014  Technology             154000
# MSFT    98052-6399  Technology             221000
# IBM          10504  Technology             282100
#
#                                       longBusinessSummary       city  \
# symbol
# AAPL    Apple Inc. designs, manufactures, and markets ...  Cupertino
# MSFT    Microsoft Corporation develops, licenses, and ...    Redmond
# IBM     International Business Machines Corporation pr...     Armonk
#
#                phone state        country companyOfficers  \
# symbol
# AAPL    408 996 1010    CA  United States              []
# MSFT    425 882 8080    WA  United States              []
# IBM     914 499 1900    NY  United States              []
#
#                           website  ...  bid tradeable dividendYield  bidSize  \
# symbol                             ...
# AAPL        https://www.apple.com  ...    0     False        0.0067     1100
# MSFT    https://www.microsoft.com  ...    0     False        0.0117     1100
# IBM           https://www.ibm.com  ...    0     False        0.0556      800
#
#         dayHigh  coinMarketCapLink  regularMarketPrice  preMarketPrice  \
# symbol
# AAPL     143.07               None              142.45            None
# MSFT     241.60               None              240.74            None
# IBM      122.21               None              121.51            None
#
#                                        logo_url           fax
# symbol
# AAPL        https://logo.clearbit.com/apple.com           NaN
# MSFT    https://logo.clearbit.com/microsoft.com  425 706 7329
# IBM           https://logo.clearbit.com/ibm.com           NaN
#
# [3 rows x 153 columns]

# %%
df.columns.isin(fundamentals)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False])

# %%
df[df.columns[df.columns.isin(fundamentals)]]
# Out:
#             beta  forwardPE      marketCap  dividendYield
# symbol
# AAPL    1.234119  22.051083  2289285464064         0.0067
# MSFT    0.942868  20.196308  1795412459520         0.0117
# IBM     0.843787  12.102590   108911845376         0.0556

# %%
plt.bar(df.index,df.dividendYield,color=('k','orange','cyan'))
plt.show()

# %%
plt.bar(df.index,df.forwardPE,color=('k','orange','cyan'))
plt.show()

# %%
tickers=pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')[1]
tickers
# Out:
#                      Company Exchange Symbol                        Industry  \
# 0                         3M     NYSE    MMM                    Conglomerate
# 1           American Express     NYSE    AXP              Financial services
# 2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3                      Apple   NASDAQ   AAPL          Information technology
# 4                     Boeing     NYSE     BA           Aerospace and defense
# 5                Caterpillar     NYSE    CAT         Construction and Mining
# 6                    Chevron     NYSE    CVX              Petroleum industry
# 7                      Cisco   NASDAQ   CSCO          Information technology
# 8                  Coca-Cola     NYSE     KO                  Drink industry
# 9                     Disney     NYSE    DIS  Broadcasting and entertainment
# 10                       Dow     NYSE    DOW               Chemical industry
# 11             Goldman Sachs     NYSE     GS              Financial services
# 12                Home Depot     NYSE     HD                Home Improvement
# 13                 Honeywell   NASDAQ    HON                    Conglomerate
# 14                       IBM     NYSE    IBM          Information technology
# 15                     Intel   NASDAQ   INTC          Semiconductor industry
# 16         Johnson & Johnson     NYSE    JNJ         Pharmaceutical industry
# 17            JPMorgan Chase     NYSE    JPM              Financial services
# 18                McDonald's     NYSE    MCD                   Food industry
# 19                     Merck     NYSE    MRK         Pharmaceutical industry
# 20                 Microsoft   NASDAQ   MSFT          Information technology
# 21                      Nike     NYSE    NKE               Clothing industry
# 22          Procter & Gamble     NYSE     PG      Fast-moving consumer goods
# 23                Salesforce     NYSE    CRM          Information technology
# 24                 Travelers     NYSE    TRV                       Insurance
# 25              UnitedHealth     NYSE    UNH             Managed health care
# 26                   Verizon     NYSE     VZ     Telecommunications industry
# 27                      Visa     NYSE      V              Financial services
# 28  Walgreens Boots Alliance   NASDAQ    WBA                       Retailing
# 29                   Walmart     NYSE    WMT                       Retailing
#
#     Date added                                              Notes  \
# 0   1976-08-09              As Minnesota Mining and Manufacturing
# 1   1982-08-30                                                NaN
# 2   2020-08-31                                                NaN
# 3   2015-03-19                                                NaN
# 4   1987-03-12                                                NaN
# 5   1991-05-06                                                NaN
# 6   2008-02-19                      Also 1930-07-18 to 1999-11-01
# 7   2009-06-08                                                NaN
# 8   1987-03-12                      Also 1932-05-26 to 1935-11-20
# 9   1991-05-06                                                NaN
# 10  2019-04-02                                                NaN
# 11  2013-09-20                                                NaN
# 12  1999-11-01                                                NaN
# 13  2020-08-31  Also 1925-12-07 to 2008-02-19 under various na...
# 14  1979-06-29                      Also 1932-05-26 to 1939-03-04
# 15  1999-11-01                                                NaN
# 16  1997-03-17                                                NaN
# 17  1991-05-06                                                NaN
# 18  1985-10-30                                                NaN
# 19  1979-06-29                                                NaN
# 20  1999-11-01                                                NaN
# 21  2013-09-20                                                NaN
# 22  1932-05-26                                                NaN
# 23  2020-08-31                                                NaN
# 24  2009-06-08                                                NaN
# 25  2012-09-24                                                NaN
# 26  2004-04-08                                                NaN
# 27  2013-09-20                                                NaN
# 28  2018-06-26                                                NaN
# 29  1997-03-17                                                NaN
#
#    Index weighting
# 0            2.88%
# 1            3.56%
# 2            4.88%
# 3            3.15%
# 4            3.40%
# 5            4.19%
# 6            3.05%
# 7            1.00%
# 8            1.28%
# 9            2.32%
# 10           1.32%
# 11           6.22%
# 12           5.90%
# 13           3.71%
# 14           2.69%
# 15           0.91%
# 16           3.60%
# 17           2.45%
# 18           4.89%
# 19           1.65%
# 20           5.43%
# 21           2.48%
# 22           3.15%
# 23           3.38%
# 24           3.38%
# 25          10.14%
# 26           0.97%
# 27           4.06%
# 28           0.88%
# 29           3.04%

# %%
tickers=tickers.Symbol
tickers
# Out:
# 0      MMM
# 1      AXP
# 2     AMGN
# 3     AAPL
# 4       BA
# 5      CAT
# 6      CVX
# 7     CSCO
# 8       KO
# 9      DIS
# 10     DOW
# 11      GS
# 12      HD
# 13     HON
# 14     IBM
# 15    INTC
# 16     JNJ
# 17     JPM
# 18     MCD
# 19     MRK
# 20    MSFT
# 21     NKE
# 22      PG
# 23     CRM
# 24     TRV
# 25     UNH
# 26      VZ
# 27       V
# 28     WBA
# 29     WMT
# Name: Symbol, dtype: object

# %%
infos=[]
for i in tickers:
    infos.append(yf.Ticker(i).info)

# %%
df=pd.DataFrame(infos)
df=df.set_index('symbol')
df
# Out:
#                zip                  sector  fullTimeEmployees  \
# symbol
# MMM     55144-1000             Industrials            95000.0
# AXP          10285      Financial Services            64000.0
# AMGN    91320-1799              Healthcare            24200.0
# AAPL         95014              Technology           154000.0
# BA      60606-1596             Industrials           142000.0
# CAT          60015             Industrials           107700.0
# CVX     94583-2324                  Energy            42595.0
# CSCO    95134-1706              Technology            83300.0
# KO           30313      Consumer Defensive            79000.0
# DIS          91521  Communication Services           152000.0
# DOW          48674         Basic Materials            35700.0
# GS           10282      Financial Services            47000.0
# HD           30339       Consumer Cyclical           500000.0
# HON          28202             Industrials            99000.0
# IBM          10504              Technology           282100.0
# INTC    95054-1549              Technology           121100.0
# JNJ          08933              Healthcare           141700.0
# JPM          10179      Financial Services           278494.0
# MCD          60607       Consumer Cyclical           100000.0
# MRK          07033              Healthcare            67000.0
# MSFT    98052-6399              Technology           221000.0
# NKE     97005-6453       Consumer Cyclical            79100.0
# PG           45202      Consumer Defensive                NaN
# CRM          94105              Technology            77810.0
# TRV          10017      Financial Services            30184.0
# UNH          55343              Healthcare           350000.0
# VZ           10036  Communication Services           119400.0
# V       94128-8999      Financial Services            21500.0
# WBA          60015              Healthcare           315000.0
# WMT          72716      Consumer Defensive          2300000.0
#
#                                       longBusinessSummary           city  \
# symbol
# MMM     3M Company operates as a diversified technolog...     Saint Paul
# AXP     American Express Company, together with its su...       New York
# AMGN    Amgen Inc. discovers, develops, manufactures, ...  Thousand Oaks
# AAPL    Apple Inc. designs, manufactures, and markets ...      Cupertino
# BA      The Boeing Company, together with its subsidia...        Chicago
# CAT     Caterpillar Inc. manufactures and sells constr...      Deerfield
# CVX     Chevron Corporation, through its subsidiaries,...      San Ramon
# CSCO    Cisco Systems, Inc. designs, manufactures, and...       San Jose
# KO      The Coca-Cola Company, a beverage company, man...        Atlanta
# DIS     The Walt Disney Company, together with its sub...        Burbank
# DOW     Dow Inc. provides various materials science so...        Midland
# GS      The Goldman Sachs Group, Inc., a financial ins...       New York
# HD      The Home Depot, Inc. operates as a home improv...        Atlanta
# HON     Honeywell International Inc. operates as a div...      Charlotte
# IBM     International Business Machines Corporation pr...         Armonk
# INTC    Intel Corporation engages in the design, manuf...    Santa Clara
# JNJ     Johnson & Johnson, together with its subsidiar...  New Brunswick
# JPM     JPMorgan Chase & Co. operates as a financial s...       New York
# MCD     McDonald's Corporation operates and franchises...        Chicago
# MRK     Merck & Co., Inc. operates as a healthcare com...     Kenilworth
# MSFT    Microsoft Corporation develops, licenses, and ...        Redmond
# NKE     NIKE, Inc., together with its subsidiaries, de...      Beaverton
# PG      The Procter & Gamble Company provides branded ...     Cincinnati
# CRM     Salesforce, Inc. provides customer relationshi...  San Francisco
# TRV     The Travelers Companies, Inc., through its sub...       New York
# UNH     UnitedHealth Group Incorporated operates as a ...     Minnetonka
# VZ      Verizon Communications Inc., through its subsi...       New York
# V       Visa Inc. operates as a payments technology co...  San Francisco
# WBA     Walgreens Boots Alliance, Inc. operates as a p...      Deerfield
# WMT     Walmart Inc. engages in the operation of retai...    Bentonville
#
#                phone state        country companyOfficers  \
# symbol
# MMM     651 733 1110    MN  United States              []
# AXP     212 640 2000    NY  United States              []
# AMGN    805 447 1000    CA  United States              []
# AAPL    408 996 1010    CA  United States              []
# BA      312 544 2000    IL  United States              []
# CAT     224-551-4000    IL  United States              []
# CVX     925 842 1000    CA  United States              []
# CSCO    408 526 4000    CA  United States              []
# KO      404 676 2121    GA  United States              []
# DIS     818 560 1000    CA  United States              []
# DOW     989 636 1000    MI  United States              []
# GS      212-902-1000    NY  United States              []
# HD      770 433 8211    GA  United States              []
# HON     704 627 6200    NC  United States              []
# IBM     914 499 1900    NY  United States              []
# INTC    408 765 8080    CA  United States              []
# JNJ     732 524 0400    NJ  United States              []
# JPM     212 270 6000    NY  United States              []
# MCD     630 623 3000    IL  United States              []
# MRK     908 740 4000    NJ  United States              []
# MSFT    425 882 8080    WA  United States              []
# NKE     503 671 6453    OR  United States              []
# PG      513 983 1100    OH  United States              []
# CRM     415 901 7000    CA  United States              []
# TRV     917 778 6000    NY  United States              []
# UNH     952 936 1300    MN  United States              []
# VZ      212 395 1000    NY  United States              []
# V       650 432 3200    CA  United States              []
# WBA     847 315 3700    IL  United States              []
# WMT     479 273 4000    AR  United States              []
#
#                                        website  ...  coinMarketCapLink  \
# symbol                                          ...
# MMM                         https://www.3m.com  ...                NaN
# AXP            https://www.americanexpress.com  ...                NaN
# AMGN                     https://www.amgen.com  ...                NaN
# AAPL                     https://www.apple.com  ...                NaN
# BA                      https://www.boeing.com  ...                NaN
# CAT                https://www.caterpillar.com  ...                NaN
# CVX                    https://www.chevron.com  ...                NaN
# CSCO                     https://www.cisco.com  ...                NaN
# KO            https://www.coca-colacompany.com  ...                NaN
# DIS       https://www.thewaltdisneycompany.com  ...                NaN
# DOW                        https://www.dow.com  ...                NaN
# GS                https://www.goldmansachs.com  ...                NaN
# HD                   https://www.homedepot.com  ...                NaN
# HON                  https://www.honeywell.com  ...                NaN
# IBM                        https://www.ibm.com  ...                NaN
# INTC                     https://www.intel.com  ...                NaN
# JNJ                        https://www.jnj.com  ...                NaN
# JPM              https://www.jpmorganchase.com  ...                NaN
# MCD            https://corporate.mcdonalds.com  ...                NaN
# MRK                      https://www.merck.com  ...                NaN
# MSFT                 https://www.microsoft.com  ...                NaN
# NKE                 https://investors.nike.com  ...                NaN
# PG                  https://www.pginvestor.com  ...                NaN
# CRM                 https://www.salesforce.com  ...                NaN
# TRV                  https://www.travelers.com  ...                NaN
# UNH          https://www.unitedhealthgroup.com  ...                NaN
# VZ                     https://www.verizon.com  ...                NaN
# V                         https://usa.visa.com  ...                NaN
# WBA     https://www.walgreensbootsalliance.com  ...                NaN
# WMT              https://www.stock.walmart.com  ...                NaN
#
#        regularMarketPrice preMarketPrice  \
# symbol
# MMM                113.22           None
# AXP                140.02           None
# AMGN               230.44           None
# AAPL               142.45           None
# BA                 126.05           None
# CAT                171.23           None
# CVX                151.73           None
# CSCO                41.29           None
# KO                  56.65           None
# DIS                 97.13           None
# DOW                 45.28           None
# GS                 299.15           None
# HD                 283.70           None
# HON                173.04           None
# IBM                121.51           None
# INTC                26.97           None
# JNJ                163.20           None
# JPM                107.73           None
# MCD                235.34           None
# MRK                 87.55           None
# MSFT               240.74           None
# NKE                 85.40           None
# PG                 128.51           None
# CRM                147.90           None
# TRV                157.07           None
# UNH                515.51           None
# VZ                  39.16           None
# V                  181.65           None
# WBA                 32.43           None
# WMT                132.53           None
#
#                                                  logo_url           fax  \
# symbol
# MMM                      https://logo.clearbit.com/3m.com           NaN
# AXP         https://logo.clearbit.com/americanexpress.com           NaN
# AMGN                  https://logo.clearbit.com/amgen.com  805 447 1010
# AAPL                  https://logo.clearbit.com/apple.com           NaN
# BA                   https://logo.clearbit.com/boeing.com           NaN
# CAT             https://logo.clearbit.com/caterpillar.com           NaN
# CVX                 https://logo.clearbit.com/chevron.com           NaN
# CSCO                  https://logo.clearbit.com/cisco.com           NaN
# KO         https://logo.clearbit.com/coca-colacompany.com           NaN
# DIS     https://logo.clearbit.com/thewaltdisneycompany...           NaN
# DOW                     https://logo.clearbit.com/dow.com  989 832 1456
# GS             https://logo.clearbit.com/goldmansachs.com           NaN
# HD                https://logo.clearbit.com/homedepot.com           NaN
# HON               https://logo.clearbit.com/honeywell.com           NaN
# IBM                     https://logo.clearbit.com/ibm.com           NaN
# INTC                  https://logo.clearbit.com/intel.com           NaN
# JNJ                     https://logo.clearbit.com/jnj.com           NaN
# JPM           https://logo.clearbit.com/jpmorganchase.com           NaN
# MCD     https://logo.clearbit.com/corporate.mcdonalds.com           NaN
# MRK                   https://logo.clearbit.com/merck.com           NaN
# MSFT              https://logo.clearbit.com/microsoft.com  425 706 7329
# NKE          https://logo.clearbit.com/investors.nike.com           NaN
# PG               https://logo.clearbit.com/pginvestor.com           NaN
# CRM              https://logo.clearbit.com/salesforce.com  415 901 7040
# TRV               https://logo.clearbit.com/travelers.com           NaN
# UNH       https://logo.clearbit.com/unitedhealthgroup.com           NaN
# VZ                  https://logo.clearbit.com/verizon.com           NaN
# V                  https://logo.clearbit.com/usa.visa.com           NaN
# WBA     https://logo.clearbit.com/walgreensbootsallian...           NaN
# WMT           https://logo.clearbit.com/stock.walmart.com           NaN
#
#                             address2  underlyingSymbol  \
# symbol
# MMM                              NaN               NaN
# AXP                              NaN               NaN
# AMGN                             NaN               NaN
# AAPL                             NaN               NaN
# BA                               NaN               NaN
# CAT                        Suite 100               NaN
# CVX                              NaN               NaN
# CSCO                             NaN               NaN
# KO                               NaN               NaN
# DIS                              NaN               NaN
# DOW                              NaN               NaN
# GS                               NaN               NaN
# HD                               NaN               NaN
# HON                              NaN               NaN
# IBM                              NaN               NaN
# INTC                             NaN               NaN
# JNJ                              NaN               NaN
# JPM                              NaN               NaN
# MCD                              NaN               NaN
# MRK                              NaN               NaN
# MSFT                             NaN               NaN
# NKE                              NaN               NaN
# PG                               NaN               NaN
# CRM     3rd Floor 415 Mission Street               NaN
# TRV                              NaN               NaN
# UNH              9900 Bren Road East               NaN
# VZ                               NaN               NaN
# V                                NaN               NaN
# WBA                              NaN               NaN
# WMT                              NaN               NaN
#
#         underlyingExchangeSymbol  headSymbol  \
# symbol
# MMM                          NaN         NaN
# AXP                          NaN         NaN
# AMGN                         NaN         NaN
# AAPL                         NaN         NaN
# BA                           NaN         NaN
# CAT                          NaN         NaN
# CVX                          NaN         NaN
# CSCO                         NaN         NaN
# KO                           NaN         NaN
# DIS                          NaN         NaN
# DOW                          NaN         NaN
# GS                           NaN         NaN
# HD                           NaN         NaN
# HON                          NaN         NaN
# IBM                          NaN         NaN
# INTC                         NaN         NaN
# JNJ                          NaN         NaN
# JPM                          NaN         NaN
# MCD                          NaN         NaN
# MRK                          NaN         NaN
# MSFT                         NaN         NaN
# NKE                          NaN         NaN
# PG                           NaN         NaN
# CRM                          NaN         NaN
# TRV                          NaN         NaN
# UNH                          NaN         NaN
# VZ                           NaN         NaN
# V                            NaN         NaN
# WBA                          NaN         NaN
# WMT                          NaN         NaN
#
#                                         uuid
# symbol
# MMM                                      NaN
# AXP                                      NaN
# AMGN                                     NaN
# AAPL                                     NaN
# BA                                       NaN
# CAT                                      NaN
# CVX                                      NaN
# CSCO                                     NaN
# KO                                       NaN
# DIS                                      NaN
# DOW                                      NaN
# GS                                       NaN
# HD      27178471-f2c4-319c-872d-1545a0f154c7
# HON     b586a6a4-876a-334e-8a5d-322e18a9cb87
# IBM     cbf44511-d041-3c6d-9dd7-3cc0c033122c
# INTC    fc39dab3-4bbe-3356-80d3-0933db783ba0
# JNJ     73aa25b0-87c8-3616-a460-03cbef1b4753
# JPM     bc753df4-b894-3e19-9c58-995ef66d8e67
# MCD     23d8bc2b-33aa-36cd-80f6-61c9e181ef67
# MRK     3fd0c404-d9b9-32ea-a95e-f2db63766fb3
# MSFT    b004b3ec-de24-385e-b2c1-923f10d3fb62
# NKE     31395cb8-4595-3f3c-a5ad-b37464c2ce43
# PG      49f38fe0-3598-34d6-bf4a-0a8791c9c8b9
# CRM     01d3fcca-fdd3-37b7-b601-1bfd3a695ce7
# TRV     f9648b70-41f5-3bd8-a005-3a20a688b790
# UNH     33ae4437-560d-3a42-9aa4-234d48c993c5
# VZ      a708480c-0400-3ea0-b2d3-ca752db5c3b1
# V       5206560a-306a-3e08-9a43-7fd258eb57ce
# WBA     888fa4a2-1f3d-3718-83dd-229207680ca9
# WMT     902d429a-38af-3903-a1d7-3374c3560928
#
# [30 rows x 158 columns]

# %%
plt.figure(figsize=(14,5))
plt.bar(df['shortName'],df.dividendYield)
plt.xticks(rotation=90)
plt.show()
