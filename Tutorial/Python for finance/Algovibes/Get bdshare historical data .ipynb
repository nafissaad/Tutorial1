# %%
from bdshare import get_current_trade_data

df = get_current_trade_data()
print(df.head())
# Out:
#        symbol   ltp  high   low close   ycp change trade   value   volume
# 0   1JANATAMF   3.5   3.6   3.5   3.5   3.6   -0.1    79    2.48   696330
# 1  1STPRIMFMF    24  24.9  23.7    24  24.3   -0.3  1015  37.433  1541814
# 2    AAMRANET  19.3  19.6  19.3  19.3  19.4   -0.1   249   3.899   200618
# 3   AAMRATECH  13.3  13.6  13.2  13.3  13.2    0.1    80    0.55    41148
# 4    ABB1STMF   3.8   3.9   3.8   3.8   3.8      0   149   5.852  1539098

# %%
from bdshare import get_basic_hist_data

df = get_basic_hist_data('2024-05-01', '2025-07-24', 'GP')  # 'GP' = Grameenphone
print(df)
# Out:
#            date   open   high    low  close  volume
# 0    2025-07-24  323.3  323.3  319.8  321.1  268454
# 1    2025-07-23  313.2  324.0  313.2  323.3  482561
# 2    2025-07-22  310.1  315.0  306.5  313.4  147093
# 3    2025-07-21  303.0  315.5  303.0  310.1  329778
# 4    2025-07-20  300.2  304.1  300.2  303.0  193685
# ..          ...    ...    ...    ...    ...     ...
# 284  2024-05-08  239.5  240.9  238.4  238.7  137311
# 285  2024-05-07  241.8  241.8  239.0  239.5  462408
# 286  2024-05-06  241.9  241.9  238.5  239.7  270193
# 287  2024-05-05  237.6  240.8  237.6  239.5   91141
# 288  2024-05-02  236.0  239.0  236.0  237.6  189769
#
# [289 rows x 6 columns]

# %%
df = df.set_index('date')

# %%
df.close.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.iloc[::-1].close.plot()
# Out:
# <Axes: xlabel='date'>
