# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sktime.datasets import load_airline
import datetime as dt
import pandas_datareader.data as reader

# %%
end=dt.datetime.now()
start=dt.datetime(end.year-10,end.month,end.day)
price=reader.get_data_yahoo('TSLA',start,end)['Adj Close']
price=pd.DataFrame(price)
price
# Out:
#              Adj Close
# Date
# 2012-09-18    2.089333
# 2012-09-19    2.070000
# 2012-09-20    2.060000
# 2012-09-21    2.001333
# 2012-09-24    2.044000
# ...                ...
# 2022-09-12  304.420013
# 2022-09-13  292.130005
# 2022-09-14  302.609985
# 2022-09-15  303.750000
# 2022-09-16  303.350006
#
# [2516 rows x 1 columns]

# %%
price.plot()

# %%
x=np.log(price)
x
# Out:
#             Adj Close
# Date
# 2012-09-18   0.736845
# 2012-09-19   0.727549
# 2012-09-20   0.722706
# 2012-09-21   0.693813
# 2012-09-24   0.714909
# ...               ...
# 2022-09-12   5.718408
# 2022-09-13   5.677199
# 2022-09-14   5.712445
# 2022-09-15   5.716205
# 2022-09-16   5.714887
#
# [2516 rows x 1 columns]

# %%
x.plot()

# %%
y=np.exp(x)
y.plot()

# %%
airline = load_airline()
airline
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
#            ...
# 1960-08    606.0
# 1960-09    508.0
# 1960-10    461.0
# 1960-11    390.0
# 1960-12    432.0
# Freq: M, Name: Number of airline passengers, Length: 144, dtype: float64

# %%
airline.plot()

# %%
x=np.log(airline)
x.plot()

# %%
y=np.exp(x)
y.plot()

# %%
x,y
# Out:
# (Period
#  1949-01    4.718499
#  1949-02    4.770685
#  1949-03    4.882802
#  1949-04    4.859812
#  1949-05    4.795791
#               ...
#  1960-08    6.406880
#  1960-09    6.230481
#  1960-10    6.133398
#  1960-11    5.966147
#  1960-12    6.068426
#  Freq: M, Name: Number of airline passengers, Length: 144, dtype: float64,
#  Period
#  1949-01    112.0
#  1949-02    118.0
#  1949-03    132.0
#  1949-04    129.0
#  1949-05    121.0
#             ...
#  1960-08    606.0
#  1960-09    508.0
#  1960-10    461.0
#  1960-11    390.0
#  1960-12    432.0
#  Freq: M, Name: Number of airline passengers, Length: 144, dtype: float64)
