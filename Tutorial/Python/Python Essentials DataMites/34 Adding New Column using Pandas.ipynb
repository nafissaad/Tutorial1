# %%
#Create a new column and name it 'investment_amount_inthousand' and fill the values from 'investment amount(in lalkh INR)' column 
#in thousand from ShartankIndiaAllPitches dataframe ?

# %%
import pandas as pd
import numpy as np
url='https://raw.githubusercontent.com/nafissaad/Tutorial1/main/Tutorial/Python/Python%20Essentials%20DataMites/32%20Conditional%20Filtering%20in%20Pandas/ShartankIndiaAllPitches.csv'
df=pd.read_csv(url)
df
# Out:
#      Episode Number  Pitch Number                Brand  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               Idea  \
# 0                                     Frozen Momos
# 1    Renting e-bike for mobility in private spaces
# 2                               Detachable Sleeves
# 3                             Healthy Potato Chips
# ...

# %%
df.columns
# Out:
# Index(['Episode Number', 'Pitch Number', 'Brand', 'Idea',
#        'Investment Amount (In Lakhs INR) ', 'Debt (In lakhs INR)', 'Equity',
#        'Anupam', 'Ashneer', 'Namita', 'Aman', 'Peyush', 'Vineeta', 'Ghazal',
#        'Season'],
#       dtype='object')

# %%
df['investment_amount_in_thousands']=df['Investment Amount (In Lakhs INR) '].map(lambda x : x*100)
df['investment_amount_in_thousands']
# Out:
# 0      7500
# 1      4000
# 2      2500
# 3      7000
# 4         0
#        ...
# 112       0
# 113       0
# 114    4000
# 115       0
# 116       0
# Name: investment_amount_in_thousands, Length: 117, dtype: int64
