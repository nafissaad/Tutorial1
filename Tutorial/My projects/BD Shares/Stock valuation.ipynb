# %%
#impoer the liberies
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL
from bdshare import get_basic_hist_data
plt.style .use('fivethirtyeight')

# %%
ticker='Olympic'
df=get_basic_hist_data('2019-01-1','2022-10-05',ticker,index='date')
df =df[~(df.open<=0)]
df
# Out:
#              open   high    low  close  volume
# date
# 2020-10-05  173.3  175.0  171.8  172.9   48156
# 2020-10-06  172.9  172.9  169.0  170.8   40558
# 2020-10-07  170.5  173.1  170.4  170.9   30845
# 2020-10-08  170.9  172.5  167.0  167.8   64991
# 2020-10-11  169.0  170.0  162.5  163.9   47197
# ...           ...    ...    ...    ...     ...
# 2022-09-28  131.0  131.0  128.0  128.1  199498
# 2022-09-29  129.9  131.0  127.5  129.6  157573
# 2022-10-02  128.6  131.5  128.6  129.5  127008
# 2022-10-03  129.5  129.5  127.8  128.2  142920
# 2022-10-04  128.4  129.9  127.4  127.9   70302
#
# [484 rows x 5 columns]

# %%
m=pd.to_datetime(df.index)
m
# Out:
# DatetimeIndex(['2020-10-05', '2020-10-06', '2020-10-07', '2020-10-08',
#                '2020-10-11', '2020-10-12', '2020-10-13', '2020-10-14',
#                '2020-10-15', '2020-10-18',
#                ...
#                '2022-09-21', '2022-09-22', '2022-09-25', '2022-09-26',
#                '2022-09-27', '2022-09-28', '2022-09-29', '2022-10-02',
#                '2022-10-03', '2022-10-04'],
#               dtype='datetime64[ns]', name='date', length=484, freq=None)

# %%
df.set_index(m, inplace=True)
t=df.asfreq('D')

# %%
#create figure
plt.figure(figsize=(15,10))
df1=df
#define width of candlestick elements
width = 1.3
width2 = 0.2

#define up and down prices
up = df1[df1.close>=df1.open]
down = df1[df1.close<df1.open]

#define colors to use
col1 = 'green'
col2 = 'red'

#plot up prices
plt.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
plt.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
plt.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

#plot down prices
plt.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
plt.bar(down.index,down.high-down.close,width2,bottom=down.close,color=col2)
plt.bar(down.index,down.low-down.open,width2,bottom=down.open,color=col2)

#rotate x-axis tick labels
plt.xticks(rotation=45, ha='right')

#display candlestick chart
plt.title('Olympic Chart')
plt.xlabel('Dates')
plt.ylabel('Price BDT')
plt.axhline(170, color='k', linestyle='--', alpha=0.2,label='Valuation')
plt.legend( fontsize=16)
plt.show()

# %%
ticker='IDLC'
df=get_basic_hist_data('2019-01-1','2022-10-05',ticker,index='date')
df=df[~(df.open<=0)]

# %%
m=pd.to_datetime(df.index)
m
df.set_index(m, inplace=True)
t=df.asfreq('D')

# %%
#create figure
plt.figure(figsize=(15,10))
df1=df
#define width of candlestick elements
width = 1.3
width2 = 0.2

#define up and down prices
up = df1[df1.close>=df1.open]
down = df1[df1.close<df1.open]

#define colors to use
col1 = 'green'
col2 = 'red'

#plot up prices
plt.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
plt.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
plt.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

#plot down prices
plt.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
plt.bar(down.index,down.high-down.close,width2,bottom=down.close,color=col2)
plt.bar(down.index,down.low-down.open,width2,bottom=down.open,color=col2)

#rotate x-axis tick labels
plt.xticks(rotation=45, ha='right')

#display candlestick chart
plt.title('IDLC Chart')
plt.xlabel('Dates')
plt.ylabel('Price BDT')
plt.axhline(65, color='k', linestyle='--', alpha=0.2,label='Valuation')
plt.legend( fontsize=16)
plt.show()

# %%
ticker='EPGL'
df=get_basic_hist_data('2019-01-1','2022-10-05',ticker,index='date')
df=df[~(df.open<=0)]

# %%
m=pd.to_datetime(df.index)
m
df.set_index(m, inplace=True)
t=df.asfreq('D')

# %%
#create figure
plt.figure(figsize=(15,10))
df1=df
#define width of candlestick elements
width = 1.3
width2 = 0.2

#define up and down prices
up = df1[df1.close>=df1.open]
down = df1[df1.close<df1.open]

#define colors to use
col1 = 'green'
col2 = 'red'

#plot up prices
plt.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
plt.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
plt.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

#plot down prices
plt.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
plt.bar(down.index,down.high-down.close,width2,bottom=down.close,color=col2)
plt.bar(down.index,down.low-down.open,width2,bottom=down.open,color=col2)

#rotate x-axis tick labels
plt.xticks(rotation=45, ha='right')

#display candlestick chart
plt.title('EPGL Chart')
plt.xlabel('Dates')
plt.ylabel('Price BDT')
plt.axhline(50, color='k', linestyle='--', alpha=0.2,label='Valuation')
plt.legend( fontsize=16)
plt.show()

# %%
ticker='BBSCABLES'
df=get_basic_hist_data('2019-01-1','2022-10-05',ticker,index='date')
df=df[~(df.open<=0)]

# %%
m=pd.to_datetime(df.index)
m
df.set_index(m, inplace=True)
t=df.asfreq('D')

# %%
#create figure
plt.figure(figsize=(15,10))
df1=df
#define width of candlestick elements
width = 1.3
width2 = 0.2

#define up and down prices
up = df1[df1.close>=df1.open]
down = df1[df1.close<df1.open]

#define colors to use
col1 = 'green'
col2 = 'red'

#plot up prices
plt.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
plt.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
plt.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

#plot down prices
plt.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
plt.bar(down.index,down.high-down.close,width2,bottom=down.close,color=col2)
plt.bar(down.index,down.low-down.open,width2,bottom=down.open,color=col2)

#rotate x-axis tick labels
plt.xticks(rotation=45, ha='right')

#display candlestick chart
plt.title('BBS Cable Chart')
plt.xlabel('Dates')
plt.ylabel('Price BDT')
plt.axhline(70, color='k', linestyle='--', alpha=0.2,label='Valuation')
plt.legend( fontsize=16)
plt.show()

# %%
ticker='IBP'
df=get_basic_hist_data('2019-01-1','2022-10-05',ticker,index='date')
df=df[~(df.open<=0)]

m=pd.to_datetime(df.index)
m
df.set_index(m, inplace=True)
t=df.asfreq('D')

#create figure
plt.figure(figsize=(15,10))
df1=df
#define width of candlestick elements
width = 1.3
width2 = 0.2

#define up and down prices
up = df1[df1.close>=df1.open]
down = df1[df1.close<df1.open]

#define colors to use
col1 = 'green'
col2 = 'red'

#plot up prices
plt.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
plt.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
plt.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

#plot down prices
plt.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
plt.bar(down.index,down.high-down.close,width2,bottom=down.close,color=col2)
plt.bar(down.index,down.low-down.open,width2,bottom=down.open,color=col2)

#rotate x-axis tick labels
plt.xticks(rotation=45, ha='right')

#display candlestick chart
plt.title('BBS Cable Chart')
plt.xlabel('Dates')
plt.ylabel('Price BDT')
plt.axhline(28.8, color='k', linestyle='--', alpha=0.2,label='Valuation')
plt.legend( fontsize=16)
plt.show()

# %%
ticker='RUNNERAUTO'
df=get_basic_hist_data('2019-01-1','2022-10-05',ticker,index='date')
df=df[~(df.open<=0)]

m=pd.to_datetime(df.index)
m
df.set_index(m, inplace=True)
t=df.asfreq('D')

#create figure
plt.figure(figsize=(15,10))
df1=df
#define width of candlestick elements
width = 1.3
width2 = 0.2

#define up and down prices
up = df1[df1.close>=df1.open]
down = df1[df1.close<df1.open]

#define colors to use
col1 = 'green'
col2 = 'red'

#plot up prices
plt.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
plt.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
plt.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

#plot down prices
plt.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
plt.bar(down.index,down.high-down.close,width2,bottom=down.close,color=col2)
plt.bar(down.index,down.low-down.open,width2,bottom=down.open,color=col2)

#rotate x-axis tick labels
plt.xticks(rotation=45, ha='right')

#display candlestick chart
plt.title('Runner Auto')
plt.xlabel('Dates')
plt.ylabel('Price BDT')
plt.axhline(70, color='k', linestyle='--', alpha=0.2,label='Valuation')
plt.legend( fontsize=16)
plt.show()

# %%
ticker='DBH'
df=get_basic_hist_data('2019-01-1','2022-10-05',ticker,index='date')
df=df[~(df.open<=0)]

m=pd.to_datetime(df.index)
m
df.set_index(m, inplace=True)
t=df.asfreq('D')

#create figure
plt.figure(figsize=(15,10))
df1=df
#define width of candlestick elements
width = 1.3
width2 = 0.2

#define up and down prices
up = df1[df1.close>=df1.open]
down = df1[df1.close<df1.open]

#define colors to use
col1 = 'green'
col2 = 'red'

#plot up prices
plt.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
plt.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
plt.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

#plot down prices
plt.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
plt.bar(down.index,down.high-down.close,width2,bottom=down.close,color=col2)
plt.bar(down.index,down.low-down.open,width2,bottom=down.open,color=col2)

#rotate x-axis tick labels
plt.xticks(rotation=45, ha='right')

#display candlestick chart
plt.title('BBS Cable Chart')
plt.xlabel('Dates')
plt.ylabel('Price BDT')
plt.axhline(80, color='k', linestyle='--', alpha=0.2,label='Valuation')
plt.legend( fontsize=16)
plt.show()

# %%
from statsmodels.tsa.seasonal import STL

# %%
ticker='RUNNERAUTO'
df=get_basic_hist_data('2019-01-1','2022-10-05',ticker,index='date')
df=df[~(df.open<=0)]
df['adj']=(df.open+df.close)/2

m=pd.to_datetime(df.index)
m
df.set_index(m, inplace=True)
t=df.asfreq('D')

# %%
df[['open','close','adj']][20:30].plot()

# %%
df=df.interpolate(method='time')
df
# Out:
#             open  high   low  close  volume    adj
# date
# 2020-10-05  55.3  55.9  53.0   53.4  333318  54.35
# 2020-10-06  54.4  54.9  51.4   52.5  341328  53.45
# 2020-10-07  53.9  54.1  52.2   52.4  249365  53.15
# 2020-10-08  53.0  53.1  52.0   52.1  168583  52.55
# 2020-10-11  52.1  52.7  48.5   50.5  185458  51.30
# ...          ...   ...   ...    ...     ...    ...
# 2022-09-28  50.6  50.6  48.6   49.0  116050  49.80
# 2022-09-29  49.9  49.9  48.5   48.7  107664  49.30
# 2022-10-02  49.0  52.0  48.6   51.0  344052  50.00
# 2022-10-03  51.5  52.7  50.3   50.8  403427  51.15
# 2022-10-04  51.0  51.9  49.7   50.1  296360  50.55
#
# [484 rows x 6 columns]

# %%
stl=STL(df['adj'],period=90)#two month seasonal Decomposition
Result = stl.fit()

# %%
seasonal,trend,resid = Result.seasonal,Result.trend, Result.resid
df['trend']=trend
df
# Out:
#             open  high   low  close  volume    adj      trend
# date
# 2020-10-05  55.3  55.9  53.0   53.4  333318  54.35  50.007340
# 2020-10-06  54.4  54.9  51.4   52.5  341328  53.45  50.017065
# 2020-10-07  53.9  54.1  52.2   52.4  249365  53.15  50.026700
# 2020-10-08  53.0  53.1  52.0   52.1  168583  52.55  50.036244
# 2020-10-11  52.1  52.7  48.5   50.5  185458  51.30  50.045695
# ...          ...   ...   ...    ...     ...    ...        ...
# 2022-09-28  50.6  50.6  48.6   49.0  116050  49.80  50.582321
# 2022-09-29  49.9  49.9  48.5   48.7  107664  49.30  50.575383
# 2022-10-02  49.0  52.0  48.6   51.0  344052  50.00  50.568471
# 2022-10-03  51.5  52.7  50.3   50.8  403427  51.15  50.561584
# 2022-10-04  51.0  51.9  49.7   50.1  296360  50.55  50.554720
#
# [484 rows x 7 columns]

# %%
#create figure
plt.figure(figsize=(15,10))
df1=df#[-100:]
#define width of candlestick elements
width = 1.3
width2 = 0.2

#define up and down prices
up = df1[df1.close>=df1.open]
down = df1[df1.close<df1.open]

#define colors to use
col1 = 'green'
col2 = 'red'

#plot up prices
plt.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
plt.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
plt.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

#plot down prices
plt.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
plt.bar(down.index,down.high-down.close,width2,bottom=down.close,color=col2)
plt.bar(down.index,down.low-down.open,width2,bottom=down.open,color=col2)

#
plt.plot(np.array(df1.index),df1.trend.values,label='trend')

#rotate x-axis tick labels
plt.xticks(rotation=45, ha='right')

#display candlestick chart
plt.title('Runner Auto')
plt.xlabel('Dates')
plt.ylabel('Price BDT')
plt.axhline(70, color='k', linestyle='--', alpha=0.2,label='Valuation')
plt.legend( fontsize=16)
plt.show()
