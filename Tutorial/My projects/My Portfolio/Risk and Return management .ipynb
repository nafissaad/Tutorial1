# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from bdshare import get_basic_hist_data

# %%
df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Port_folio_draft.xlsx", index_col='Unnamed: 0')
df
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# RAKCERAMIC                  RAK Ceramics (Bangladesh) Limited
# SALAMCRST                     S. Alam Cold Rolled Steels Ltd.
# POWERGRID               Power Grid Company of Bangladesh Ltd.
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# MARICO                              Marico Bangladesh Limited
# SINGERBD                                Singer Bangladesh Ltd
# LINDEBD                                  Linde Bangladesh Ltd
# SUMITPOWER                                   Summit Power Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# SAPORTL                              Summit Alliance Port Ltd
# BSCCL                         Bangladesh Submarine Cables PLC
# GP                                           Grameenphone Ltd
# SQUARETEXT                                 Square Textile Ltd
# HEIDELBCEM                   Heidelberg Cement Bangladesh Ltd
# OLYMPIC                        Olympic Industries Ltd OLYMPIC
# BSRMSTEEL                                     BSRM Steels Ltd
# BEXIMCO                                           BEXIMCO Ltd
# NATLIFEINS                     National Life Insurance Co Ltd
# HFL                                         Hamid Fabrics Ltd
# BATASHOE                        Bata Shoe Co (Bangladesh) Ltd
#  APEXSPINN                 Apex Spinning & Knitting Mills Ltd
# UPGDCL         United Power Generation & Distribution Co. Ltd
# DELTALIFE                      Green Delta Insurance Co. Ltd.
# CROWNCEMNT                                   Crown Cement PLC
# BENGALWTL                  Bengal Windsor Thermoplastics Ltd.
# EHL                                      Eastern Housing Ltd.
# IBNSINA                  IBN SINA Pharmaceutical Industry PLC
# WALTONHIL                      Walton Hi-Tech Industries Ltd.
# UNIQUEHRL                         Unique Hotel & Resorts Ltd.
# UNILEVERCL                        Unilever Consumer Care Ltd.
# KDSALTD                                  KDS Accessories Ltd.
# JHRML               JMI Hospital Requisite Manufacturing Ltd.
# ADNTEL                                 Adn Telecom Ltd (ADNT)
# ITC                                       IT Consultants Ltd.
# SIMTEX                                 Simtex Industries Ltd.
# APEXFOOT                                   Apex Footwear Ltd.
# APEXFOODS                                     Apex Foods Ltd.
# FORTUNE                                    Fortune Shoes Ltd.
# INDEXAGRO                          Index Agro Industries Ltd.
# AMANFEED                                       Aman Feed Ltd.
# SKICL                     Sena Kalyan Insurance Co Ltd (SENA)
# ACI                                                  ACI Ltd.
# ACIFORMULA                              ACI Formulations Ltd.
# EXIMBANK                     Export Import Bank of Bangladesh
# IFILISLMF1                         IFIL Islamic Mutual Fund-1
# AIBL1STIMF                       AIBL 1st Islamic Mutual Fund
# EXIM1STMF                           EXIM Bank 1st Mutual Fund
# RECKITTBEN                           Reckitt & Benckiser Ltd.
# JMISMDL                   JMI Syringes & Medical Devices Ltd.
# BPML                             Bashundhara Paper Mills Ltd.
#
#                                  Sector Evaluation
# ISLAMIBANK                         Bank          G
# RAKCERAMIC                      Ceramic          M
# SALAMCRST                   Engineering          P
# POWERGRID                  Fuel & Power          P
# BATBC                     FOOD & Allied          G
# RENATA      Pharmaceuticals & Chemicals          G
# MARICO      Pharmaceuticals & Chemicals          M
# SINGERBD                    Engineering          M
# LINDEBD                    Fuel & Power          G
# SUMITPOWER                 Fuel & Power          M
# BERGERPBL                 Miscellaneous          G
# BXPHARMA    Pharmaceuticals & Chemicals          G
# SQURPHARMA  Pharmaceuticals & Chemicals          G
# SAPORTL          Services & Real Estate          M
# BSCCL                 Telecommunication          M
# GP                    Telecommunication          G
# SQUARETEXT                      Textile          M
# HEIDELBCEM                       Cement          P
# OLYMPIC                   FOOD & Allied          G
# BSRMSTEEL                  Iron & Steel          P
# BEXIMCO                   Miscellaneous          M
# NATLIFEINS                    Insurance          P
# HFL                             Textile          M
# BATASHOE             Tannery Industries          P
#  APEXSPINN                      Textile          P
# UPGDCL                     Fuel & Power          G
# DELTALIFE                     Insurance          G
# CROWNCEMNT                       Cement          P
# BENGALWTL                   Engineering          M
# EHL              Services & Real Estate          M
# IBNSINA     Pharmaceuticals & Chemicals          G
# WALTONHIL                   Engineering          G
# UNIQUEHRL            Travel and Leisure          G
# UNILEVERCL                FOOD & Allied          M
# KDSALTD                     Engineering          M
# JHRML       Pharmaceuticals & Chemicals          M
# ADNTEL                        IT Sector          G
# ITC                           IT Sector          G
# SIMTEX                          Textile          M
# APEXFOOT             Tannery Industries          P
# APEXFOODS                 FOOD & Allied          G
# FORTUNE              Tannery Industries          G
# INDEXAGRO                 Miscellaneous          M
# AMANFEED                  Miscellaneous          G
# SKICL                         Insurance          G
# ACI         Pharmaceuticals & Chemicals          G
# ACIFORMULA  Pharmaceuticals & Chemicals          M
# EXIMBANK                           Bank          M
# IFILISLMF1                  Mutual Fund          G
# AIBL1STIMF                  Mutual Fund          G
# EXIM1STMF                   Mutual Fund          M
# RECKITTBEN  Pharmaceuticals & Chemicals          G
# JMISMDL     Pharmaceuticals & Chemicals          G
# BPML                   Paper & Printing          P

# %%
df[df['Evaluation']=='P']
# Out:
#                                         Full Name              Sector  \
# SALAMCRST         S. Alam Cold Rolled Steels Ltd.         Engineering
# POWERGRID   Power Grid Company of Bangladesh Ltd.        Fuel & Power
# HEIDELBCEM       Heidelberg Cement Bangladesh Ltd              Cement
# BSRMSTEEL                         BSRM Steels Ltd        Iron & Steel
# NATLIFEINS         National Life Insurance Co Ltd           Insurance
# BATASHOE            Bata Shoe Co (Bangladesh) Ltd  Tannery Industries
#  APEXSPINN     Apex Spinning & Knitting Mills Ltd             Textile
# CROWNCEMNT                       Crown Cement PLC              Cement
# APEXFOOT                       Apex Footwear Ltd.  Tannery Industries
# BPML                 Bashundhara Paper Mills Ltd.    Paper & Printing
#
#            Evaluation
# SALAMCRST           P
# POWERGRID           P
# HEIDELBCEM          P
# BSRMSTEEL           P
# NATLIFEINS          P
# BATASHOE            P
#  APEXSPINN          P
# CROWNCEMNT          P
# APEXFOOT            P
# BPML                P

# %%
df=df[~(df['Evaluation']=='P')]
df
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# RAKCERAMIC                  RAK Ceramics (Bangladesh) Limited
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# MARICO                              Marico Bangladesh Limited
# SINGERBD                                Singer Bangladesh Ltd
# LINDEBD                                  Linde Bangladesh Ltd
# SUMITPOWER                                   Summit Power Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# SAPORTL                              Summit Alliance Port Ltd
# BSCCL                         Bangladesh Submarine Cables PLC
# GP                                           Grameenphone Ltd
# SQUARETEXT                                 Square Textile Ltd
# OLYMPIC                        Olympic Industries Ltd OLYMPIC
# BEXIMCO                                           BEXIMCO Ltd
# HFL                                         Hamid Fabrics Ltd
# UPGDCL         United Power Generation & Distribution Co. Ltd
# DELTALIFE                      Green Delta Insurance Co. Ltd.
# BENGALWTL                  Bengal Windsor Thermoplastics Ltd.
# EHL                                      Eastern Housing Ltd.
# IBNSINA                  IBN SINA Pharmaceutical Industry PLC
# WALTONHIL                      Walton Hi-Tech Industries Ltd.
# UNIQUEHRL                         Unique Hotel & Resorts Ltd.
# UNILEVERCL                        Unilever Consumer Care Ltd.
# KDSALTD                                  KDS Accessories Ltd.
# JHRML               JMI Hospital Requisite Manufacturing Ltd.
# ADNTEL                                 Adn Telecom Ltd (ADNT)
# ITC                                       IT Consultants Ltd.
# SIMTEX                                 Simtex Industries Ltd.
# APEXFOODS                                     Apex Foods Ltd.
# FORTUNE                                    Fortune Shoes Ltd.
# INDEXAGRO                          Index Agro Industries Ltd.
# AMANFEED                                       Aman Feed Ltd.
# SKICL                     Sena Kalyan Insurance Co Ltd (SENA)
# ACI                                                  ACI Ltd.
# ACIFORMULA                              ACI Formulations Ltd.
# EXIMBANK                     Export Import Bank of Bangladesh
# IFILISLMF1                         IFIL Islamic Mutual Fund-1
# AIBL1STIMF                       AIBL 1st Islamic Mutual Fund
# EXIM1STMF                           EXIM Bank 1st Mutual Fund
# RECKITTBEN                           Reckitt & Benckiser Ltd.
# JMISMDL                   JMI Syringes & Medical Devices Ltd.
#
#                                  Sector Evaluation
# ISLAMIBANK                         Bank          G
# RAKCERAMIC                      Ceramic          M
# BATBC                     FOOD & Allied          G
# RENATA      Pharmaceuticals & Chemicals          G
# MARICO      Pharmaceuticals & Chemicals          M
# SINGERBD                    Engineering          M
# LINDEBD                    Fuel & Power          G
# SUMITPOWER                 Fuel & Power          M
# BERGERPBL                 Miscellaneous          G
# BXPHARMA    Pharmaceuticals & Chemicals          G
# SQURPHARMA  Pharmaceuticals & Chemicals          G
# SAPORTL          Services & Real Estate          M
# BSCCL                 Telecommunication          M
# GP                    Telecommunication          G
# SQUARETEXT                      Textile          M
# OLYMPIC                   FOOD & Allied          G
# BEXIMCO                   Miscellaneous          M
# HFL                             Textile          M
# UPGDCL                     Fuel & Power          G
# DELTALIFE                     Insurance          G
# BENGALWTL                   Engineering          M
# EHL              Services & Real Estate          M
# IBNSINA     Pharmaceuticals & Chemicals          G
# WALTONHIL                   Engineering          G
# UNIQUEHRL            Travel and Leisure          G
# UNILEVERCL                FOOD & Allied          M
# KDSALTD                     Engineering          M
# JHRML       Pharmaceuticals & Chemicals          M
# ADNTEL                        IT Sector          G
# ITC                           IT Sector          G
# SIMTEX                          Textile          M
# APEXFOODS                 FOOD & Allied          G
# FORTUNE              Tannery Industries          G
# INDEXAGRO                 Miscellaneous          M
# AMANFEED                  Miscellaneous          G
# SKICL                         Insurance          G
# ACI         Pharmaceuticals & Chemicals          G
# ACIFORMULA  Pharmaceuticals & Chemicals          M
# EXIMBANK                           Bank          M
# IFILISLMF1                  Mutual Fund          G
# AIBL1STIMF                  Mutual Fund          G
# EXIM1STMF                   Mutual Fund          M
# RECKITTBEN  Pharmaceuticals & Chemicals          G
# JMISMDL     Pharmaceuticals & Chemicals          G

# %%
df[df['Evaluation']=='G']
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# LINDEBD                                  Linde Bangladesh Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# GP                                           Grameenphone Ltd
# OLYMPIC                        Olympic Industries Ltd OLYMPIC
# UPGDCL         United Power Generation & Distribution Co. Ltd
# DELTALIFE                      Green Delta Insurance Co. Ltd.
# IBNSINA                  IBN SINA Pharmaceutical Industry PLC
# WALTONHIL                      Walton Hi-Tech Industries Ltd.
# UNIQUEHRL                         Unique Hotel & Resorts Ltd.
# ADNTEL                                 Adn Telecom Ltd (ADNT)
# ITC                                       IT Consultants Ltd.
# APEXFOODS                                     Apex Foods Ltd.
# FORTUNE                                    Fortune Shoes Ltd.
# AMANFEED                                       Aman Feed Ltd.
# SKICL                     Sena Kalyan Insurance Co Ltd (SENA)
# ACI                                                  ACI Ltd.
# IFILISLMF1                         IFIL Islamic Mutual Fund-1
# AIBL1STIMF                       AIBL 1st Islamic Mutual Fund
# RECKITTBEN                           Reckitt & Benckiser Ltd.
# JMISMDL                   JMI Syringes & Medical Devices Ltd.
#
#                                  Sector Evaluation
# ISLAMIBANK                         Bank          G
# BATBC                     FOOD & Allied          G
# RENATA      Pharmaceuticals & Chemicals          G
# LINDEBD                    Fuel & Power          G
# BERGERPBL                 Miscellaneous          G
# BXPHARMA    Pharmaceuticals & Chemicals          G
# SQURPHARMA  Pharmaceuticals & Chemicals          G
# GP                    Telecommunication          G
# OLYMPIC                   FOOD & Allied          G
# UPGDCL                     Fuel & Power          G
# DELTALIFE                     Insurance          G
# IBNSINA     Pharmaceuticals & Chemicals          G
# WALTONHIL                   Engineering          G
# UNIQUEHRL            Travel and Leisure          G
# ADNTEL                        IT Sector          G
# ITC                           IT Sector          G
# APEXFOODS                 FOOD & Allied          G
# FORTUNE              Tannery Industries          G
# AMANFEED                  Miscellaneous          G
# SKICL                         Insurance          G
# ACI         Pharmaceuticals & Chemicals          G
# IFILISLMF1                  Mutual Fund          G
# AIBL1STIMF                  Mutual Fund          G
# RECKITTBEN  Pharmaceuticals & Chemicals          G
# JMISMDL     Pharmaceuticals & Chemicals          G

# %%
df[df['Evaluation']=='M']
# Out:
#                                             Full Name  \
# RAKCERAMIC          RAK Ceramics (Bangladesh) Limited
# MARICO                      Marico Bangladesh Limited
# SINGERBD                        Singer Bangladesh Ltd
# SUMITPOWER                           Summit Power Ltd
# SAPORTL                      Summit Alliance Port Ltd
# BSCCL                 Bangladesh Submarine Cables PLC
# SQUARETEXT                         Square Textile Ltd
# BEXIMCO                                   BEXIMCO Ltd
# HFL                                 Hamid Fabrics Ltd
# BENGALWTL          Bengal Windsor Thermoplastics Ltd.
# EHL                              Eastern Housing Ltd.
# UNILEVERCL                Unilever Consumer Care Ltd.
# KDSALTD                          KDS Accessories Ltd.
# JHRML       JMI Hospital Requisite Manufacturing Ltd.
# SIMTEX                         Simtex Industries Ltd.
# INDEXAGRO                  Index Agro Industries Ltd.
# ACIFORMULA                      ACI Formulations Ltd.
# EXIMBANK             Export Import Bank of Bangladesh
# EXIM1STMF                   EXIM Bank 1st Mutual Fund
#
#                                  Sector Evaluation
# RAKCERAMIC                      Ceramic          M
# MARICO      Pharmaceuticals & Chemicals          M
# SINGERBD                    Engineering          M
# SUMITPOWER                 Fuel & Power          M
# SAPORTL          Services & Real Estate          M
# BSCCL                 Telecommunication          M
# SQUARETEXT                      Textile          M
# BEXIMCO                   Miscellaneous          M
# HFL                             Textile          M
# BENGALWTL                   Engineering          M
# EHL              Services & Real Estate          M
# UNILEVERCL                FOOD & Allied          M
# KDSALTD                     Engineering          M
# JHRML       Pharmaceuticals & Chemicals          M
# SIMTEX                          Textile          M
# INDEXAGRO                 Miscellaneous          M
# ACIFORMULA  Pharmaceuticals & Chemicals          M
# EXIMBANK                           Bank          M
# EXIM1STMF                   Mutual Fund          M

# %%
df.groupby('Evaluation')['Evaluation'].agg('count').sort_values(ascending=False)
# Out:
# Evaluation
# G    25
# M    19
# Name: Evaluation, dtype: int64

# %%
df.groupby('Sector')['Sector'].agg('count').sort_values(ascending=False)
# Out:
# Sector
# Pharmaceuticals & Chemicals    10
# Engineering                     4
# FOOD & Allied                   4
# Miscellaneous                   4
# Fuel & Power                    3
# Mutual Fund                     3
# Textile                         3
# Bank                            2
# IT Sector                       2
# Insurance                       2
# Services & Real Estate          2
# Telecommunication               2
# Ceramic                         1
# Tannery Industries              1
# Travel and Leisure              1
# Name: Sector, dtype: int64

# %%
ticker=[i for i in df.index.values]
ticker
# Out:
# ['ISLAMIBANK',
#  'RAKCERAMIC',
#  'BATBC',
#  'RENATA',
#  'MARICO',
#  'SINGERBD',
#  'LINDEBD',
#  'SUMITPOWER',
#  'BERGERPBL',
#  'BXPHARMA',
#  'SQURPHARMA',
#  'SAPORTL',
#  'BSCCL',
#  'GP',
#  'SQUARETEXT',
#  'OLYMPIC',
#  'BEXIMCO',
#  'HFL',
#  'UPGDCL',
#  'DELTALIFE',
#  'BENGALWTL',
#  'EHL',
#  'IBNSINA',
#  'WALTONHIL',
#  'UNIQUEHRL',
#  'UNILEVERCL',
#  'KDSALTD',
#  'JHRML',
#  'ADNTEL',
#  'ITC',
#  'SIMTEX',
#  'APEXFOODS',
#  'FORTUNE',
#  'INDEXAGRO',
#  'AMANFEED',
#  'SKICL',
#  'ACI',
#  'ACIFORMULA',
#  'EXIMBANK',
#  'IFILISLMF1',
#  'AIBL1STIMF',
#  'EXIM1STMF',
#  'RECKITTBEN',
#  'JMISMDL']

# %%
sets=pd.DataFrame()
for i in ticker:
    print('Working on :',i)
    date='2023-06-11'
    try:
        data=get_basic_hist_data('2020-01-1',date,i,index='date')['close']
        sets[i]=data
    except:
        df=pd.read_html('https://www.dsebd.org/day_end_archive.php?startDate=2020-01-01&endDate='+date+'&inst='+i+'&archive=data')[348]
        df.index=df['DATE']
        sets[i]=df['CLOSEP*']
        print('Exception')
sets.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx")

def concat(x):
    sets=pd.DataFrame()
    for i in ticker:
        sets[i]=get_basic_hist_data(str(pd.to_datetime(x.index[-1])+timedelta(days=1))[0:10],str(datetime.today()-timedelta(days=1))[0:10],i,index='date')['close']
    return(pd.concat([x,sets],axis=0))
sets
# Out:
# Working on : ISLAMIBANK
# Working on : RAKCERAMIC
# Working on : BATBC
# Working on : RENATA
# Working on : MARICO
# Working on : SINGERBD
# Working on : LINDEBD
# Working on : SUMITPOWER
# Working on : BERGERPBL
# Working on : BXPHARMA
# Working on : SQURPHARMA
# Working on : SAPORTL
# Working on : BSCCL
# Working on : GP
# Working on : SQUARETEXT
# Working on : OLYMPIC
# Working on : BEXIMCO
# Working on : HFL
# Working on : UPGDCL
# Working on : DELTALIFE
# Working on : BENGALWTL
# Working on : EHL
# Working on : IBNSINA
# Working on : WALTONHIL
# Working on : UNIQUEHRL
# Working on : UNILEVERCL
# Working on : KDSALTD
# Working on : JHRML
# Working on : ADNTEL
# Working on : ITC
# Working on : SIMTEX
# Working on : APEXFOODS
# Working on : FORTUNE
# Working on : INDEXAGRO
# Working on : AMANFEED
# Working on : SKICL
# Working on : ACI
# Working on : ACIFORMULA
# Working on : EXIMBANK
# Working on : IFILISLMF1
# Working on : AIBL1STIMF
# Working on : EXIM1STMF
# Working on : RECKITTBEN
# Working on : JMISMDL
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
# 2021-06-14        27.5        35.2  532.9  1284.6  2117.7     180.0   1297.1
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-05        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-06        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-07        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4    NaN  262.5
# 2021-06-14        42.7     1743.1     170.8  ...      47.2    NaN  269.1
# 2021-06-15        42.6     1772.2     171.0  ...      48.1    NaN  269.7
# 2021-06-16        42.7     1775.1     170.8  ...      48.4    NaN  263.7
# 2021-06-17        44.3     1770.2     174.9  ...      48.6    NaN  263.5
# ...                ...        ...       ...  ...       ...    ...    ...
# 2023-06-05        34.0     1794.8     146.2  ...      33.5   48.5  260.2
# 2023-06-06        34.0     1795.1     146.2  ...      33.5   47.1  260.2
# 2023-06-07        34.0     1788.4     146.2  ...      33.5   49.8  260.2
# 2023-06-08        34.0     1787.4     146.2  ...      33.5   48.9  260.2
# 2023-06-11        34.0     1776.4     146.2  ...      33.5   48.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
# 2021-06-14       144.4      11.0         6.7         9.2        7.1
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
# 2021-06-16       145.0      10.8         6.7         9.2        7.1
# 2021-06-17       143.0      10.8         6.7         9.1        7.2
# ...                ...       ...         ...         ...        ...
# 2023-06-05       162.1      10.4         6.4         7.3        5.8
# 2023-06-06       159.1      10.4         6.4         7.3        5.8
# 2023-06-07       157.5      10.4         6.4         7.3        5.8
# 2023-06-08       159.7      10.4         6.4         7.3        5.8
# 2023-06-11       159.7      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
# 2021-06-14      4219.3    326.4
# 2021-06-15      4245.3    323.3
# 2021-06-16      4269.4    320.6
# 2021-06-17      4301.0    320.1
# ...                ...      ...
# 2023-06-05      4970.4    255.5
# 2023-06-06      4930.1    255.5
# 2023-06-07      4836.2    255.5
# 2023-06-08      4826.7    255.5
# 2023-06-11      4795.2    255.5
#
# [484 rows x 44 columns]

# %%
concat(sets).to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx")

# %%
sets=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
sets
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
# 2021-06-14        27.5        35.2  532.9  1284.6  2117.7     180.0   1297.1
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-06        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-07        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4    NaN  262.5
# 2021-06-14        42.7     1743.1     170.8  ...      47.2    NaN  269.1
# 2021-06-15        42.6     1772.2     171.0  ...      48.1    NaN  269.7
# 2021-06-16        42.7     1775.1     170.8  ...      48.4    NaN  263.7
# 2021-06-17        44.3     1770.2     174.9  ...      48.6    NaN  263.5
# ...                ...        ...       ...  ...       ...    ...    ...
# 2023-06-06        34.0     1795.1     146.2  ...      33.5   47.1  260.2
# 2023-06-07        34.0     1788.4     146.2  ...      33.5   49.8  260.2
# 2023-06-08        34.0     1787.4     146.2  ...      33.5   48.9  260.2
# 2023-06-11        34.0     1776.4     146.2  ...      33.5   48.7  260.2
# 2023-06-12        34.0     1767.9     146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
# 2021-06-14       144.4      11.0         6.7         9.2        7.1
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
# 2021-06-16       145.0      10.8         6.7         9.2        7.1
# 2021-06-17       143.0      10.8         6.7         9.1        7.2
# ...                ...       ...         ...         ...        ...
# 2023-06-06       159.1      10.4         6.4         7.3        5.8
# 2023-06-07       157.5      10.4         6.4         7.3        5.8
# 2023-06-08       159.7      10.4         6.4         7.3        5.8
# 2023-06-11       159.7      10.4         6.4         7.3        5.8
# 2023-06-12       157.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
# 2021-06-14      4219.3    326.4
# 2021-06-15      4245.3    323.3
# 2021-06-16      4269.4    320.6
# 2021-06-17      4301.0    320.1
# ...                ...      ...
# 2023-06-06      4930.1    255.5
# 2023-06-07      4836.2    255.5
# 2023-06-08      4826.7    255.5
# 2023-06-11      4795.2    255.5
# 2023-06-12      4802.2    255.5
#
# [485 rows x 44 columns]

# %%
sets.index[31]
# Out:
# '2021-08-05'

# %%
sets.loc[sets.index[31],'ISLAMIBANK']
# Out:
# 29.0

# %%
sets.index[49]
# Out:
# '2021-09-05'

# %%
sets.loc[sets.index[49],'ISLAMIBANK']
# Out:
# 29.7

# %%
sets.index=pd.to_datetime(sets.index)
sets.resample('1M').last()
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06
146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-30       148.2      11.6         6.8         9.1        7.9
# 2021-07-31       154.1      12.0         7.3         9.7        9.4
# 2021-08-31       172.9      13.0         7.0         9.0        8.2
# 2021-09-30       170.9      12.7         6.7         8.9        7.0
# 2021-10-31       163.7      12.8         6.6         8.8        6.8
# 2021-11-30       148.5      13.0         6.4         8.5        6.6
# 2021-12-31       147.1      12.7         6.4         8.5        6.2
# 2022-01-31       177.2      12.7         7.0         8.7        6.1
# 2022-02-28       163.9      12.1         6.7         8.4        5.9
# 2022-03-31       169.5      12.5         6.8         8.6        6.1
# 2022-04-30       166.2      12.3         6.6         8.6        6.2
# 2022-05-31       166.6      11.5         6.6         9.2        6.0
# 2022-06-30       158.1      10.9         6.5         7.9        6.0
# 2022-07-31       155.3      10.6         6.4         7.3        6.0
# 2022-08-31       171.5      10.8         6.6         7.3        6.1
# 2022-09-30       171.1      10.5         6.4         7.3        5.8
# 2022-10-31       155.0      10.4         6.4         7.3        5.8
# 2022-11-30       155.0      10.4         6.4         7.3        5.8
# 2022-12-31       155.0      10.4         6.4         7.4        5.8
# 2023-01-31       155.0      10.4         7.0         7.7        5.8
# 2023-02-28       155.0      10.4         7.0         7.7        5.8
# 2023-03-31       155.0      10.4         6.4         7.3        5.8
# 2023-04-30       158.1      10.8         6.4         7.3        5.8
# 2023-05-31       156.9      10.4         6.4         7.3        5.8
# 2023-06-30       157.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-30      4356.3    331.1
# 2021-07-31      4526.4    356.5
# 2021-08-31      4475.1    375.3
# 2021-09-30      4837.2    396.5
# 2021-10-31      5038.7    334.2
# 2021-11-30      4892.4    316.0
# 2021-12-31      5729.9    333.7
# 2022-01-31      5840.1    336.9
# 2022-02-28      5853.3    342.6
# 2022-03-31      5388.4    345.6
# 2022-04-30      4871.3    323.3
# 2022-05-31      4695.9    305.1
# 2022-06-30      4868.5    312.3
# 2022-07-31      4796.1    299.0
# 2022-08-31      4892.2    344.6
# 2022-09-30      4830.9    392.4
# 2022-10-31      4760.7    347.5
# 2022-11-30      4760.7    255.5
# 2022-12-31      4760.7    255.5
# 2023-01-31      4760.7    255.5
# 2023-02-28      4760.7    255.5
# 2023-03-31      4760.7    255.5
# 2023-04-30      4777.9    255.5
# 2023-05-31      4772.2    255.5
# 2023-06-30      4802.2    255.5
#
# [25 rows x 44 columns]

# %%
simple_return=sets['ISLAMIBANK'].pct_change()
log_return=np.log(sets['ISLAMIBANK']/sets['ISLAMIBANK'].shift(1)).dropna()
simple_return.describe(),log_return.describe()
# Out:
# (count    484.000000
#  mean       0.000383
#  std        0.008937
#  min       -0.048851
#  25%       -0.003030
#  50%        0.000000
#  75%        0.003040
#  max        0.089109
#  Name: ISLAMIBANK, dtype: float64,
#  count    484.000000
#  mean       0.000344
#  std        0.008835
#  min       -0.050084
#  25%       -0.003035
#  50%        0.000000
#  75%        0.003035
#  max        0.085360
#  Name: ISLAMIBANK, dtype: float64)

# %%
log_return.mean()*22
# Out:
# 0.007568023438616304

# %%
135.9*(1+(log_return.mean()*22))**(len(sets)/22)
# Out:
# 160.4739587605743

# %%
135.9*(1+simple_return.mean()*22)**(len(sets)/22)
# Out:
# 163.5374594306889

# %%
sets['ISLAMIBANK'].std()/sets['ISLAMIBANK'].mean()
# Out:
# 0.04510840161211843

# %%
stats=pd.DataFrame(columns=[sets.columns],index=['Log Return','Rsquared','Return Standard Deviation','COV'])
for i in ticker:
    print('Working on :',i)
    stats.loc['Log Return',i]=np.log(sets[i]/sets[i].shift(1)).dropna().mean()*22
    stats.loc['Return Standard Deviation',i]=np.log(sets[i]/sets[i].shift(1)).dropna().std()*22
    stats.loc['COV',i]=(sets[i].std()/sets[i].mean())
stats=stats.T
stats
# Out:
# Working on : ISLAMIBANK
# Working on : RAKCERAMIC
# Working on : BATBC
# Working on : RENATA
# Working on : MARICO
# Working on : SINGERBD
# Working on : LINDEBD
# Working on : SUMITPOWER
# Working on : BERGERPBL
# Working on : BXPHARMA
# Working on : SQURPHARMA
# Working on : SAPORTL
# Working on : BSCCL
# Working on : GP
# Working on : SQUARETEXT
# Working on : OLYMPIC
# Working on : BEXIMCO
# Working on : HFL
# Working on : UPGDCL
# Working on : DELTALIFE
# Working on : BENGALWTL
# Working on : EHL
# Working on : IBNSINA
# Working on : WALTONHIL
# Working on : UNIQUEHRL
# Working on : UNILEVERCL
# Working on : KDSALTD
# Working on : JHRML
# Working on : ADNTEL
# Working on : ITC
# Working on : SIMTEX
# Working on : APEXFOODS
# Working on : FORTUNE
# Working on : INDEXAGRO
# Working on : AMANFEED
# Working on : SKICL
# Working on : ACI
# Working on : ACIFORMULA
# Working on : EXIMBANK
# Working on : IFILISLMF1
# Working on : AIBL1STIMF
# Working on : EXIM1STMF
# Working on : RECKITTBEN
# Working on : JMISMDL
#            Log Return Rsquared Return Standard Deviation       COV
# ISLAMIBANK   0.007568      NaN                  0.194371  0.045108
# RAKCERAMIC   0.007219      NaN                   0.42887  0.087959
# BATBC       -0.001338      NaN                  0.210377   0.09843
# RENATA      -0.002356      NaN                   0.15179  0.055562
# MARICO       0.005903      NaN                  0.106603  0.026533
# SINGERBD    -0.008242      NaN                  0.172103  0.080145
# LINDEBD      0.003203      NaN                  0.277859  0.083557
# SUMITPOWER  -0.009928      NaN                  0.224223   0.11561
# BERGERPBL    0.000476      NaN                  0.187333  0.021309
# BXPHARMA    -0.007572      NaN                  0.360032  0.159254
# SQURPHARMA  -0.001007      NaN                  0.151542  0.040703
# SAPORTL     -0.000474      NaN                  0.590145  0.089796
# BSCCL        0.011252      NaN                  0.350737  0.073623
# GP           -0.00942      NaN                  0.161302  0.106754
# SQUARETEXT   0.021566      NaN                  0.358928  0.127324
# OLYMPIC     -0.005491      NaN                  0.422453  0.150753
# BEXIMCO      0.008398      NaN                  0.398966  0.155317
# HFL         -0.000514      NaN                  0.727168  0.152529
# UPGDCL      -0.007496      NaN                  0.181491  0.083841
# DELTALIFE    0.015871      NaN                   0.61022  0.164866
# BENGALWTL     0.01431      NaN                  0.634367  0.165432
# EHL          0.033409      NaN                  0.786076  0.323844
# IBNSINA      0.007054      NaN                  0.266287  0.052157
# WALTONHIL   -0.011852      NaN                   0.21134  0.098561
# UNIQUEHRL    0.032096      NaN                   0.61972  0.163776
# UNILEVERCL  -0.013014      NaN                  0.558064  0.097243
# KDSALTD      0.021199      NaN                  0.506999   0.16704
# JHRML        0.095528      NaN                  0.914519  0.214476
# ADNTEL       0.040342      NaN                  0.700173  0.388219
# ITC            0.0036      NaN                  0.520299   0.08938
# SIMTEX       0.007117      NaN                  0.586265  0.139879
# APEXFOODS    0.056296      NaN                  0.792159  0.350495
# FORTUNE      0.025603      NaN                  0.522619  0.248385
# INDEXAGRO   -0.002972      NaN                  0.581116  0.094084
# AMANFEED    -0.017655      NaN                  0.532703   0.28831
# SKICL        0.082544      NaN                  0.755212  0.211054
# ACI           -0.0004      NaN                  0.271898  0.067006
# ACIFORMULA   0.005614      NaN                  0.440637    0.0615
# EXIMBANK    -0.002134      NaN                  0.230765   0.09246
# IFILISLMF1  -0.002756      NaN                  0.312217  0.040239
# AIBL1STIMF  -0.011493      NaN                    0.1944  0.094203
# EXIM1STMF   -0.011074      NaN                  0.357193  0.138868
# RECKITTBEN    0.00587      NaN                  0.220072  0.078296
# JMISMDL      -0.01102      NaN                  0.553236  0.161363

# %%
pct_change=pd.DataFrame()
for i in sets.columns:
    pct_change[i]=sets[i].pct_change(5)
pct_change=pct_change.fillna(0)

# %%
import statsmodels.api as sm
def VIF_score(df):
    VIF_score=[]
    ticker=[]
    for i in df.columns:
        model=sm.OLS(df[i],sm.add_constant(df.loc[:, df.columns!=i]),hasconst=True)
        results=model.fit()
        VIF_score.append(results.rsquared)
        ticker.append(i)
    return(VIF_score,ticker)

# %%
for i in pct_change.columns:
    print(i)
# Out:
# ISLAMIBANK
# RAKCERAMIC
# BATBC
# RENATA
# MARICO
# SINGERBD
# LINDEBD
# SUMITPOWER
# BERGERPBL
# BXPHARMA
# SQURPHARMA
# SAPORTL
# BSCCL
# GP
# SQUARETEXT
# OLYMPIC
# BEXIMCO
# HFL
# UPGDCL
# DELTALIFE
# BENGALWTL
# EHL
# IBNSINA
# WALTONHIL
# UNIQUEHRL
# UNILEVERCL
# KDSALTD
# JHRML
# ADNTEL
# ITC
# SIMTEX
# APEXFOODS
# FORTUNE
# INDEXAGRO
# AMANFEED
# SKICL
# ACI
# ACIFORMULA
# EXIMBANK
# IFILISLMF1
# AIBL1STIMF
# EXIM1STMF
# RECKITTBEN
# JMISMDL

# %%
stats['Rsquared']=VIF_score(pct_change)[0]

# %%
stats.sort_values('Rsquared', axis=0, ascending=False)
# Out:
#            Log Return  Rsquared Return Standard Deviation       COV
# UPGDCL      -0.007496  0.714673                  0.181491  0.083841
# LINDEBD      0.003203  0.696680                  0.277859  0.083557
# SQURPHARMA  -0.001007  0.655809                  0.151542  0.040703
# EXIM1STMF   -0.011074  0.636367                  0.357193  0.138868
# BXPHARMA    -0.007572  0.622946                  0.360032  0.159254
# EHL          0.033409  0.606217                  0.786076  0.323844
# SINGERBD    -0.008242  0.592979                  0.172103  0.080145
# RECKITTBEN    0.00587  0.587926                  0.220072  0.078296
# BATBC       -0.001338  0.587090                  0.210377   0.09843
# WALTONHIL   -0.011852  0.583650                   0.21134  0.098561
# UNIQUEHRL    0.032096  0.582732                   0.61972  0.163776
# SUMITPOWER  -0.009928  0.574706                  0.224223   0.11561
# BEXIMCO      0.008398  0.572418                  0.398966  0.155317
# ACI           -0.0004  0.562442                  0.271898  0.067006
# GP           -0.00942  0.548364                  0.161302  0.106754
# MARICO       0.005903  0.544411                  0.106603  0.026533
# BSCCL        0.011252  0.540121                  0.350737  0.073623
# HFL         -0.000514  0.535280                  0.727168  0.152529
# AMANFEED    -0.017655  0.508821                  0.532703   0.28831
# EXIMBANK    -0.002134  0.502508                  0.230765   0.09246
# ACIFORMULA   0.005614  0.502304                  0.440637    0.0615
# ITC            0.0036  0.499357                  0.520299   0.08938
# JMISMDL      -0.01102  0.484316                  0.553236  0.161363
# SQUARETEXT   0.021566  0.483753                  0.358928  0.127324
# APEXFOODS    0.056296  0.475714                  0.792159  0.350495
# SAPORTL     -0.000474  0.475582                  0.590145  0.089796
# SIMTEX       0.007117  0.475425                  0.586265  0.139879
# IFILISLMF1  -0.002756  0.473414                  0.312217  0.040239
# BENGALWTL     0.01431  0.472265                  0.634367  0.165432
# IBNSINA      0.007054  0.469801                  0.266287  0.052157
# BERGERPBL    0.000476  0.452442                  0.187333  0.021309
# ISLAMIBANK   0.007568  0.439154                  0.194371  0.045108
# RENATA      -0.002356  0.436258                   0.15179  0.055562
# KDSALTD      0.021199  0.430385                  0.506999   0.16704
# AIBL1STIMF  -0.011493  0.424954                    0.1944  0.094203
# OLYMPIC     -0.005491  0.422515                  0.422453  0.150753
# INDEXAGRO   -0.002972  0.419235                  0.581116  0.094084
# RAKCERAMIC   0.007219  0.418807                   0.42887  0.087959
# FORTUNE      0.025603  0.390807                  0.522619  0.248385
# ADNTEL       0.040342  0.384974                  0.700173  0.388219
# DELTALIFE    0.015871  0.364435                   0.61022  0.164866
# SKICL        0.082544  0.338569                  0.755212  0.211054
# JHRML        0.095528  0.330577                  0.914519  0.214476
# UNILEVERCL  -0.013014  0.258793                  0.558064  0.097243

# %%
plt.scatter(pct_change['UPGDCL'],pct_change['BXPHARMA'])

# %%
stats.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Statistics.xlsx")

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).cumsum().plot(figsize=(12.2,6.4),legend=False)

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).mean()
# Out:
# ISLAMIBANK    0.000344
# RAKCERAMIC    0.000328
# BATBC        -0.000061
# RENATA       -0.000107
# MARICO        0.000268
# SINGERBD     -0.000375
# LINDEBD       0.000146
# SUMITPOWER   -0.000451
# BERGERPBL     0.000022
# BXPHARMA     -0.000344
# SQURPHARMA   -0.000046
# SAPORTL      -0.000022
# BSCCL         0.000511
# GP           -0.000428
# SQUARETEXT    0.000980
# OLYMPIC      -0.000250
# BEXIMCO       0.000382
# HFL          -0.000023
# UPGDCL       -0.000341
# DELTALIFE     0.000721
# BENGALWTL     0.000650
# EHL           0.001519
# IBNSINA       0.000321
# WALTONHIL    -0.000539
# UNIQUEHRL     0.001459
# UNILEVERCL   -0.000592
# KDSALTD       0.000964
# JHRML         0.004342
# ADNTEL        0.001834
# ITC           0.000164
# SIMTEX        0.000323
# APEXFOODS     0.002559
# FORTUNE       0.001164
# INDEXAGRO    -0.000135
# AMANFEED     -0.000802
# SKICL         0.003752
# ACI          -0.000018
# ACIFORMULA    0.000255
# EXIMBANK     -0.000097
# IFILISLMF1   -0.000125
# AIBL1STIMF   -0.000522
# EXIM1STMF    -0.000503
# RECKITTBEN    0.000267
# JMISMDL      -0.000501
# dtype: float64

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).std()
# Out:
# ISLAMIBANK    0.008835
# RAKCERAMIC    0.019494
# BATBC         0.009563
# RENATA        0.006900
# MARICO        0.004846
# SINGERBD      0.007823
# LINDEBD       0.012630
# SUMITPOWER    0.010192
# BERGERPBL     0.008515
# BXPHARMA      0.016365
# SQURPHARMA    0.006888
# SAPORTL       0.026825
# BSCCL         0.015943
# GP            0.007332
# SQUARETEXT    0.016315
# OLYMPIC       0.019202
# BEXIMCO       0.018135
# HFL           0.033053
# UPGDCL        0.008250
# DELTALIFE     0.027737
# BENGALWTL     0.028835
# EHL           0.035731
# IBNSINA       0.012104
# WALTONHIL     0.009606
# UNIQUEHRL     0.028169
# UNILEVERCL    0.025367
# KDSALTD       0.023045
# JHRML         0.041569
# ADNTEL        0.031826
# ITC           0.023650
# SIMTEX        0.026648
# APEXFOODS     0.036007
# FORTUNE       0.023755
# INDEXAGRO     0.026414
# AMANFEED      0.024214
# SKICL         0.034328
# ACI           0.012359
# ACIFORMULA    0.020029
# EXIMBANK      0.010489
# IFILISLMF1    0.014192
# AIBL1STIMF    0.008836
# EXIM1STMF     0.016236
# RECKITTBEN    0.010003
# JMISMDL       0.025147
# dtype: float64

# %%
plt.figure(figsize = (30,30))
pic=plt.imread("Modern portfolio theory.png")
plt.imshow(pic)
plt.axis('off')
plt.show()

# %%
# vector is weights
W=np.array([1/len(sets.columns) for i in range(len(sets.columns))])#creating equal weighted portfolio
W
# Out:
# array([0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727])

# %%
portfolio_ret=np.log(sets[sets.columns]/sets[sets.columns].shift(1))

# %%
portfolio_ret.mean()
# Out:
# ISLAMIBANK    0.000344
# RAKCERAMIC    0.000328
# BATBC        -0.000061
# RENATA       -0.000107
# MARICO        0.000268
# SINGERBD     -0.000375
# LINDEBD       0.000146
# SUMITPOWER   -0.000451
# BERGERPBL     0.000022
# BXPHARMA     -0.000344
# SQURPHARMA   -0.000046
# SAPORTL      -0.000022
# BSCCL         0.000511
# GP           -0.000428
# SQUARETEXT    0.000980
# OLYMPIC      -0.000250
# BEXIMCO       0.000382
# HFL          -0.000023
# UPGDCL       -0.000341
# DELTALIFE     0.000721
# BENGALWTL     0.000650
# EHL           0.001519
# IBNSINA       0.000321
# WALTONHIL    -0.000539
# UNIQUEHRL     0.001459
# UNILEVERCL   -0.000592
# KDSALTD       0.000964
# JHRML         0.004342
# ADNTEL        0.001834
# ITC           0.000164
# SIMTEX        0.000323
# APEXFOODS     0.002559
# FORTUNE       0.001164
# INDEXAGRO    -0.000135
# AMANFEED     -0.000802
# SKICL         0.003752
# ACI          -0.000018
# ACIFORMULA    0.000255
# EXIMBANK     -0.000097
# IFILISLMF1   -0.000125
# AIBL1STIMF   -0.000522
# EXIM1STMF    -0.000503
# RECKITTBEN    0.000267
# JMISMDL      -0.000501
# dtype: float64

# %%
0.000336*0.02702703
# Out:
# 9.08108208e-06

# %%
(W*portfolio_ret.mean()).sum()*252
# Out:
# 0.09731891152993642

# %%
portfolio_ret.mean().dot(W)*252
# Out:
# 0.09731891152993645

# %%
W.dot(portfolio_ret.mean())
# Out:
# 0.0003861861568648272

# %%
len(portfolio_ret.mean())
# Out:
# 44

# %%
portfolio_ret.cov()
# Out:
#               ISLAMIBANK    RAKCERAMIC     BATBC        RENATA        MARICO  \
# ISLAMIBANK  7.805826e-05  4.989895e-07  0.000005 -1.294735e-05  3.792155e-06
# RAKCERAMIC  4.989895e-07  3.800195e-04  0.000040  9.679345e-06  1.456142e-05
# BATBC       4.728819e-06  4.010720e-05  0.000091  1.206768e-05  1.012173e-05
# RENATA     -1.294735e-05  9.679345e-06  0.000012  4.760391e-05  5.986992e-06
# MARICO      3.792155e-06  1.456142e-05  0.000010  5.986992e-06  2.347994e-05
# SINGERBD    5.732665e-06  1.458033e-05  0.000015  5.446830e-06  8.429608e-06
# LINDEBD     8.617217e-06  5.147335e-05  0.000036  7.826623e-06  9.346629e-06
# SUMITPOWER  2.928935e-06  4.802171e-05  0.000029  1.721937e-05  7.649270e-06
# BERGERPBL   4.632521e-07  5.982446e-06  0.000012  9.355519e-06  1.229689e-05
# BXPHARMA    1.338297e-05  7.183097e-05  0.000040  1.364492e-05  8.900027e-06
# SQURPHARMA  9.450282e-06  3.166302e-05  0.000022  3.456712e-06  7.001908e-06
# SAPORTL     1.697408e-05  1.557734e-04  0.000027  8.343905e-06  7.929481e-06
# BSCCL       4.855913e-06  8.084189e-05  0.000039  1.391124e-05  1.165952e-05
# GP          2.619234e-06  2.716293e-05  0.000019  4.048466e-06  8.421107e-06
# SQUARETEXT  1.897337e-05  9.880490e-05  0.000035  2.862448e-06  5.143500e-06
# OLYMPIC     8.572818e-06  6.006698e-05  0.000032  1.058722e-05  7.287763e-06
# BEXIMCO     4.176789e-06  7.195371e-05  0.000029  1.512058e-05  8.325498e-06
# HFL         8.163335e-06  1.113453e-04 -0.000001  7.726501e-06  2.014019e-06
# UPGDCL      7.364851e-06  4.379433e-05  0.000019  9.487586e-06  7.499057e-06
# DELTALIFE   1.925145e-05  6.077780e-05  0.000042  1.523540e-05  2.385321e-05
# BENGALWTL   1.162922e-05  8.091603e-05  0.000039  1.284426e-05  1.506646e-05
# EHL         3.220714e-06  1.557506e-04  0.000045  2.674919e-05  8.030420e-06
# IBNSINA     1.277797e-05  4.400501e-05  0.000010  4.582396e-06  4.907884e-06
# WALTONHIL   6.009372e-07  4.076382e-05  0.000031  1.242738e-05  1.648244e-05
# UNIQUEHRL  -2.279875e-06  1.334309e-04  0.000031  2.314765e-05  5.365403e-06
# UNILEVERCL  4.016353e-06  2.631567e-05  0.000024  8.441285e-06  1.263380e-05
# KDSALTD     1.166352e-05  1.449817e-04  0.000040 -5.368735e-06  5.047768e-06
# AIBL1STIMF    0.000032  7.808159e-05  5.985671e-05  5.415112e-07  0.000006
# EXIM1STMF     0.000067  5.985671e-05  2.636095e-04  1.381475e-05  0.000036
# RECKITTBEN    0.000007  5.415112e-07  1.381475e-05  1.000650e-04  0.000017
# JMISMDL       0.000009  6.163228e-06  3.570228e-05  1.674452e-05  0.000632
#
# [44 rows x 44 columns]

# %%
(W.T.dot((portfolio_ret.cov()*252).dot(W)))**(1/2)
# Out:
# 0.12192435266829821

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).std()
# Out:
# ISLAMIBANK    0.008835
# RAKCERAMIC    0.019494
# BATBC         0.009563
# RENATA        0.006900
# MARICO        0.004846
# SINGERBD      0.007823
# LINDEBD       0.012630
# SUMITPOWER    0.010192
# BERGERPBL     0.008515
# BXPHARMA      0.016365
# SQURPHARMA    0.006888
# SAPORTL       0.026825
# BSCCL         0.015943
# GP            0.007332
# SQUARETEXT    0.016315
# OLYMPIC       0.019202
# BEXIMCO       0.018135
# HFL           0.033053
# UPGDCL        0.008250
# DELTALIFE     0.027737
# BENGALWTL     0.028835
# EHL           0.035731
# IBNSINA       0.012104
# WALTONHIL     0.009606
# UNIQUEHRL     0.028169
# UNILEVERCL    0.025367
# KDSALTD       0.023045
# JHRML         0.041569
# ADNTEL        0.031826
# ITC           0.023650
# SIMTEX        0.026648
# APEXFOODS     0.036007
# FORTUNE       0.023755
# INDEXAGRO     0.026414
# AMANFEED      0.024214
# SKICL         0.034328
# ACI           0.012359
# ACIFORMULA    0.020029
# EXIMBANK      0.010489
# IFILISLMF1    0.014192
# AIBL1STIMF    0.008836
# EXIM1STMF     0.016236
# RECKITTBEN    0.010003
# JMISMDL       0.025147
# dtype: float64

# %%
def sharpe_pf(W,portfolio_ret):
    pf_risk=(W.T.dot(portfolio_ret.cov().dot(W)))**(1/2)
    SR=W.dot(portfolio_ret.mean())/pf_risk
    return(SR)

# %%
sharpe_pf(W,portfolio_ret)
# Out:
# 0.050281301896423186

# %%
weights=np.random.random(len(sets.columns))
weights/=np.sum(weights)

# %%
weights[2]
# Out:
# 0.04272335023016248

# %%
len(weights)
# Out:
# 44

# %%
weights.sum()
# Out:
# 0.9999999999999999

# %%
returns=np.log(sets[sets.columns]/sets[sets.columns].shift(1))
mean_ret=portfolio_ret.mean()*252
mean_ret
# Out:
# ISLAMIBANK    0.086688
# RAKCERAMIC    0.082693
# BATBC        -0.015331
# RENATA       -0.026991
# MARICO        0.067614
# SINGERBD     -0.094413
# LINDEBD       0.036689
# SUMITPOWER   -0.113726
# BERGERPBL     0.005447
# BXPHARMA     -0.086732
# SQURPHARMA   -0.011535
# SAPORTL      -0.005433
# BSCCL         0.128883
# GP           -0.107905
# SQUARETEXT    0.247032
# OLYMPIC      -0.062892
# BEXIMCO       0.096190
# HFL          -0.005883
# UPGDCL       -0.085863
# DELTALIFE     0.181796
# BENGALWTL     0.163910
# EHL           0.382683
# IBNSINA       0.080806
# WALTONHIL    -0.135757
# UNIQUEHRL     0.367642
# UNILEVERCL   -0.149073
# KDSALTD       0.242823
# JHRML         1.094232
# ACIFORMULA   0.005170    0.006190  0.032126
# EXIMBANK     0.012959    0.002531  0.001738
# IFILISLMF1   0.016964    0.001699  0.002266
# AIBL1STIMF   0.015084    0.000136  0.001553
# EXIM1STMF    0.066430    0.003481  0.008997
# RECKITTBEN   0.003481    0.025216  0.004220
# JMISMDL      0.008997    0.004220  0.159359
#
# [44 rows x 44 columns]

# %%
weights.dot(returns.mean())*252 #yearly return
# Out:
# 0.11659082853211171

# %%
np.sqrt(weights.T.dot((portfolio_ret.cov()*252).dot(weights)))#yearly risk
# Out:
# 0.12563880220007614

# %%
p_ret = []#Return list of our random portfolio
p_vol = []#Volatility list of our random portfolio
p_sr = []#sharp ration to maximize profit and minimize risk(rate of return- risk free rate)/standard deviation
p_wt = []#weights

for x in range(30000):
    p_weights=np.random.random(len(sets.columns))
    p_weights/=np.sum(p_weights)
    ret_1=p_weights.dot(returns.mean())*252
    p_ret.append(ret_1)
    vol_1 = np.sqrt(p_weights.T.dot((portfolio_ret.cov()*252).dot(p_weights)))
    p_vol.append(vol_1)
    SR_1 = (ret_1-0.06)/vol_1
    p_sr.append(SR_1)
    p_wt.append(p_weights)
p_ret = np.array(p_ret)
p_vol = np.array(p_vol)
p_SR = np.array(p_sr)
p_wt = np.array(p_wt)

    
p_ret,p_vol,p_SR,p_wt
# Out:
# (array([0.11536793, 0.0789004 , 0.09029921, ..., 0.12185867, 0.07553782,
#         0.10394753]),
#  array([0.12446012, 0.11770916, 0.12897858, ..., 0.12273775, 0.11963699,
#         0.12759316]),
#  array([0.44486481, 0.16056867, 0.2349166 , ..., 0.50399061, 0.12987469,
#         0.34443481]),
#  array([[0.02824487, 0.01628814, 0.0304759 , ..., 0.02877056, 0.00264463,
#          0.02788565],
#         [0.03293173, 0.02453828, 0.01708066, ..., 0.04324051, 0.02261219,
#          0.00353902],
#         [0.03993496, 0.01744186, 0.01544231, ..., 0.01973369, 0.01328473,
#          0.00264895],
#         ...,
#         [0.00376759, 0.01479815, 0.03043422, ..., 0.00897922, 0.0015135 ,
#          0.00767722],
#         [0.02546938, 0.01001182, 0.0382095 , ..., 0.0207027 , 0.02585509,
#          0.02535217],
#         [0.04103012, 0.00564911, 0.00734169, ..., 0.02914035, 0.01858992,
#          0.03093925]]))

# %%
ports = pd.DataFrame({'Returns' : p_ret, 'volatility' :p_vol})
ports
# Out:
#         Returns  volatility
# 0      0.115368    0.124460
# 1      0.078900    0.117709
# 2      0.090299    0.128979
# 3      0.103160    0.126298
# 4      0.069625    0.116978
# ...         ...         ...
# 29995  0.068726    0.127761
# 29996  0.089272    0.121622
# 29997  0.121859    0.122738
# 29998  0.075538    0.119637
# 29999  0.103948    0.127593
#
# [30000 rows x 2 columns]

# %%
ports.plot(x='volatility', y ='Returns', kind='scatter',figsize=(16,9))
plt.scatter(x=0.11388582770213351,y=0.10727701366332347,color="Red",marker='+')
#plt.scatter(x=0.294,y=1.1,color="Red",marker='+')
plt.show()

# %%
SR_IDX=np.argmax(p_SR)
SR_IDX
# Out:
# 26207

# %%
i=0
while i < len(sets.columns):
    print('Stock : %s : %2.2f'%(sets.columns[i],(p_wt[SR_IDX][i]*100)))
    i+=1
print('\nVolatility :',p_vol[SR_IDX])
print('Return :',p_ret[SR_IDX])
# Out:
# Stock : ISLAMIBANK : 1.91
# Stock : RAKCERAMIC : 2.33
# Stock : BATBC : 4.71
# Stock : RENATA : 2.10
# Stock : MARICO : 3.82
# Stock : SINGERBD : 1.16
# Stock : LINDEBD : 2.66
# Stock : SUMITPOWER : 0.24
# Stock : BERGERPBL : 2.42
# Stock : BXPHARMA : 0.83
# Stock : SQURPHARMA : 3.42
# Stock : SAPORTL : 0.91
# Stock : BSCCL : 1.49
# Stock : GP : 0.14
# Stock : SQUARETEXT : 5.31
# Stock : OLYMPIC : 1.04
# Stock : BEXIMCO : 0.16
# Stock : HFL : 3.17
# Stock : UPGDCL : 1.13
# Stock : DELTALIFE : 0.29
# Stock : BENGALWTL : 3.02
# Stock : EHL : 0.35
# Stock : IBNSINA : 2.53
# Stock : WALTONHIL : 0.57
# Stock : UNIQUEHRL : 3.23
# Stock : UNILEVERCL : 4.66
# Stock : KDSALTD : 1.67
# Stock : JHRML : 4.95
# Stock : ADNTEL : 4.61
# Stock : ITC : 3.59
# Stock : SIMTEX : 1.87
# Stock : APEXFOODS : 5.73
# Stock : FORTUNE : 2.25
# Stock : INDEXAGRO : 2.09
# Stock : AMANFEED : 1.73
# Stock : SKICL : 4.38
# Stock : ACI : 1.60
# Stock : ACIFORMULA : 3.67
# Stock : EXIMBANK : 0.08
# Stock : IFILISLMF1 : 0.63
# Stock : AIBL1STIMF : 5.11
# Stock : EXIM1STMF : 0.50
# Stock : RECKITTBEN : 1.66
# Stock : JMISMDL : 0.28
#
# Volatility : 0.1380672225900526
# Return : 0.1884921407211449

# %%
p_wt[SR_IDX].sum()
# Out:
# 1.0

# %%
m=pd.DataFrame(columns=['Weights'],index=[sets.columns])
m['Weights']=p_wt[SR_IDX]*100

# %%
len(m['Weights'])
# Out:
# 44

# %%
m.loc['ISLAMIBANK','Weights']=2
m.loc['RAKCERAMIC','Weights']=1
m.loc['BATBC','Weights']=2
m.loc['RENATA','Weights']=3
m.loc['MARICO','Weights']=2
m.loc['SINGERBD','Weights']=1
m.loc['LINDEBD','Weights']=6
m.loc['SUMITPOWER','Weights']=1
m.loc['BERGERPBL','Weights']=5
m.loc['BXPHARMA','Weights']=1
m.loc['SQURPHARMA','Weights']=3
m.loc['SAPORTL','Weights']=1
m.loc['BSCCL','Weights']=2
m.loc['GP','Weights']=3
m.loc['SQUARETEXT','Weights']=1
m.loc['OLYMPIC','Weights']=3
m.loc['BEXIMCO','Weights']=3
m.loc['HFL','Weights']=1
m.loc['UPGDCL','Weights']=4
m.loc['DELTALIFE','Weights']=3
m.loc['BENGALWTL','Weights']=2
m.loc['EHL','Weights']=4
m.loc['IBNSINA','Weights']=3
m.loc['WALTONHIL','Weights']=1
m.loc['UNIQUEHRL','Weights']=2
m.loc['UNILEVERCL','Weights']=3
m.loc['KDSALTD','Weights']=1
m.loc['JHRML','Weights']=1
m.loc['ADNTEL','Weights']=2
m.loc['ITC','Weights']=2
m.loc['SIMTEX','Weights']=1
m.loc['APEXFOODS','Weights']=2
m.loc['FORTUNE','Weights']=3
m.loc['INDEXAGRO','Weights']=1.5
m.loc['AMANFEED','Weights']=1.5
m.loc['SKICL','Weights']=4
m.loc['ACI','Weights']=1.5
m.loc['ACIFORMULA','Weights']=1.5
m.loc['EXIMBANK' ,'Weights']=3
m.loc['IFILISLMF1','Weights']=3
m.loc['AIBL1STIMF','Weights']=2
m.loc['EXIM1STMF','Weights']=2
m.loc['RECKITTBEN','Weights']=3
m.loc['JMISMDL','Weights']=2

# %%
m['Weights'].sum()
# Out:
# 100.0

# %%
m
# Out:
#             Weights
# ISLAMIBANK      2.0
# RAKCERAMIC      1.0
# BATBC           2.0
# RENATA          3.0
# MARICO          2.0
# SINGERBD        1.0
# LINDEBD         6.0
# SUMITPOWER      1.0
# BERGERPBL       5.0
# BXPHARMA        1.0
# SQURPHARMA      3.0
# SAPORTL         1.0
# BSCCL           2.0
# GP              3.0
# SQUARETEXT      1.0
# OLYMPIC         3.0
# BEXIMCO         3.0
# HFL             1.0
# UPGDCL          4.0
# DELTALIFE       3.0
# BENGALWTL       2.0
# EHL             4.0
# IBNSINA         3.0
# WALTONHIL       1.0
# UNIQUEHRL       2.0
# UNILEVERCL      3.0
# KDSALTD         1.0
# JHRML           1.0
# ADNTEL          2.0
# ITC             2.0
# SIMTEX          1.0
# APEXFOODS       2.0
# FORTUNE         3.0
# INDEXAGRO       1.5
# AMANFEED        1.5
# SKICL           4.0
# ACI             1.5
# ACIFORMULA      1.5
# EXIMBANK        3.0
# IFILISLMF1      3.0
# AIBL1STIMF      2.0
# EXIM1STMF       2.0
# RECKITTBEN      3.0
# JMISMDL         2.0

# %%
np.sqrt((m['Weights'].values/100).T.dot((portfolio_ret.cov()*252).dot(m['Weights'].values/100)))
# Out:
# 0.11392729258790243

# %%
(m['Weights'].values/100).dot(returns.mean())*252 #yearly return
# Out:
# 0.10298618038767968

# %%
m.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Weights.xlsx")

# %%
def price(sdate,edate):
    df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
    mask = (df.index >= sdate) & (df.index <= edate)
    return(df.loc[mask])
price('2021-06-13','2021-06-13')
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4    NaN  262.5
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
#
# [1 rows x 44 columns]

# %%
sets
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
# 2021-06-14        27.5        35.2  532.9  1284.6  2117.7     180.0   1297.1
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-06        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-07        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4    NaN  262.5
# 2021-06-14        42.7     1743.1     170.8  ...      47.2    NaN  269.1
# 2021-06-15        42.6     1772.2     171.0  ...      48.1    NaN  269.7
# 2021-06-16        42.7     1775.1     170.8  ...      48.4    NaN  263.7
# 2021-06-17        44.3     1770.2     174.9  ...      48.6    NaN  263.5
# ...                ...        ...       ...  ...       ...    ...    ...
# 2023-06-06        34.0     1795.1     146.2  ...      33.5   47.1  260.2
# 2023-06-07        34.0     1788.4     146.2  ...      33.5   49.8  260.2
# 2023-06-08        34.0     1787.4     146.2  ...      33.5   48.9  260.2
# 2023-06-11        34.0     1776.4     146.2  ...      33.5   48.7  260.2
# 2023-06-12        34.0     1767.9     146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
# 2021-06-14       144.4      11.0         6.7         9.2        7.1
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
# 2021-06-16       145.0      10.8         6.7         9.2        7.1
# 2021-06-17       143.0      10.8         6.7         9.1        7.2
# ...                ...       ...         ...         ...        ...
# 2023-06-06       159.1      10.4         6.4         7.3        5.8
# 2023-06-07       157.5      10.4         6.4         7.3        5.8
# 2023-06-08       159.7      10.4         6.4         7.3        5.8
# 2023-06-11       159.7      10.4         6.4         7.3        5.8
# 2023-06-12       157.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
# 2021-06-14      4219.3    326.4
# 2021-06-15      4245.3    323.3
# 2021-06-16      4269.4    320.6
# 2021-06-17      4301.0    320.1
# ...                ...      ...
# 2023-06-06      4930.1    255.5
# 2023-06-07      4836.2    255.5
# 2023-06-08      4826.7    255.5
# 2023-06-11      4795.2    255.5
# 2023-06-12      4802.2    255.5
#
# [485 rows x 44 columns]

# %%
wt=(500000/100)*(m.loc['ISLAMIBANK'].values)
quantity=float(wt)/float(price('2023-06-08','2023-06-08')['ISLAMIBANK'].values)
round(quantity)*float(price('2023-06-08','2023-06-08')['ISLAMIBANK'].values)
# Out:
# 10008.2

# %%
sdate,edate='2022-05-12','2022-05-12'
def price(sdate,edate):
    df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
    df=df.fillna(method='bfill',axis='rows')
    mask = (df.index >= sdate) & (df.index <= edate)
    return(df.loc[mask])
price('2021-06-13','2021-06-13')
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4   11.0  262.5
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
#
# [1 rows x 44 columns]

# %%
sdate,edate='2021-06-13','2021-06-13'

# %%
def my_port(investment,m):
    Q=[]
    P=[]
    T=[]
    m=m
    pr=price(sdate,edate)
    for i in sets.columns:
        wt=(investment/ m['Weights'].sum())*(m.loc[i].values)
        Q.append(round(float(wt)/float(pr[i].values)))
        P.append(float(pr[i].values))
        T.append(round(float(wt)/float(pr[i].values))*float(pr[i].values))
    return(Q,P,T)

# %%
my_port(500000,m)
# Out:
# ([362,
#   137,
#   19,
#   12,
#   5,
#   27,
#   23,
#   118,
#   14,
#   29,
#   70,
#   173,
#   59,
#   43,
#   119,
#   88,
#   156,
#   281,
#   73,
#   146,
#   500,
#   427,
#   61,
#   4,
#   290,
#   5,
#   104,
#   227,
#   194,
#   275,
#   282,
#   80,
#   348,
#   68,
#   152,
#   1818,
#   29,
#   54,
#   1376,
#   2206,
#   1064,
#   1351,
#   4,
#   31],
#  [27.6,
#   36.6,
#   534.2,
#   1282.7,
#   2126.6,
#   182.1,
#   1302.6,
#   42.3,
#   1749.5,
#   172.7,
#   214.5,
#   28.9,
#   170.9,
#   352.6,
#   42.0,
#   170.5,
#   96.1,
#   17.8,
#   275.6,
#   102.9,
#   20.0,
#   46.8,
#   245.4,
#   1359.8,
#   34.5,
#   2729.2,
#   48.3,
#   22.0,
#   51.5,
#   36.4,
#   17.7,
#   125.2,
#   43.1,
#   110.6,
#   49.4,
#   11.0,
#   262.5,
#   139.2,
#   10.9,
#   6.8,
#   9.4,
#   7.4,
#   4220.4,
#   325.6],
#  [9991.2,
#   5014.2,
#   10149.800000000001,
#   15392.400000000001,
#   10633.0,
#   4916.7,
#   29959.8,
#   4991.4,
#   24493.0,
#   5008.299999999999,
#   15015.0,
#   4999.7,
#   10083.1,
#   15161.800000000001,
#   4998.0,
#   15004.0,
#   14991.599999999999,
#   5001.8,
#   20118.800000000003,
#   15023.400000000001,
#   10000.0,
#   19983.6,
#   14969.4,
#   5439.2,
#   10005.0,
#   13646.0,
#   5023.2,
#   4994.0,
#   9991.0,
#   10010.0,
#   4991.4,
#   10016.0,
#   14998.800000000001,
#   7520.799999999999,
#   7508.8,
#   19998.0,
#   7612.5,
#   7516.799999999999,
#   14998.4,
#   15000.8,
#   10001.6,
#   9997.4,
#   16881.6,
#   10093.6])

# %%
lists=pd.DataFrame()

# %%
lists=pd.DataFrame(columns=['Ouantity','Price','Total'],index=[sets.columns])
lists['Ouantity']=my_port(1000000,m)[0]
lists['Price']=my_port(1000000,m)[1]
lists['Total']=my_port(1000000,m)[2]
lists#['Total'].sum()
# Out:
#             Ouantity   Price    Total
# ISLAMIBANK       725    27.6  20010.0
# RAKCERAMIC       273    36.6   9991.8
# BATBC             37   534.2  19765.4
# RENATA            23  1282.7  29502.1
# MARICO             9  2126.6  19139.4
# SINGERBD          55   182.1  10015.5
# LINDEBD           46  1302.6  59919.6
# SUMITPOWER       236    42.3   9982.8
# BERGERPBL         29  1749.5  50735.5
# BXPHARMA          58   172.7  10016.6
# SQURPHARMA       140   214.5  30030.0
# SAPORTL          346    28.9   9999.4
# BSCCL            117   170.9  19995.3
# GP                85   352.6  29971.0
# SQUARETEXT       238    42.0   9996.0
# OLYMPIC          176   170.5  30008.0
# BEXIMCO          312    96.1  29983.2
# HFL              562    17.8  10003.6
# UPGDCL           145   275.6  39962.0
# DELTALIFE        292   102.9  30046.8
# BENGALWTL       1000    20.0  20000.0
# EHL              855    46.8  40014.0
# IBNSINA          122   245.4  29938.8
# WALTONHIL          7  1359.8   9518.6
# UNIQUEHRL        580    34.5  20010.0
# UNILEVERCL        11  2729.2  30021.2
# KDSALTD          207    48.3   9998.1
# JHRML            455    22.0  10010.0
# ADNTEL           388    51.5  19982.0
# ITC              549    36.4  19983.6
# SIMTEX           565    17.7  10000.5
# APEXFOODS        160   125.2  20032.0
# FORTUNE          696    43.1  29997.6
# INDEXAGRO        136   110.6  15041.6
# AMANFEED         304    49.4  15017.6
# SKICL           3636    11.0  39996.0
# ACI               57   262.5  14962.5
# ACIFORMULA       108   139.2  15033.6
# EXIMBANK        2752    10.9  29996.8
# IFILISLMF1      4412     6.8  30001.6
# AIBL1STIMF      2128     9.4  20003.2
# EXIM1STMF       2703     7.4  20002.2
# RECKITTBEN         7  4220.4  29542.8
# JMISMDL           61   325.6  19861.6

# %%
n=((lists['Total']/997658.2999999999)*100).values
n
# Out:
# array([2.00569674, 1.00152527, 1.98117933, 2.95713472, 1.91843239,
#        1.00390083, 6.00602431, 1.00062316, 5.08545862, 1.00401109,
#        3.01004863, 1.00228706, 2.00422329, 3.00413478, 1.00194626,
#        3.00784347, 3.00535765, 1.00270804, 4.00557987, 3.01173257,
#        2.00469439, 4.01079207, 3.00090722, 0.9540942 , 2.00569674,
#        3.00916657, 1.00215675, 1.00334954, 2.00289017, 2.00305054,
#        1.00239731, 2.0079019 , 3.00680103, 1.50769056, 1.50528493,
#        4.00898785, 1.49976199, 1.50688868, 3.00672084, 3.00720196,
#        2.00501514, 2.00491491, 2.96121428, 1.99082191])

# %%
(n/100).dot(returns.mean())*252 #yearly return
# Out:
# 0.10326533635339033

# %%
np.sqrt((n/100).T.dot((portfolio_ret.cov()*252).dot(n/100)))
# Out:
# 0.11412569590175407

# %%
lists['Total'].sum()
# Out:
# 998039.9

# %%
df=pd.read_excel('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx',index_col='date')

# %%
df.isnull().sum()
# Out:
# ISLAMIBANK      0
# RAKCERAMIC      0
# BATBC           0
# RENATA          0
# MARICO          0
# SINGERBD        0
# LINDEBD         0
# SUMITPOWER      0
# BERGERPBL       0
# BXPHARMA        0
# SQURPHARMA      0
# SAPORTL         0
# BSCCL           0
# GP              0
# SQUARETEXT      0
# OLYMPIC         0
# BEXIMCO         0
# HFL             0
# UPGDCL          0
# DELTALIFE       0
# BENGALWTL       0
# EHL             0
# IBNSINA         0
# WALTONHIL       0
# UNIQUEHRL       0
# UNILEVERCL      0
# KDSALTD         0
# JHRML         194
# ADNTEL          0
# ITC             0
# SIMTEX          0
# APEXFOODS       0
# FORTUNE         0
# INDEXAGRO       0
# AMANFEED        0
# SKICL          93
# ACI             0
# ACIFORMULA      0
# EXIMBANK        0
# IFILISLMF1      0
# AIBL1STIMF      0
# EXIM1STMF       0
# RECKITTBEN      0
# JMISMDL         0
# dtype: int64

# %%
df=df.fillna(method='bfill',axis='rows')
df
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
# 2021-06-14        27.5        35.2  532.9  1284.6  2117.7     180.0   1297.1
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-06        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-07        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4   11.0  262.5
# 2021-06-14        42.7     1743.1     170.8  ...      47.2   11.0  269.1
# 2021-06-15        42.6     1772.2     171.0  ...      48.1   11.0  269.7
# 2021-06-16        42.7     1775.1     170.8  ...      48.4   11.0  263.7
# 2021-06-17        44.3     1770.2     174.9  ...      48.6   11.0  263.5
# ...                ...        ...       ...  ...       ...    ...    ...
# 2023-06-06        34.0     1795.1     146.2  ...      33.5   47.1  260.2
# 2023-06-07        34.0     1788.4     146.2  ...      33.5   49.8  260.2
# 2023-06-08        34.0     1787.4     146.2  ...      33.5   48.9  260.2
# 2023-06-11        34.0     1776.4     146.2  ...      33.5   48.7  260.2
# 2023-06-12        34.0     1767.9     146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
# 2021-06-14       144.4      11.0         6.7         9.2        7.1
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
# 2021-06-16       145.0      10.8         6.7         9.2        7.1
# 2021-06-17       143.0      10.8         6.7         9.1        7.2
# ...                ...       ...         ...         ...        ...
# 2023-06-06       159.1      10.4         6.4         7.3        5.8
# 2023-06-07       157.5      10.4         6.4         7.3        5.8
# 2023-06-08       159.7      10.4         6.4         7.3        5.8
# 2023-06-11       159.7      10.4         6.4         7.3        5.8
# 2023-06-12       157.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
# 2021-06-14      4219.3    326.4
# 2021-06-15      4245.3    323.3
# 2021-06-16      4269.4    320.6
# 2021-06-17      4301.0    320.1
# ...                ...      ...
# 2023-06-06      4930.1    255.5
# 2023-06-07      4836.2    255.5
# 2023-06-08      4826.7    255.5
# 2023-06-11      4795.2    255.5
# 2023-06-12      4802.2    255.5
#
# [485 rows x 44 columns]

# %%
df.isnull().sum()
# Out:
# ISLAMIBANK    0
# RAKCERAMIC    0
# BATBC         0
# RENATA        0
# MARICO        0
# SINGERBD      0
# LINDEBD       0
# SUMITPOWER    0
# BERGERPBL     0
# BXPHARMA      0
# SQURPHARMA    0
# SAPORTL       0
# BSCCL         0
# GP            0
# SQUARETEXT    0
# OLYMPIC       0
# BEXIMCO       0
# HFL           0
# UPGDCL        0
# DELTALIFE     0
# BENGALWTL     0
# EHL           0
# IBNSINA       0
# WALTONHIL     0
# UNIQUEHRL     0
# UNILEVERCL    0
# KDSALTD       0
# JHRML         0
# ADNTEL        0
# ITC           0
# SIMTEX        0
# APEXFOODS     0
# FORTUNE       0
# INDEXAGRO     0
# AMANFEED      0
# SKICL         0
# ACI           0
# ACIFORMULA    0
# EXIMBANK      0
# IFILISLMF1    0
# AIBL1STIMF    0
# EXIM1STMF     0
# RECKITTBEN    0
# JMISMDL       0
# dtype: int64

# %%
port=pd.DataFrame(columns=[df.columns],index=df.index)
port
# Out:
#            ISLAMIBANK RAKCERAMIC BATBC RENATA MARICO SINGERBD LINDEBD  \
# date
# 2021-06-13        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-14        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-15        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-16        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-17        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# ...               ...        ...   ...    ...    ...      ...     ...
# 2023-06-06        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-07        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-08        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-11        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-12        NaN        NaN   NaN    NaN    NaN      NaN     NaN
#
#            SUMITPOWER BERGERPBL BXPHARMA  ... AMANFEED SKICL  ACI ACIFORMULA  \
# date                                      ...
# 2021-06-13        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2021-06-14        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2021-06-15        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2021-06-16        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2021-06-17        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# ...               ...       ...      ...  ...      ...   ...  ...        ...
# 2023-06-06        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2023-06-07        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2023-06-08        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2023-06-11        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2023-06-12        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
#
#            EXIMBANK IFILISLMF1 AIBL1STIMF EXIM1STMF RECKITTBEN JMISMDL
# date
# 2021-06-13      NaN        NaN        NaN       NaN        NaN     NaN
# 2021-06-14      NaN        NaN        NaN       NaN        NaN     NaN
# 2021-06-15      NaN        NaN        NaN       NaN        NaN     NaN
# 2021-06-16      NaN        NaN        NaN       NaN        NaN     NaN
# 2021-06-17      NaN        NaN        NaN       NaN        NaN     NaN
# ...             ...        ...        ...       ...        ...     ...
# 2023-06-06      NaN        NaN        NaN       NaN        NaN     NaN
# 2023-06-07      NaN        NaN        NaN       NaN        NaN     NaN
# 2023-06-08      NaN        NaN        NaN       NaN        NaN     NaN
# 2023-06-11      NaN        NaN        NaN       NaN        NaN     NaN
# 2023-06-12      NaN        NaN        NaN       NaN        NaN     NaN
#
# [485 rows x 44 columns]

# %%
for i in port.index:
    for j in df.columns:
        port.loc[i,j]=df.loc[i,j]*lists.loc[j]['Ouantity'][0]
port['Total']=port.iloc[:,0:len(df.columns)].sum(axis=1)

# %%
port.index=pd.to_datetime(port.index)

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')
plt.figure(figsize=(8, 6), dpi=200)
plt.title('My Portfolio Tow Years Performance')
plt.plot(np.array(port.index),np.array(port['Total'].values))
plt.xlabel('years')
plt.ylabel('BDT')
plt.xticks(rotation=45)
plt.show()

# %%
np.log(port['Total']/port['Total'].shift(1)).describe()
# Out:
#             Total
# count  484.000000
# mean     0.000604
# std      0.009336
# min     -0.035113
# 25%     -0.004589
# 50%      0.000582
# 75%      0.005464
# max      0.034125
