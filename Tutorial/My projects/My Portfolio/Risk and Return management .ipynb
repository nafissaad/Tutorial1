# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from bdshare import get_basic_hist_data

# %%
df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Port_folio_draft.xlsx", index_col='Unnamed: 0')
df
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# RAKCERAMIC                  RAK Ceramics (Bangladesh) Limited
# SALAMCRST                     S. Alam Cold Rolled Steels Ltd.
# POWERGRID               Power Grid Company of Bangladesh Ltd.
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# MARICO                              Marico Bangladesh Limited
# SINGERBD                                Singer Bangladesh Ltd
# LINDEBD                                  Linde Bangladesh Ltd
# SUMITPOWER                                   Summit Power Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# SAPORTL                              Summit Alliance Port Ltd
# BSCCL                         Bangladesh Submarine Cables PLC
# GP                                           Grameenphone Ltd
# SQUARETEXT                                 Square Textile Ltd
# HEIDELBCEM                   Heidelberg Cement Bangladesh Ltd
# OLYMPIC                        Olympic Industries Ltd OLYMPIC
# BSRMSTEEL                                     BSRM Steels Ltd
# BEXIMCO                                           BEXIMCO Ltd
# NATLIFEINS                     National Life Insurance Co Ltd
# HFL                                         Hamid Fabrics Ltd
# BATASHOE                        Bata Shoe Co (Bangladesh) Ltd
#  APEXSPINN                 Apex Spinning & Knitting Mills Ltd
# UPGDCL         United Power Generation & Distribution Co. Ltd
# DELTALIFE                      Green Delta Insurance Co. Ltd.
# CROWNCEMNT                                   Crown Cement PLC
# BENGALWTL                  Bengal Windsor Thermoplastics Ltd.
# EHL                                      Eastern Housing Ltd.
# IBNSINA                  IBN SINA Pharmaceutical Industry PLC
# WALTONHIL                      Walton Hi-Tech Industries Ltd.
# UNIQUEHRL                         Unique Hotel & Resorts Ltd.
# UNILEVERCL                        Unilever Consumer Care Ltd.
# KDSALTD                                  KDS Accessories Ltd.
# JHRML               JMI Hospital Requisite Manufacturing Ltd.
# ADNTEL                                 Adn Telecom Ltd (ADNT)
# ITC                                       IT Consultants Ltd.
# SIMTEX                                 Simtex Industries Ltd.
# APEXFOOT                                   Apex Footwear Ltd.
# APEXFOODS                                     Apex Foods Ltd.
# FORTUNE                                    Fortune Shoes Ltd.
# INDEXAGRO                          Index Agro Industries Ltd.
# AMANFEED                                       Aman Feed Ltd.
# SKICL                     Sena Kalyan Insurance Co Ltd (SENA)
# ACI                                                  ACI Ltd.
# ACIFORMULA                              ACI Formulations Ltd.
# EXIMBANK                     Export Import Bank of Bangladesh
# IFILISLMF1                         IFIL Islamic Mutual Fund-1
# AIBL1STIMF                       AIBL 1st Islamic Mutual Fund
# EXIM1STMF                           EXIM Bank 1st Mutual Fund
# RECKITTBEN                           Reckitt & Benckiser Ltd.
# JMISMDL                   JMI Syringes & Medical Devices Ltd.
# BPML                             Bashundhara Paper Mills Ltd.
#
#                                  Sector Evaluation
# ISLAMIBANK                         Bank          G
# RAKCERAMIC                      Ceramic          M
# SALAMCRST                   Engineering          P
# POWERGRID                  Fuel & Power          P
# BATBC                     FOOD & Allied          G
# RENATA      Pharmaceuticals & Chemicals          G
# MARICO      Pharmaceuticals & Chemicals          M
# SINGERBD                    Engineering          M
# LINDEBD                    Fuel & Power          G
# SUMITPOWER                 Fuel & Power          M
# BERGERPBL                 Miscellaneous          G
# BXPHARMA    Pharmaceuticals & Chemicals          G
# SQURPHARMA  Pharmaceuticals & Chemicals          G
# SAPORTL          Services & Real Estate          M
# BSCCL                 Telecommunication          M
# GP                    Telecommunication          G
# SQUARETEXT                      Textile          M
# HEIDELBCEM                       Cement          P
# OLYMPIC                   FOOD & Allied          G
# BSRMSTEEL                  Iron & Steel          P
# BEXIMCO                   Miscellaneous          M
# NATLIFEINS                    Insurance          P
# HFL                             Textile          M
# BATASHOE             Tannery Industries          P
#  APEXSPINN                      Textile          P
# UPGDCL                     Fuel & Power          G
# DELTALIFE                     Insurance          G
# CROWNCEMNT                       Cement          P
# BENGALWTL                   Engineering          M
# EHL              Services & Real Estate          M
# IBNSINA     Pharmaceuticals & Chemicals          G
# WALTONHIL                   Engineering          G
# UNIQUEHRL            Travel and Leisure          G
# UNILEVERCL                FOOD & Allied          M
# KDSALTD                     Engineering          M
# JHRML       Pharmaceuticals & Chemicals          M
# ADNTEL                        IT Sector          G
# ITC                           IT Sector          G
# SIMTEX                          Textile          M
# APEXFOOT             Tannery Industries          P
# APEXFOODS                 FOOD & Allied          G
# FORTUNE              Tannery Industries          G
# INDEXAGRO                 Miscellaneous          M
# AMANFEED                  Miscellaneous          G
# SKICL                         Insurance          G
# ACI         Pharmaceuticals & Chemicals          G
# ACIFORMULA  Pharmaceuticals & Chemicals          M
# EXIMBANK                           Bank          M
# IFILISLMF1                  Mutual Fund          G
# AIBL1STIMF                  Mutual Fund          G
# EXIM1STMF                   Mutual Fund          M
# RECKITTBEN  Pharmaceuticals & Chemicals          G
# JMISMDL     Pharmaceuticals & Chemicals          G
# BPML                   Paper & Printing          P

# %%
df[df['Evaluation']=='P']
# Out:
#                                         Full Name              Sector  \
# SALAMCRST         S. Alam Cold Rolled Steels Ltd.         Engineering
# POWERGRID   Power Grid Company of Bangladesh Ltd.        Fuel & Power
# HEIDELBCEM       Heidelberg Cement Bangladesh Ltd              Cement
# BSRMSTEEL                         BSRM Steels Ltd        Iron & Steel
# NATLIFEINS         National Life Insurance Co Ltd           Insurance
# BATASHOE            Bata Shoe Co (Bangladesh) Ltd  Tannery Industries
#  APEXSPINN     Apex Spinning & Knitting Mills Ltd             Textile
# CROWNCEMNT                       Crown Cement PLC              Cement
# APEXFOOT                       Apex Footwear Ltd.  Tannery Industries
# BPML                 Bashundhara Paper Mills Ltd.    Paper & Printing
#
#            Evaluation
# SALAMCRST           P
# POWERGRID           P
# HEIDELBCEM          P
# BSRMSTEEL           P
# NATLIFEINS          P
# BATASHOE            P
#  APEXSPINN          P
# CROWNCEMNT          P
# APEXFOOT            P
# BPML                P

# %%
df=df[~(df['Evaluation']=='P')]
df
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# RAKCERAMIC                  RAK Ceramics (Bangladesh) Limited
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# MARICO                              Marico Bangladesh Limited
# SINGERBD                                Singer Bangladesh Ltd
# LINDEBD                                  Linde Bangladesh Ltd
# SUMITPOWER                                   Summit Power Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# SAPORTL                              Summit Alliance Port Ltd
# BSCCL                         Bangladesh Submarine Cables PLC
# GP                                           Grameenphone Ltd
# SQUARETEXT                                 Square Textile Ltd
# OLYMPIC                        Olympic Industries Ltd OLYMPIC
# BEXIMCO                                           BEXIMCO Ltd
# HFL                                         Hamid Fabrics Ltd
# UPGDCL         United Power Generation & Distribution Co. Ltd
# DELTALIFE                      Green Delta Insurance Co. Ltd.
# BENGALWTL                  Bengal Windsor Thermoplastics Ltd.
# EHL                                      Eastern Housing Ltd.
# IBNSINA                  IBN SINA Pharmaceutical Industry PLC
# WALTONHIL                      Walton Hi-Tech Industries Ltd.
# UNIQUEHRL                         Unique Hotel & Resorts Ltd.
# UNILEVERCL                        Unilever Consumer Care Ltd.
# KDSALTD                                  KDS Accessories Ltd.
# JHRML               JMI Hospital Requisite Manufacturing Ltd.
# ADNTEL                                 Adn Telecom Ltd (ADNT)
# ITC                                       IT Consultants Ltd.
# SIMTEX                                 Simtex Industries Ltd.
# APEXFOODS                                     Apex Foods Ltd.
# FORTUNE                                    Fortune Shoes Ltd.
# INDEXAGRO                          Index Agro Industries Ltd.
# AMANFEED                                       Aman Feed Ltd.
# SKICL                     Sena Kalyan Insurance Co Ltd (SENA)
# ACI                                                  ACI Ltd.
# ACIFORMULA                              ACI Formulations Ltd.
# EXIMBANK                     Export Import Bank of Bangladesh
# IFILISLMF1                         IFIL Islamic Mutual Fund-1
# AIBL1STIMF                       AIBL 1st Islamic Mutual Fund
# EXIM1STMF                           EXIM Bank 1st Mutual Fund
# RECKITTBEN                           Reckitt & Benckiser Ltd.
# JMISMDL                   JMI Syringes & Medical Devices Ltd.
#
#                                  Sector Evaluation
# ISLAMIBANK                         Bank          G
# RAKCERAMIC                      Ceramic          M
# BATBC                     FOOD & Allied          G
# RENATA      Pharmaceuticals & Chemicals          G
# MARICO      Pharmaceuticals & Chemicals          M
# SINGERBD                    Engineering          M
# LINDEBD                    Fuel & Power          G
# SUMITPOWER                 Fuel & Power          M
# BERGERPBL                 Miscellaneous          G
# BXPHARMA    Pharmaceuticals & Chemicals          G
# SQURPHARMA  Pharmaceuticals & Chemicals          G
# SAPORTL          Services & Real Estate          M
# BSCCL                 Telecommunication          M
# GP                    Telecommunication          G
# SQUARETEXT                      Textile          M
# OLYMPIC                   FOOD & Allied          G
# BEXIMCO                   Miscellaneous          M
# HFL                             Textile          M
# UPGDCL                     Fuel & Power          G
# DELTALIFE                     Insurance          G
# BENGALWTL                   Engineering          M
# EHL              Services & Real Estate          M
# IBNSINA     Pharmaceuticals & Chemicals          G
# WALTONHIL                   Engineering          G
# UNIQUEHRL            Travel and Leisure          G
# UNILEVERCL                FOOD & Allied          M
# KDSALTD                     Engineering          M
# JHRML       Pharmaceuticals & Chemicals          M
# ADNTEL                        IT Sector          G
# ITC                           IT Sector          G
# SIMTEX                          Textile          M
# APEXFOODS                 FOOD & Allied          G
# FORTUNE              Tannery Industries          G
# INDEXAGRO                 Miscellaneous          M
# AMANFEED                  Miscellaneous          G
# SKICL                         Insurance          G
# ACI         Pharmaceuticals & Chemicals          G
# ACIFORMULA  Pharmaceuticals & Chemicals          M
# EXIMBANK                           Bank          M
# IFILISLMF1                  Mutual Fund          G
# AIBL1STIMF                  Mutual Fund          G
# EXIM1STMF                   Mutual Fund          M
# RECKITTBEN  Pharmaceuticals & Chemicals          G
# JMISMDL     Pharmaceuticals & Chemicals          G

# %%
df[df['Evaluation']=='G']
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# LINDEBD                                  Linde Bangladesh Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# GP                                           Grameenphone Ltd
# OLYMPIC                        Olympic Industries Ltd OLYMPIC
# UPGDCL         United Power Generation & Distribution Co. Ltd
# DELTALIFE                      Green Delta Insurance Co. Ltd.
# IBNSINA                  IBN SINA Pharmaceutical Industry PLC
# WALTONHIL                      Walton Hi-Tech Industries Ltd.
# UNIQUEHRL                         Unique Hotel & Resorts Ltd.
# ADNTEL                                 Adn Telecom Ltd (ADNT)
# ITC                                       IT Consultants Ltd.
# APEXFOODS                                     Apex Foods Ltd.
# FORTUNE                                    Fortune Shoes Ltd.
# AMANFEED                                       Aman Feed Ltd.
# SKICL                     Sena Kalyan Insurance Co Ltd (SENA)
# ACI                                                  ACI Ltd.
# IFILISLMF1                         IFIL Islamic Mutual Fund-1
# AIBL1STIMF                       AIBL 1st Islamic Mutual Fund
# RECKITTBEN                           Reckitt & Benckiser Ltd.
# JMISMDL                   JMI Syringes & Medical Devices Ltd.
#
#                                  Sector Evaluation
# ISLAMIBANK                         Bank          G
# BATBC                     FOOD & Allied          G
# RENATA      Pharmaceuticals & Chemicals          G
# LINDEBD                    Fuel & Power          G
# BERGERPBL                 Miscellaneous          G
# BXPHARMA    Pharmaceuticals & Chemicals          G
# SQURPHARMA  Pharmaceuticals & Chemicals          G
# GP                    Telecommunication          G
# OLYMPIC                   FOOD & Allied          G
# UPGDCL                     Fuel & Power          G
# DELTALIFE                     Insurance          G
# IBNSINA     Pharmaceuticals & Chemicals          G
# WALTONHIL                   Engineering          G
# UNIQUEHRL            Travel and Leisure          G
# ADNTEL                        IT Sector          G
# ITC                           IT Sector          G
# APEXFOODS                 FOOD & Allied          G
# FORTUNE              Tannery Industries          G
# AMANFEED                  Miscellaneous          G
# SKICL                         Insurance          G
# ACI         Pharmaceuticals & Chemicals          G
# IFILISLMF1                  Mutual Fund          G
# AIBL1STIMF                  Mutual Fund          G
# RECKITTBEN  Pharmaceuticals & Chemicals          G
# JMISMDL     Pharmaceuticals & Chemicals          G

# %%
df[df['Evaluation']=='M']
# Out:
#                                             Full Name  \
# RAKCERAMIC          RAK Ceramics (Bangladesh) Limited
# MARICO                      Marico Bangladesh Limited
# SINGERBD                        Singer Bangladesh Ltd
# SUMITPOWER                           Summit Power Ltd
# SAPORTL                      Summit Alliance Port Ltd
# BSCCL                 Bangladesh Submarine Cables PLC
# SQUARETEXT                         Square Textile Ltd
# BEXIMCO                                   BEXIMCO Ltd
# HFL                                 Hamid Fabrics Ltd
# BENGALWTL          Bengal Windsor Thermoplastics Ltd.
# EHL                              Eastern Housing Ltd.
# UNILEVERCL                Unilever Consumer Care Ltd.
# KDSALTD                          KDS Accessories Ltd.
# JHRML       JMI Hospital Requisite Manufacturing Ltd.
# SIMTEX                         Simtex Industries Ltd.
# INDEXAGRO                  Index Agro Industries Ltd.
# ACIFORMULA                      ACI Formulations Ltd.
# EXIMBANK             Export Import Bank of Bangladesh
# EXIM1STMF                   EXIM Bank 1st Mutual Fund
#
#                                  Sector Evaluation
# RAKCERAMIC                      Ceramic          M
# MARICO      Pharmaceuticals & Chemicals          M
# SINGERBD                    Engineering          M
# SUMITPOWER                 Fuel & Power          M
# SAPORTL          Services & Real Estate          M
# BSCCL                 Telecommunication          M
# SQUARETEXT                      Textile          M
# BEXIMCO                   Miscellaneous          M
# HFL                             Textile          M
# BENGALWTL                   Engineering          M
# EHL              Services & Real Estate          M
# UNILEVERCL                FOOD & Allied          M
# KDSALTD                     Engineering          M
# JHRML       Pharmaceuticals & Chemicals          M
# SIMTEX                          Textile          M
# INDEXAGRO                 Miscellaneous          M
# ACIFORMULA  Pharmaceuticals & Chemicals          M
# EXIMBANK                           Bank          M
# EXIM1STMF                   Mutual Fund          M

# %%
df.groupby('Evaluation')['Evaluation'].agg('count').sort_values(ascending=False)
# Out:
# Evaluation
# G    25
# M    19
# Name: Evaluation, dtype: int64

# %%
df.groupby('Sector')['Sector'].agg('count').sort_values(ascending=False)
# Out:
# Sector
# Pharmaceuticals & Chemicals    10
# Engineering                     4
# FOOD & Allied                   4
# Miscellaneous                   4
# Fuel & Power                    3
# Mutual Fund                     3
# Textile                         3
# Bank                            2
# IT Sector                       2
# Insurance                       2
# Services & Real Estate          2
# Telecommunication               2
# Ceramic                         1
# Tannery Industries              1
# Travel and Leisure              1
# Name: Sector, dtype: int64

# %%
ticker=[i for i in df.index.values]
ticker
# Out:
# ['ISLAMIBANK',
#  'RAKCERAMIC',
#  'BATBC',
#  'RENATA',
#  'MARICO',
#  'SINGERBD',
#  'LINDEBD',
#  'SUMITPOWER',
#  'BERGERPBL',
#  'BXPHARMA',
#  'SQURPHARMA',
#  'SAPORTL',
#  'BSCCL',
#  'GP',
#  'SQUARETEXT',
#  'OLYMPIC',
#  'BEXIMCO',
#  'HFL',
#  'UPGDCL',
#  'DELTALIFE',
#  'BENGALWTL',
#  'EHL',
#  'IBNSINA',
#  'WALTONHIL',
#  'UNIQUEHRL',
#  'UNILEVERCL',
#  'KDSALTD',
#  'JHRML',
#  'ADNTEL',
#  'ITC',
#  'SIMTEX',
#  'APEXFOODS',
#  'FORTUNE',
#  'INDEXAGRO',
#  'AMANFEED',
#  'SKICL',
#  'ACI',
#  'ACIFORMULA',
#  'EXIMBANK',
#  'IFILISLMF1',
#  'AIBL1STIMF',
#  'EXIM1STMF',
#  'RECKITTBEN',
#  'JMISMDL']

# %%
#sets=pd.DataFrame()
#for i in ticker:
    #print('Working on :',i)
    #date='2023-06-11'
    #try:
        #data=get_basic_hist_data('2020-01-1',date,i,index='date')['close']
        #sets[i]=data
    #except:
        #df=pd.read_html('https://www.dsebd.org/day_end_archive.php?startDate=2020-01-01&endDate='+date+'&inst='+i+'&archive=data')[348]
        #df.index=df['DATE']
        #sets[i]=df['CLOSEP*']
        #print('Exception')
#sets.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx")

def concat(x):
    sets=pd.DataFrame()
    for i in ticker:
        sets[i]=get_basic_hist_data(str(pd.to_datetime(x.index[-1])+timedelta(days=1))[0:10],str(datetime.today()-timedelta(days=1))[0:10],i,index='date')['close']
    return(pd.concat([x,sets],axis=0))
pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
# 2021-06-14        27.5        35.2  532.9  1284.6  2117.7     180.0   1297.1
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-06        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-07        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4    NaN  262.5
# 2021-06-14        42.7     1743.1     170.8  ...      47.2    NaN  269.1
# 2021-06-15        42.6     1772.2     171.0  ...      48.1    NaN  269.7
# 2021-06-16        42.7     1775.1     170.8  ...      48.4    NaN  263.7
# 2021-06-17        44.3     1770.2     174.9  ...      48.6    NaN  263.5
# ...                ...        ...       ...  ...       ...    ...    ...
# 2023-06-06        34.0     1795.1     146.2  ...      33.5   47.1  260.2
# 2023-06-07        34.0     1788.4     146.2  ...      33.5   49.8  260.2
# 2023-06-08        34.0     1787.4     146.2  ...      33.5   48.9  260.2
# 2023-06-11        34.0     1776.4     146.2  ...      33.5   48.7  260.2
# 2023-06-12        34.0     1767.9     146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
# 2021-06-14       144.4      11.0         6.7         9.2        7.1
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
# 2021-06-16       145.0      10.8         6.7         9.2        7.1
# 2021-06-17       143.0      10.8         6.7         9.1        7.2
# ...                ...       ...         ...         ...        ...
# 2023-06-06       159.1      10.4         6.4         7.3        5.8
# 2023-06-07       157.5      10.4         6.4         7.3        5.8
# 2023-06-08       159.7      10.4         6.4         7.3        5.8
# 2023-06-11       159.7      10.4         6.4         7.3        5.8
# 2023-06-12       157.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
# 2021-06-14      4219.3    326.4
# 2021-06-15      4245.3    323.3
# 2021-06-16      4269.4    320.6
# 2021-06-17      4301.0    320.1
# ...                ...      ...
# 2023-06-06      4930.1    255.5
# 2023-06-07      4836.2    255.5
# 2023-06-08      4826.7    255.5
# 2023-06-11      4795.2    255.5
# 2023-06-12      4802.2    255.5
#
# [485 rows x 44 columns]

# %%
concat(pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')).to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx")

# %%
sets=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
sets
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
# 2021-06-14        27.5        35.2  532.9  1284.6  2117.7     180.0   1297.1
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-07        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-13        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4    NaN  262.5
# 2021-06-14        42.7     1743.1     170.8  ...      47.2    NaN  269.1
# 2021-06-15        42.6     1772.2     171.0  ...      48.1    NaN  269.7
# 2021-06-16        42.7     1775.1     170.8  ...      48.4    NaN  263.7
# 2021-06-17        44.3     1770.2     174.9  ...      48.6    NaN  263.5
# ...                ...        ...       ...  ...       ...    ...    ...
# 2023-06-07        34.0     1788.4     146.2  ...      33.5   49.8  260.2
# 2023-06-08        34.0     1787.4     146.2  ...      33.5   48.9  260.2
# 2023-06-11        34.0     1776.4     146.2  ...      33.5   48.7  260.2
# 2023-06-12        34.0     1767.9     146.2  ...      33.5   47.7  260.2
# 2023-06-13        34.0     1770.1     146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
# 2021-06-14       144.4      11.0         6.7         9.2        7.1
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
# 2021-06-16       145.0      10.8         6.7         9.2        7.1
# 2021-06-17       143.0      10.8         6.7         9.1        7.2
# ...                ...       ...         ...         ...        ...
# 2023-06-07       157.5      10.4         6.4         7.3        5.8
# 2023-06-08       159.7      10.4         6.4         7.3        5.8
# 2023-06-11       159.7      10.4         6.4         7.3        5.8
# 2023-06-12       157.5      10.4         6.4         7.3        5.8
# 2023-06-13       156.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
# 2021-06-14      4219.3    326.4
# 2021-06-15      4245.3    323.3
# 2021-06-16      4269.4    320.6
# 2021-06-17      4301.0    320.1
# ...                ...      ...
# 2023-06-07      4836.2    255.5
# 2023-06-08      4826.7    255.5
# 2023-06-11      4795.2    255.5
# 2023-06-12      4802.2    255.5
# 2023-06-13      4814.8    255.5
#
# [486 rows x 44 columns]

# %%
sets.index[31]
# Out:
# '2021-08-05'

# %%
sets.loc[sets.index[31],'ISLAMIBANK']
# Out:
# 29.0

# %%
sets.index[49]
# Out:
# '2021-09-05'

# %%
sets.loc[sets.index[49],'ISLAMIBANK']
# Out:
# 29.7

# %%
sets.index=pd.to_datetime(sets.index)
sets.resample('1M').last()
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06
146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-30       148.2      11.6         6.8         9.1        7.9
# 2021-07-31       154.1      12.0         7.3         9.7        9.4
# 2021-08-31       172.9      13.0         7.0         9.0        8.2
# 2021-09-30       170.9      12.7         6.7         8.9        7.0
# 2021-10-31       163.7      12.8         6.6         8.8        6.8
# 2021-11-30       148.5      13.0         6.4         8.5        6.6
# 2021-12-31       147.1      12.7         6.4         8.5        6.2
# 2022-01-31       177.2      12.7         7.0         8.7        6.1
# 2022-02-28       163.9      12.1         6.7         8.4        5.9
# 2022-03-31       169.5      12.5         6.8         8.6        6.1
# 2022-04-30       166.2      12.3         6.6         8.6        6.2
# 2022-05-31       166.6      11.5         6.6         9.2        6.0
# 2022-06-30       158.1      10.9         6.5         7.9        6.0
# 2022-07-31       155.3      10.6         6.4         7.3        6.0
# 2022-08-31       171.5      10.8         6.6         7.3        6.1
# 2022-09-30       171.1      10.5         6.4         7.3        5.8
# 2022-10-31       155.0      10.4         6.4         7.3        5.8
# 2022-11-30       155.0      10.4         6.4         7.3        5.8
# 2022-12-31       155.0      10.4         6.4         7.4        5.8
# 2023-01-31       155.0      10.4         7.0         7.7        5.8
# 2023-02-28       155.0      10.4         7.0         7.7        5.8
# 2023-03-31       155.0      10.4         6.4         7.3        5.8
# 2023-04-30       158.1      10.8         6.4         7.3        5.8
# 2023-05-31       156.9      10.4         6.4         7.3        5.8
# 2023-06-30       156.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-30      4356.3    331.1
# 2021-07-31      4526.4    356.5
# 2021-08-31      4475.1    375.3
# 2021-09-30      4837.2    396.5
# 2021-10-31      5038.7    334.2
# 2021-11-30      4892.4    316.0
# 2021-12-31      5729.9    333.7
# 2022-01-31      5840.1    336.9
# 2022-02-28      5853.3    342.6
# 2022-03-31      5388.4    345.6
# 2022-04-30      4871.3    323.3
# 2022-05-31      4695.9    305.1
# 2022-06-30      4868.5    312.3
# 2022-07-31      4796.1    299.0
# 2022-08-31      4892.2    344.6
# 2022-09-30      4830.9    392.4
# 2022-10-31      4760.7    347.5
# 2022-11-30      4760.7    255.5
# 2022-12-31      4760.7    255.5
# 2023-01-31      4760.7    255.5
# 2023-02-28      4760.7    255.5
# 2023-03-31      4760.7    255.5
# 2023-04-30      4777.9    255.5
# 2023-05-31      4772.2    255.5
# 2023-06-30      4814.8    255.5
#
# [25 rows x 44 columns]

# %%
simple_return=sets['LINDEBD'].pct_change()
log_return=np.log(sets['LINDEBD']/sets['LINDEBD'].shift(1)).dropna()
simple_return.describe(),log_return.describe()
# Out:
# (count    485.000000
#  mean       0.000225
#  std        0.012696
#  min       -0.057060
#  25%       -0.002988
#  50%        0.000000
#  75%        0.001079
#  max        0.062438
#  Name: LINDEBD, dtype: float64,
#  count    485.000000
#  mean       0.000145
#  std        0.012617
#  min       -0.058753
#  25%       -0.002993
#  50%        0.000000
#  75%        0.001079
#  max        0.060566
#  Name: LINDEBD, dtype: float64)

# %%
log_return.mean()
# Out:
# 0.0001452902296465152

# %%
len(log_return)
1397.7-1421.4061975711857
# Out:
# -23.706197571185612

# %%
1324.7*(1+log_return.mean())**(len(log_return))
# Out:
# 1421.4061975711857

# %%
1324.7*(1+simple_return.mean())**(len(log_return))
# Out:
# 1477.4616342042339

# %%
sets['ISLAMIBANK'].std()/sets['ISLAMIBANK'].mean()
# Out:
# 0.04506735275183418

# %%
stats=pd.DataFrame(columns=[sets.columns],index=['Log Return','Rsquared','Return Standard Deviation','COV'])
for i in ticker:
    print('Working on :',i)
    stats.loc['Log Return',i]=np.log(sets[i]/sets[i].shift(1)).dropna().mean()*100
    stats.loc['Return Standard Deviation',i]=np.log(sets[i]/sets[i].shift(1)).dropna().std()*100
    stats.loc['COV',i]=(sets[i].std()/sets[i].mean())
stats=stats.T
stats
# Out:
# Working on : ISLAMIBANK
# Working on : RAKCERAMIC
# Working on : BATBC
# Working on : RENATA
# Working on : MARICO
# Working on : SINGERBD
# Working on : LINDEBD
# Working on : SUMITPOWER
# Working on : BERGERPBL
# Working on : BXPHARMA
# Working on : SQURPHARMA
# Working on : SAPORTL
# Working on : BSCCL
# Working on : GP
# Working on : SQUARETEXT
# Working on : OLYMPIC
# Working on : BEXIMCO
# Working on : HFL
# Working on : UPGDCL
# Working on : DELTALIFE
# Working on : BENGALWTL
# Working on : EHL
# Working on : IBNSINA
# Working on : WALTONHIL
# Working on : UNIQUEHRL
# Working on : UNILEVERCL
# Working on : KDSALTD
# Working on : JHRML
# Working on : ADNTEL
# Working on : ITC
# Working on : SIMTEX
# Working on : APEXFOODS
# Working on : FORTUNE
# Working on : INDEXAGRO
# Working on : AMANFEED
# Working on : SKICL
# Working on : ACI
# Working on : ACIFORMULA
# Working on : EXIMBANK
# Working on : IFILISLMF1
# Working on : AIBL1STIMF
# Working on : EXIM1STMF
# Working on : RECKITTBEN
# Working on : JMISMDL
#            Log Return Rsquared Return Standard Deviation       COV
# ISLAMIBANK   0.034329      NaN                  0.882594  0.045067
# RAKCERAMIC   0.032747      NaN                  1.947395  0.087895
# BATBC       -0.006071      NaN                   0.95527  0.098415
# RENATA      -0.010688      NaN                  0.689243  0.055603
# MARICO       0.026776      NaN                  0.484062  0.026516
# SINGERBD    -0.037388      NaN                   0.78148  0.080141
# LINDEBD      0.014529      NaN                  1.261689  0.083502
# SUMITPOWER  -0.045036      NaN                  1.018144  0.115609
# BERGERPBL    0.002414      NaN                  0.850651  0.021289
# BXPHARMA    -0.034346      NaN                   1.63482  0.159302
# SQURPHARMA  -0.004568      NaN                  0.688116   0.04069
# SAPORTL     -0.003598      NaN                  2.679893  0.089735
# BSCCL        0.051038      NaN                  1.592611  0.073559
# GP          -0.042731      NaN                  0.732436   0.10676
# SQUARETEXT   0.097826      NaN                  1.629813  0.127229
# OLYMPIC     -0.025179      NaN                   1.91826  0.150594
# BEXIMCO      0.038092      NaN                   1.81161  0.155263
# HFL         -0.003505      NaN                  3.301992   0.15266
# UPGDCL      -0.034003      NaN                  0.824109  0.083827
# DELTALIFE    0.066115      NaN                  2.774035  0.164745
# BENGALWTL    0.063399      NaN                  2.880733  0.165258
# EHL          0.148566      NaN                  3.570115  0.323606
# IBNSINA         0.032      NaN                  1.209147  0.052104
# WALTONHIL   -0.053761      NaN                  0.959647  0.098522
# UNIQUEHRL    0.140512      NaN                  2.816488  0.163694
# UNILEVERCL  -0.059034      NaN                  2.534035  0.097984
# KDSALTD       0.09616      NaN                  2.302165  0.166908
# JHRML        0.432283      NaN                  4.149864  0.214182
# ADNTEL       0.197013      NaN                   3.19347  0.388305
# ITC          0.017373      NaN                  2.362658  0.089388
# SIMTEX       0.025189      NaN                   2.66675  0.139798
# APEXFOODS    0.248719      NaN                  3.600466   0.35195
# FORTUNE      0.116135      NaN                  2.373092  0.248283
# INDEXAGRO   -0.013481      NaN                  2.638704  0.094047
# AMANFEED    -0.080084      NaN                  2.418877  0.288387
# SKICL        0.374244      NaN                   3.42844   0.21096
# ACI         -0.001815      NaN                  1.234621  0.067029
# ACIFORMULA   0.024153      NaN                  2.001053  0.061459
# EXIMBANK    -0.009682      NaN                   1.04785  0.092481
# IFILISLMF1    -0.0125      NaN                    1.4177  0.040233
# AIBL1STIMF  -0.052131      NaN                  0.882728  0.094244
# EXIM1STMF   -0.050231      NaN                  1.621929   0.13881
# RECKITTBEN   0.027168      NaN                  0.999348  0.078226
# JMISMDL     -0.049989      NaN                   2.51211   0.16154

# %%
pct_change=pd.DataFrame()
for i in sets.columns:
    pct_change[i]=sets[i].pct_change(5)
pct_change=pct_change.fillna(0)

# %%
import statsmodels.api as sm
def VIF_score(df):
    VIF_score=[]
    ticker=[]
    for i in df.columns:
        model=sm.OLS(df[i],sm.add_constant(df.loc[:, df.columns!=i]),hasconst=True)
        results=model.fit()
        VIF_score.append(results.rsquared)
        ticker.append(i)
    return(VIF_score,ticker)

# %%
for i in pct_change.columns:
    print(i)
# Out:
# ISLAMIBANK
# RAKCERAMIC
# BATBC
# RENATA
# MARICO
# SINGERBD
# LINDEBD
# SUMITPOWER
# BERGERPBL
# BXPHARMA
# SQURPHARMA
# SAPORTL
# BSCCL
# GP
# SQUARETEXT
# OLYMPIC
# BEXIMCO
# HFL
# UPGDCL
# DELTALIFE
# BENGALWTL
# EHL
# IBNSINA
# WALTONHIL
# UNIQUEHRL
# UNILEVERCL
# KDSALTD
# JHRML
# ADNTEL
# ITC
# SIMTEX
# APEXFOODS
# FORTUNE
# INDEXAGRO
# AMANFEED
# SKICL
# ACI
# ACIFORMULA
# EXIMBANK
# IFILISLMF1
# AIBL1STIMF
# EXIM1STMF
# RECKITTBEN
# JMISMDL

# %%
stats['Rsquared']=VIF_score(pct_change)[0]

# %%
stats.sort_values('Rsquared', axis=0, ascending=False)
# Out:
#            Log Return  Rsquared Return Standard Deviation       COV
# UPGDCL      -0.034003  0.714498                  0.824109  0.083827
# LINDEBD      0.014529  0.696127                  1.261689  0.083502
# SQURPHARMA  -0.004568  0.655747                  0.688116   0.04069
# EXIM1STMF   -0.050231  0.636250                  1.621929   0.13881
# BXPHARMA    -0.034346  0.622868                   1.63482  0.159302
# EHL          0.148566  0.606344                  3.570115  0.323606
# SINGERBD    -0.037388  0.592982                   0.78148  0.080141
# BATBC       -0.006071  0.587075                   0.95527  0.098415
# RECKITTBEN   0.027168  0.586944                  0.999348  0.078226
# WALTONHIL   -0.053761  0.583316                  0.959647  0.098522
# UNIQUEHRL    0.140512  0.581925                  2.816488  0.163694
# SUMITPOWER  -0.045036  0.574524                  1.018144  0.115609
# BEXIMCO      0.038092  0.572404                   1.81161  0.155263
# ACI         -0.001815  0.562289                  1.234621  0.067029
# GP          -0.042731  0.548361                  0.732436   0.10676
# MARICO       0.026776  0.544303                  0.484062  0.026516
# BSCCL        0.051038  0.540078                  1.592611  0.073559
# HFL         -0.003505  0.535081                  3.301992   0.15266
# AMANFEED    -0.080084  0.507632                  2.418877  0.288387
# EXIMBANK    -0.009682  0.502497                   1.04785  0.092481
# ACIFORMULA   0.024153  0.502235                  2.001053  0.061459
# ITC          0.017373  0.499428                  2.362658  0.089388
# JMISMDL     -0.049989  0.483849                   2.51211   0.16154
# SQUARETEXT   0.097826  0.483628                  1.629813  0.127229
# SAPORTL     -0.003598  0.475922                  2.679893  0.089735
# APEXFOODS    0.248719  0.473915                  3.600466   0.35195
# IFILISLMF1    -0.0125  0.473343                    1.4177  0.040233
# SIMTEX       0.025189  0.472564                   2.66675  0.139798
# BENGALWTL    0.063399  0.472445                  2.880733  0.165258
# IBNSINA         0.032  0.469804                  1.209147  0.052104
# BERGERPBL    0.002414  0.451449                  0.850651  0.021289
# ISLAMIBANK   0.034329  0.439170                  0.882594  0.045067
# RENATA      -0.010688  0.435385                  0.689243  0.055603
# KDSALTD       0.09616  0.429144                  2.302165  0.166908
# AIBL1STIMF  -0.052131  0.424913                  0.882728  0.094244
# OLYMPIC     -0.025179  0.421570                   1.91826  0.150594
# INDEXAGRO   -0.013481  0.419195                  2.638704  0.094047
# RAKCERAMIC   0.032747  0.418793                  1.947395  0.087895
# FORTUNE      0.116135  0.390827                  2.373092  0.248283
# ADNTEL       0.197013  0.385006                   3.19347  0.388305
# DELTALIFE    0.066115  0.365383                  2.774035  0.164745
# SKICL        0.374244  0.338504                   3.42844   0.21096
# JHRML        0.432283  0.330419                  4.149864  0.214182
# UNILEVERCL  -0.059034  0.258776                  2.534035  0.097984

# %%
plt.scatter(pct_change['UPGDCL'],pct_change['BXPHARMA'])

# %%
stats.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Statistics.xlsx")

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).cumsum().plot(figsize=(12.2,6.4),legend=False)

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).mean()
# Out:
# ISLAMIBANK    0.000343
# RAKCERAMIC    0.000327
# BATBC        -0.000061
# RENATA       -0.000107
# MARICO        0.000268
# SINGERBD     -0.000374
# LINDEBD       0.000145
# SUMITPOWER   -0.000450
# BERGERPBL     0.000024
# BXPHARMA     -0.000343
# SQURPHARMA   -0.000046
# SAPORTL      -0.000036
# BSCCL         0.000510
# GP           -0.000427
# SQUARETEXT    0.000978
# OLYMPIC      -0.000252
# BEXIMCO       0.000381
# HFL          -0.000035
# UPGDCL       -0.000340
# DELTALIFE     0.000661
# BENGALWTL     0.000634
# EHL           0.001486
# IBNSINA       0.000320
# WALTONHIL    -0.000538
# UNIQUEHRL     0.001405
# UNILEVERCL   -0.000590
# KDSALTD       0.000962
# JHRML         0.004323
# ADNTEL        0.001970
# ITC           0.000174
# SIMTEX        0.000252
# APEXFOODS     0.002487
# FORTUNE       0.001161
# INDEXAGRO    -0.000135
# AMANFEED     -0.000801
# SKICL         0.003742
# ACI          -0.000018
# ACIFORMULA    0.000242
# EXIMBANK     -0.000097
# IFILISLMF1   -0.000125
# AIBL1STIMF   -0.000521
# EXIM1STMF    -0.000502
# RECKITTBEN    0.000272
# JMISMDL      -0.000500
# dtype: float64

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).std()
# Out:
# ISLAMIBANK    0.008826
# RAKCERAMIC    0.019474
# BATBC         0.009553
# RENATA        0.006892
# MARICO        0.004841
# SINGERBD      0.007815
# LINDEBD       0.012617
# SUMITPOWER    0.010181
# BERGERPBL     0.008507
# BXPHARMA      0.016348
# SQURPHARMA    0.006881
# SAPORTL       0.026799
# BSCCL         0.015926
# GP            0.007324
# SQUARETEXT    0.016298
# OLYMPIC       0.019183
# BEXIMCO       0.018116
# HFL           0.033020
# UPGDCL        0.008241
# DELTALIFE     0.027740
# BENGALWTL     0.028807
# EHL           0.035701
# IBNSINA       0.012091
# WALTONHIL     0.009596
# UNIQUEHRL     0.028165
# UNILEVERCL    0.025340
# KDSALTD       0.023022
# JHRML         0.041499
# ADNTEL        0.031935
# ITC           0.023627
# SIMTEX        0.026668
# APEXFOODS     0.036005
# FORTUNE       0.023731
# INDEXAGRO     0.026387
# AMANFEED      0.024189
# SKICL         0.034284
# ACI           0.012346
# ACIFORMULA    0.020011
# EXIMBANK      0.010478
# IFILISLMF1    0.014177
# AIBL1STIMF    0.008827
# EXIM1STMF     0.016219
# RECKITTBEN    0.009993
# JMISMDL       0.025121
# dtype: float64

# %%
plt.figure(figsize = (30,30))
pic=plt.imread("Modern portfolio theory.png")
plt.imshow(pic)
plt.axis('off')
plt.show()

# %%
# vector is weights
W=np.array([1/len(sets.columns) for i in range(len(sets.columns))])#creating equal weighted portfolio
W
# Out:
# array([0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727, 0.02272727,
#        0.02272727, 0.02272727, 0.02272727, 0.02272727])

# %%
portfolio_ret=np.log(sets[sets.columns]/sets[sets.columns].shift(1))

# %%
portfolio_ret.mean()
# Out:
# ISLAMIBANK    0.000343
# RAKCERAMIC    0.000327
# BATBC        -0.000061
# RENATA       -0.000107
# MARICO        0.000268
# SINGERBD     -0.000374
# LINDEBD       0.000145
# SUMITPOWER   -0.000450
# BERGERPBL     0.000024
# BXPHARMA     -0.000343
# SQURPHARMA   -0.000046
# SAPORTL      -0.000036
# BSCCL         0.000510
# GP           -0.000427
# SQUARETEXT    0.000978
# OLYMPIC      -0.000252
# BEXIMCO       0.000381
# HFL          -0.000035
# UPGDCL       -0.000340
# DELTALIFE     0.000661
# BENGALWTL     0.000634
# EHL           0.001486
# IBNSINA       0.000320
# WALTONHIL    -0.000538
# UNIQUEHRL     0.001405
# UNILEVERCL   -0.000590
# KDSALTD       0.000962
# JHRML         0.004323
# ADNTEL        0.001970
# ITC           0.000174
# SIMTEX        0.000252
# APEXFOODS     0.002487
# FORTUNE       0.001161
# INDEXAGRO    -0.000135
# AMANFEED     -0.000801
# SKICL         0.003742
# ACI          -0.000018
# ACIFORMULA    0.000242
# EXIMBANK     -0.000097
# IFILISLMF1   -0.000125
# AIBL1STIMF   -0.000521
# EXIM1STMF    -0.000502
# RECKITTBEN    0.000272
# JMISMDL      -0.000500
# dtype: float64

# %%
0.000336*0.02702703
# Out:
# 9.08108208e-06

# %%
(W*portfolio_ret.mean()).sum()*252
# Out:
# 0.09604404776467869

# %%
portfolio_ret.mean().dot(W)*252
# Out:
# 0.09604404776467866

# %%
W.dot(portfolio_ret.mean())
# Out:
# 0.00038112717366935975

# %%
len(portfolio_ret.mean())
# Out:
# 44

# %%
portfolio_ret.cov()
# Out:
#               ISLAMIBANK    RAKCERAMIC     BATBC        RENATA        MARICO  \
# ISLAMIBANK  7.789723e-05  4.981913e-07  0.000005 -1.292068e-05  3.784510e-06
# RAKCERAMIC  4.981913e-07  3.792346e-04  0.000040  9.659274e-06  1.453152e-05
# BATBC       4.719006e-06  4.002430e-05  0.000091  1.204276e-05  1.010078e-05
# RENATA     -1.292068e-05  9.659274e-06  0.000012  4.750558e-05  5.974563e-06
# MARICO      3.784510e-06  1.453152e-05  0.000010  5.974563e-06  2.343158e-05
# SINGERBD    5.720555e-06  1.454996e-05  0.000015  5.435659e-06  8.411984e-06
# LINDEBD     8.599516e-06  5.136709e-05  0.000036  7.810420e-06  9.327398e-06
# SUMITPOWER  2.922563e-06  4.792218e-05  0.000029  1.718390e-05  7.633217e-06
# BERGERPBL   4.614282e-07  5.969259e-06  0.000012  9.336459e-06  1.227081e-05
# BXPHARMA    1.335508e-05  7.168232e-05  0.000040  1.361680e-05  8.881448e-06
# SQURPHARMA  9.430724e-06  3.159757e-05  0.000022  3.449580e-06  6.987416e-06
# SAPORTL     1.694397e-05  1.554563e-04  0.000027  8.325120e-06  7.916969e-06
# BSCCL       4.846243e-06  8.067520e-05  0.000039  1.388239e-05  1.163572e-05
# GP          2.613519e-06  2.710652e-05  0.000019  4.040196e-06  8.403471e-06
# SQUARETEXT  1.893486e-05  9.860142e-05  0.000035  2.856317e-06  5.133415e-06
# OLYMPIC     8.555868e-06  5.994360e-05  0.000032  1.056511e-05  7.273301e-06
# BEXIMCO     4.168430e-06  7.180530e-05  0.000029  1.508925e-05  8.308508e-06
# HFL         8.150494e-06  1.111190e-04 -0.000001  7.709284e-06  2.012997e-06
# UPGDCL      7.349393e-06  4.370361e-05  0.000019  9.468059e-06  7.483375e-06
# DELTALIFE   1.923241e-05  6.067200e-05  0.000042  1.519746e-05  2.382009e-05
# BENGALWTL   1.161085e-05  8.075424e-05  0.000039  1.281596e-05  1.503975e-05
# EHL         3.225385e-06  1.554396e-04  0.000045  2.669040e-05  8.022662e-06
# IBNSINA     1.275180e-05  4.391431e-05  0.000010  4.572857e-06  4.897921e-06
# WALTONHIL   5.993135e-07  4.067923e-05  0.000031  1.240182e-05  1.644808e-05
# UNIQUEHRL  -2.256667e-06  1.331729e-04  0.000030  2.309406e-05  5.368745e-06
# UNILEVERCL  4.007635e-06  2.626090e-05  0.000024  8.423975e-06  1.260737e-05
# KDSALTD     1.164010e-05  1.446828e-04  0.000040 -5.357855e-06  5.037871e-06
# AIBL1STIMF    0.000032  7.792082e-05  5.973358e-05  5.429273e-07  0.000006
# EXIM1STMF     0.000067  5.973358e-05  2.630653e-04  1.378865e-05  0.000036
# RECKITTBEN    0.000007  5.429273e-07  1.378865e-05  9.986971e-05  0.000017
# JMISMDL       0.000009  6.151034e-06  3.562903e-05  1.671235e-05  0.000631
#
# [44 rows x 44 columns]

# %%
(W.T.dot((portfolio_ret.cov()*252).dot(W)))**(1/2)
# Out:
# 0.12179975860505902

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).std()
# Out:
# ISLAMIBANK    0.008826
# RAKCERAMIC    0.019474
# BATBC         0.009553
# RENATA        0.006892
# MARICO        0.004841
# SINGERBD      0.007815
# LINDEBD       0.012617
# SUMITPOWER    0.010181
# BERGERPBL     0.008507
# BXPHARMA      0.016348
# SQURPHARMA    0.006881
# SAPORTL       0.026799
# BSCCL         0.015926
# GP            0.007324
# SQUARETEXT    0.016298
# OLYMPIC       0.019183
# BEXIMCO       0.018116
# HFL           0.033020
# UPGDCL        0.008241
# DELTALIFE     0.027740
# BENGALWTL     0.028807
# EHL           0.035701
# IBNSINA       0.012091
# WALTONHIL     0.009596
# UNIQUEHRL     0.028165
# UNILEVERCL    0.025340
# KDSALTD       0.023022
# JHRML         0.041499
# ADNTEL        0.031935
# ITC           0.023627
# SIMTEX        0.026668
# APEXFOODS     0.036005
# FORTUNE       0.023731
# INDEXAGRO     0.026387
# AMANFEED      0.024189
# SKICL         0.034284
# ACI           0.012346
# ACIFORMULA    0.020011
# EXIMBANK      0.010478
# IFILISLMF1    0.014177
# AIBL1STIMF    0.008827
# EXIM1STMF     0.016219
# RECKITTBEN    0.009993
# JMISMDL       0.025121
# dtype: float64

# %%
def sharpe_pf(W,portfolio_ret):
    pf_risk=(W.T.dot(portfolio_ret.cov().dot(W)))**(1/2)
    SR=W.dot(portfolio_ret.mean())/pf_risk
    return(SR)

# %%
sharpe_pf(W,portfolio_ret)
# Out:
# 0.049673385118326537

# %%
weights=np.random.random(len(sets.columns))
weights/=np.sum(weights)

# %%
weights[2]
# Out:
# 0.005879459795832593

# %%
len(weights)
# Out:
# 44

# %%
weights.sum()
# Out:
# 0.9999999999999999

# %%
returns=np.log(sets[sets.columns]/sets[sets.columns].shift(1))
mean_ret=portfolio_ret.mean()*252
mean_ret
# Out:
# ISLAMIBANK    0.086510
# RAKCERAMIC    0.082523
# BATBC        -0.015299
# RENATA       -0.026935
# MARICO        0.067475
# SINGERBD     -0.094219
# LINDEBD       0.036613
# SUMITPOWER   -0.113492
# BERGERPBL     0.006082
# BXPHARMA     -0.086553
# SQURPHARMA   -0.011511
# SAPORTL      -0.009068
# BSCCL         0.128617
# GP           -0.107683
# SQUARETEXT    0.246522
# OLYMPIC      -0.063451
# BEXIMCO       0.095992
# HFL          -0.008832
# UPGDCL       -0.085686
# DELTALIFE     0.166611
# BENGALWTL     0.159765
# EHL           0.374387
# IBNSINA       0.080639
# WALTONHIL    -0.135477
# UNIQUEHRL     0.354091
# AMANFEED     0.017063    0.008505  0.020419
# SKICL        0.018523    0.003461  0.015945
# ACI          0.006264    0.001115  0.014974
# ACIFORMULA   0.005158    0.006169  0.032058
# EXIMBANK     0.012932    0.002526  0.001734
# IFILISLMF1   0.016929    0.001696  0.002261
# AIBL1STIMF   0.015053    0.000137  0.001550
# EXIM1STMF    0.066292    0.003475  0.008979
# RECKITTBEN   0.003475    0.025167  0.004212
# JMISMDL      0.008979    0.004212  0.159030
#
# [44 rows x 44 columns]

# %%
weights.dot(returns.mean())*252 #yearly return
# Out:
# 0.07553175854872385

# %%
np.sqrt(weights.T.dot((portfolio_ret.cov()*252).dot(weights)))#yearly risk
# Out:
# 0.12617494240105798

# %%
p_ret = []#Return list of our random portfolio
p_vol = []#Volatility list of our random portfolio
p_sr = []#sharp ration to maximize profit and minimize risk(rate of return- risk free rate)/standard deviation
p_wt = []#weights

for x in range(30000):
    p_weights=np.random.random(len(sets.columns))
    p_weights/=np.sum(p_weights)
    ret_1=p_weights.dot(returns.mean())*252
    p_ret.append(ret_1)
    vol_1 = np.sqrt(p_weights.T.dot((portfolio_ret.cov()*252).dot(p_weights)))
    p_vol.append(vol_1)
    SR_1 = (ret_1-0.06)/vol_1
    p_sr.append(SR_1)
    p_wt.append(p_weights)
p_ret = np.array(p_ret)
p_vol = np.array(p_vol)
p_SR = np.array(p_sr)
p_wt = np.array(p_wt)

    
p_ret,p_vol,p_SR,p_wt
# Out:
# (array([0.07553506, 0.07906691, 0.08948832, ..., 0.08397351, 0.09994802,
#         0.11030379]),
#  array([0.11991122, 0.12958588, 0.1225129 , ..., 0.11558442, 0.12247636,
#         0.1231383 ]),
#  array([0.12955467, 0.14713726, 0.24069563, ..., 0.20741128, 0.32616921,
#         0.40851454]),
#  array([[0.00893128, 0.01479309, 0.02481836, ..., 0.03686919, 0.00102618,
#          0.03486401],
#         [0.0146023 , 0.02970037, 0.00815914, ..., 0.00200653, 0.0386923 ,
#          0.02325778],
#         [0.02716475, 0.03250919, 0.03268503, ..., 0.03976598, 0.03565815,
#          0.01581277],
#         ...,
#         [0.02905786, 0.02189039, 0.03804125, ..., 0.04510934, 0.02384986,
#          0.00800739],
#         [0.02283067, 0.05165469, 0.05221211, ..., 0.03233286, 0.05458133,
#          0.02879982],
#         [0.03966514, 0.02714238, 0.03278235, ..., 0.03560081, 0.01307625,
#          0.00556231]]))

# %%
ports = pd.DataFrame({'Returns' : p_ret, 'volatility' :p_vol})
ports
# Out:
#         Returns  volatility
# 0      0.075535    0.119911
# 1      0.079067    0.129586
# 2      0.089488    0.122513
# 3      0.099335    0.124190
# 4      0.121924    0.125714
# ...         ...         ...
# 29995  0.108130    0.136096
# 29996  0.079880    0.119264
# 29997  0.083974    0.115584
# 29998  0.099948    0.122476
# 29999  0.110304    0.123138
#
# [30000 rows x 2 columns]

# %%
ports.plot(x='volatility', y ='Returns', kind='scatter',figsize=(16,9))
plt.scatter(x=0.11388582770213351,y=0.10727701366332347,color="Red",marker='+')
#plt.scatter(x=0.294,y=1.1,color="Red",marker='+')
plt.show()

# %%
SR_IDX=np.argmax(p_SR)
SR_IDX
# Out:
# 24869

# %%
i=0
while i < len(sets.columns):
    print('Stock : %s : %2.2f'%(sets.columns[i],(p_wt[SR_IDX][i]*100)))
    i+=1
print('\nVolatility :',p_vol[SR_IDX])
print('Return :',p_ret[SR_IDX])
# Out:
# Stock : ISLAMIBANK : 4.58
# Stock : RAKCERAMIC : 2.45
# Stock : BATBC : 1.23
# Stock : RENATA : 0.72
# Stock : MARICO : 4.53
# Stock : SINGERBD : 0.07
# Stock : LINDEBD : 1.01
# Stock : SUMITPOWER : 1.56
# Stock : BERGERPBL : 0.63
# Stock : BXPHARMA : 2.88
# Stock : SQURPHARMA : 5.92
# Stock : SAPORTL : 0.78
# Stock : BSCCL : 3.92
# Stock : GP : 1.83
# Stock : SQUARETEXT : 3.84
# Stock : OLYMPIC : 0.92
# Stock : BEXIMCO : 5.52
# Stock : HFL : 0.76
# Stock : UPGDCL : 2.13
# Stock : DELTALIFE : 4.71
# Stock : BENGALWTL : 1.54
# Stock : EHL : 1.42
# Stock : IBNSINA : 2.62
# Stock : WALTONHIL : 0.23
# Stock : UNIQUEHRL : 1.65
# Stock : UNILEVERCL : 1.78
# Stock : KDSALTD : 5.33
# Stock : JHRML : 4.43
# Stock : ADNTEL : 5.01
# Stock : ITC : 1.15
# Stock : SIMTEX : 1.61
# Stock : APEXFOODS : 5.23
# Stock : FORTUNE : 0.23
# Stock : INDEXAGRO : 1.77
# Stock : AMANFEED : 0.38
# Stock : SKICL : 3.28
# Stock : ACI : 1.40
# Stock : ACIFORMULA : 0.69
# Stock : EXIMBANK : 4.39
# Stock : IFILISLMF1 : 0.28
# Stock : AIBL1STIMF : 0.33
# Stock : EXIM1STMF : 0.86
# Stock : RECKITTBEN : 2.99
# Stock : JMISMDL : 1.41
#
# Volatility : 0.13417857217829482
# Return : 0.18853884426991796

# %%
p_wt[SR_IDX].sum()
# Out:
# 0.9999999999999997

# %%
m=pd.DataFrame(columns=['Weights'],index=[sets.columns])
m['Weights']=p_wt[SR_IDX]*100

# %%
len(m['Weights'])
# Out:
# 44

# %%
m.loc['ISLAMIBANK','Weights']=2
m.loc['RAKCERAMIC','Weights']=1
m.loc['BATBC','Weights']=2
m.loc['RENATA','Weights']=3
m.loc['MARICO','Weights']=2
m.loc['SINGERBD','Weights']=1
m.loc['LINDEBD','Weights']=6
m.loc['SUMITPOWER','Weights']=1
m.loc['BERGERPBL','Weights']=5
m.loc['BXPHARMA','Weights']=1
m.loc['SQURPHARMA','Weights']=3
m.loc['SAPORTL','Weights']=1
m.loc['BSCCL','Weights']=2
m.loc['GP','Weights']=3
m.loc['SQUARETEXT','Weights']=1
m.loc['OLYMPIC','Weights']=3
m.loc['BEXIMCO','Weights']=3
m.loc['HFL','Weights']=1
m.loc['UPGDCL','Weights']=4
m.loc['DELTALIFE','Weights']=3
m.loc['BENGALWTL','Weights']=2
m.loc['EHL','Weights']=4
m.loc['IBNSINA','Weights']=3
m.loc['WALTONHIL','Weights']=1
m.loc['UNIQUEHRL','Weights']=2
m.loc['UNILEVERCL','Weights']=3
m.loc['KDSALTD','Weights']=1
m.loc['JHRML','Weights']=1
m.loc['ADNTEL','Weights']=2
m.loc['ITC','Weights']=2
m.loc['SIMTEX','Weights']=1
m.loc['APEXFOODS','Weights']=2
m.loc['FORTUNE','Weights']=3
m.loc['INDEXAGRO','Weights']=1.5
m.loc['AMANFEED','Weights']=1.5
m.loc['SKICL','Weights']=4
m.loc['ACI','Weights']=1.5
m.loc['ACIFORMULA','Weights']=1.5
m.loc['EXIMBANK' ,'Weights']=3
m.loc['IFILISLMF1','Weights']=3
m.loc['AIBL1STIMF','Weights']=2
m.loc['EXIM1STMF','Weights']=2
m.loc['RECKITTBEN','Weights']=3
m.loc['JMISMDL','Weights']=2

# %%
m['Weights'].sum()
# Out:
# 100.0

# %%
m
# Out:
#             Weights
# ISLAMIBANK      2.0
# RAKCERAMIC      1.0
# BATBC           2.0
# RENATA          3.0
# MARICO          2.0
# SINGERBD        1.0
# LINDEBD         6.0
# SUMITPOWER      1.0
# BERGERPBL       5.0
# BXPHARMA        1.0
# SQURPHARMA      3.0
# SAPORTL         1.0
# BSCCL           2.0
# GP              3.0
# SQUARETEXT      1.0
# OLYMPIC         3.0
# BEXIMCO         3.0
# HFL             1.0
# UPGDCL          4.0
# DELTALIFE       3.0
# BENGALWTL       2.0
# EHL             4.0
# IBNSINA         3.0
# WALTONHIL       1.0
# UNIQUEHRL       2.0
# UNILEVERCL      3.0
# KDSALTD         1.0
# JHRML           1.0
# ADNTEL          2.0
# ITC             2.0
# SIMTEX          1.0
# APEXFOODS       2.0
# FORTUNE         3.0
# INDEXAGRO       1.5
# AMANFEED        1.5
# SKICL           4.0
# ACI             1.5
# ACIFORMULA      1.5
# EXIMBANK        3.0
# IFILISLMF1      3.0
# AIBL1STIMF      2.0
# EXIM1STMF       2.0
# RECKITTBEN      3.0
# JMISMDL         2.0

# %%
np.sqrt((m['Weights'].values/100).T.dot((portfolio_ret.cov()*252).dot(m['Weights'].values/100)))
# Out:
# 0.11381252490653171

# %%
(m['Weights'].values/100).dot(returns.mean())*252 #yearly return
# Out:
# 0.10183474452469753

# %%
m.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Weights.xlsx")

# %%
def price(sdate,edate):
    df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
    mask = (df.index >= sdate) & (df.index <= edate)
    return(df.loc[mask])
price('2021-06-13','2021-06-13')
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4    NaN  262.5
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
#
# [1 rows x 44 columns]

# %%
sets
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
# 2021-06-14        27.5        35.2  532.9  1284.6  2117.7     180.0   1297.1
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-07        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-13        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4    NaN  262.5
# 2021-06-14        42.7     1743.1     170.8  ...      47.2    NaN  269.1
# 2021-06-15        42.6     1772.2     171.0  ...      48.1    NaN  269.7
# 2021-06-16        42.7     1775.1     170.8  ...      48.4    NaN  263.7
# 2021-06-17        44.3     1770.2     174.9  ...      48.6    NaN  263.5
# ...                ...        ...       ...  ...       ...    ...    ...
# 2023-06-07        34.0     1788.4     146.2  ...      33.5   49.8  260.2
# 2023-06-08        34.0     1787.4     146.2  ...      33.5   48.9  260.2
# 2023-06-11        34.0     1776.4     146.2  ...      33.5   48.7  260.2
# 2023-06-12        34.0     1767.9     146.2  ...      33.5   47.7  260.2
# 2023-06-13        34.0     1770.1     146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
# 2021-06-14       144.4      11.0         6.7         9.2        7.1
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
# 2021-06-16       145.0      10.8         6.7         9.2        7.1
# 2021-06-17       143.0      10.8         6.7         9.1        7.2
# ...                ...       ...         ...         ...        ...
# 2023-06-07       157.5      10.4         6.4         7.3        5.8
# 2023-06-08       159.7      10.4         6.4         7.3        5.8
# 2023-06-11       159.7      10.4         6.4         7.3        5.8
# 2023-06-12       157.5      10.4         6.4         7.3        5.8
# 2023-06-13       156.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
# 2021-06-14      4219.3    326.4
# 2021-06-15      4245.3    323.3
# 2021-06-16      4269.4    320.6
# 2021-06-17      4301.0    320.1
# ...                ...      ...
# 2023-06-07      4836.2    255.5
# 2023-06-08      4826.7    255.5
# 2023-06-11      4795.2    255.5
# 2023-06-12      4802.2    255.5
# 2023-06-13      4814.8    255.5
#
# [486 rows x 44 columns]

# %%
wt=(500000/100)*(m.loc['ISLAMIBANK'].values)
quantity=float(wt)/float(price('2023-06-08','2023-06-08')['ISLAMIBANK'].values)
round(quantity)*float(price('2023-06-08','2023-06-08')['ISLAMIBANK'].values)
# Out:
# 10008.2

# %%
sdate,edate='2022-05-12','2022-05-12'
def price(sdate,edate):
    df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
    df=df.fillna(method='bfill',axis='rows')
    mask = (df.index >= sdate) & (df.index <= edate)
    return(df.loc[mask])
price('2021-06-13','2021-06-13')
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4   11.0  262.5
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
#
# [1 rows x 44 columns]

# %%
sdate,edate='2021-06-13','2021-06-13'

# %%
def my_port(investment,m):
    Q=[]
    P=[]
    T=[]
    m=m
    pr=price(sdate,edate)
    for i in sets.columns:
        wt=(investment/ m['Weights'].sum())*(m.loc[i].values)
        Q.append(round(float(wt)/float(pr[i].values)))
        P.append(float(pr[i].values))
        T.append(round(float(wt)/float(pr[i].values))*float(pr[i].values))
    return(Q,P,T)

# %%
my_port(500000,m)
# Out:
# ([362,
#   137,
#   19,
#   12,
#   5,
#   27,
#   23,
#   118,
#   14,
#   29,
#   70,
#   173,
#   59,
#   43,
#   119,
#   88,
#   156,
#   281,
#   73,
#   146,
#   500,
#   427,
#   61,
#   4,
#   290,
#   5,
#   104,
#   227,
#   194,
#   275,
#   282,
#   80,
#   348,
#   68,
#   152,
#   1818,
#   29,
#   54,
#   1376,
#   2206,
#   1064,
#   1351,
#   4,
#   31],
#  [27.6,
#   36.6,
#   534.2,
#   1282.7,
#   2126.6,
#   182.1,
#   1302.6,
#   42.3,
#   1749.5,
#   172.7,
#   214.5,
#   28.9,
#   170.9,
#   352.6,
#   42.0,
#   170.5,
#   96.1,
#   17.8,
#   275.6,
#   102.9,
#   20.0,
#   46.8,
#   245.4,
#   1359.8,
#   34.5,
#   2729.2,
#   48.3,
#   22.0,
#   51.5,
#   36.4,
#   17.7,
#   125.2,
#   43.1,
#   110.6,
#   49.4,
#   11.0,
#   262.5,
#   139.2,
#   10.9,
#   6.8,
#   9.4,
#   7.4,
#   4220.4,
#   325.6],
#  [9991.2,
#   5014.2,
#   10149.800000000001,
#   15392.400000000001,
#   10633.0,
#   4916.7,
#   29959.8,
#   4991.4,
#   24493.0,
#   5008.299999999999,
#   15015.0,
#   4999.7,
#   10083.1,
#   15161.800000000001,
#   4998.0,
#   15004.0,
#   14991.599999999999,
#   5001.8,
#   20118.800000000003,
#   15023.400000000001,
#   10000.0,
#   19983.6,
#   14969.4,
#   5439.2,
#   10005.0,
#   13646.0,
#   5023.2,
#   4994.0,
#   9991.0,
#   10010.0,
#   4991.4,
#   10016.0,
#   14998.800000000001,
#   7520.799999999999,
#   7508.8,
#   19998.0,
#   7612.5,
#   7516.799999999999,
#   14998.4,
#   15000.8,
#   10001.6,
#   9997.4,
#   16881.6,
#   10093.6])

# %%
lists=pd.DataFrame()

# %%
lists=pd.DataFrame(columns=['Ouantity','Price','Total'],index=[sets.columns])
lists['Ouantity']=my_port(1000000,m)[0]
lists['Price']=my_port(1000000,m)[1]
lists['Total']=my_port(1000000,m)[2]
lists#['Total'].sum()
# Out:
#             Ouantity   Price    Total
# ISLAMIBANK       725    27.6  20010.0
# RAKCERAMIC       273    36.6   9991.8
# BATBC             37   534.2  19765.4
# RENATA            23  1282.7  29502.1
# MARICO             9  2126.6  19139.4
# SINGERBD          55   182.1  10015.5
# LINDEBD           46  1302.6  59919.6
# SUMITPOWER       236    42.3   9982.8
# BERGERPBL         29  1749.5  50735.5
# BXPHARMA          58   172.7  10016.6
# SQURPHARMA       140   214.5  30030.0
# SAPORTL          346    28.9   9999.4
# BSCCL            117   170.9  19995.3
# GP                85   352.6  29971.0
# SQUARETEXT       238    42.0   9996.0
# OLYMPIC          176   170.5  30008.0
# BEXIMCO          312    96.1  29983.2
# HFL              562    17.8  10003.6
# UPGDCL           145   275.6  39962.0
# DELTALIFE        292   102.9  30046.8
# BENGALWTL       1000    20.0  20000.0
# EHL              855    46.8  40014.0
# IBNSINA          122   245.4  29938.8
# WALTONHIL          7  1359.8   9518.6
# UNIQUEHRL        580    34.5  20010.0
# UNILEVERCL        11  2729.2  30021.2
# KDSALTD          207    48.3   9998.1
# JHRML            455    22.0  10010.0
# ADNTEL           388    51.5  19982.0
# ITC              549    36.4  19983.6
# SIMTEX           565    17.7  10000.5
# APEXFOODS        160   125.2  20032.0
# FORTUNE          696    43.1  29997.6
# INDEXAGRO        136   110.6  15041.6
# AMANFEED         304    49.4  15017.6
# SKICL           3636    11.0  39996.0
# ACI               57   262.5  14962.5
# ACIFORMULA       108   139.2  15033.6
# EXIMBANK        2752    10.9  29996.8
# IFILISLMF1      4412     6.8  30001.6
# AIBL1STIMF      2128     9.4  20003.2
# EXIM1STMF       2703     7.4  20002.2
# RECKITTBEN         7  4220.4  29542.8
# JMISMDL           61   325.6  19861.6

# %%
n=((lists['Total']/997658.2999999999)*100).values
n
# Out:
# array([2.00569674, 1.00152527, 1.98117933, 2.95713472, 1.91843239,
#        1.00390083, 6.00602431, 1.00062316, 5.08545862, 1.00401109,
#        3.01004863, 1.00228706, 2.00422329, 3.00413478, 1.00194626,
#        3.00784347, 3.00535765, 1.00270804, 4.00557987, 3.01173257,
#        2.00469439, 4.01079207, 3.00090722, 0.9540942 , 2.00569674,
#        3.00916657, 1.00215675, 1.00334954, 2.00289017, 2.00305054,
#        1.00239731, 2.0079019 , 3.00680103, 1.50769056, 1.50528493,
#        4.00898785, 1.49976199, 1.50688868, 3.00672084, 3.00720196,
#        2.00501514, 2.00491491, 2.96121428, 1.99082191])

# %%
(n/100).dot(returns.mean())*252 #yearly return
# Out:
# 0.10210866832648596

# %%
np.sqrt((n/100).T.dot((portfolio_ret.cov()*252).dot(n/100)))
# Out:
# 0.11401078124392307

# %%
lists['Total'].sum()
# Out:
# 998039.9

# %%
df=pd.read_excel('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx',index_col='date')

# %%
df.isnull().sum()
# Out:
# ISLAMIBANK      0
# RAKCERAMIC      0
# BATBC           0
# RENATA          0
# MARICO          0
# SINGERBD        0
# LINDEBD         0
# SUMITPOWER      0
# BERGERPBL       0
# BXPHARMA        0
# SQURPHARMA      0
# SAPORTL         0
# BSCCL           0
# GP              0
# SQUARETEXT      0
# OLYMPIC         0
# BEXIMCO         0
# HFL             0
# UPGDCL          0
# DELTALIFE       0
# BENGALWTL       0
# EHL             0
# IBNSINA         0
# WALTONHIL       0
# UNIQUEHRL       0
# UNILEVERCL      0
# KDSALTD         0
# JHRML         194
# ADNTEL          0
# ITC             0
# SIMTEX          0
# APEXFOODS       0
# FORTUNE         0
# INDEXAGRO       0
# AMANFEED        0
# SKICL          93
# ACI             0
# ACIFORMULA      0
# EXIMBANK        0
# IFILISLMF1      0
# AIBL1STIMF      0
# EXIM1STMF       0
# RECKITTBEN      0
# JMISMDL         0
# dtype: int64

# %%
df=df.fillna(method='bfill',axis='rows')
df
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-13        27.6        36.6  534.2  1282.7  2126.6     182.1   1302.6
# 2021-06-14        27.5        35.2  532.9  1284.6  2117.7     180.0   1297.1
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-07        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-13        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-13        42.3     1749.5     172.7  ...      49.4   11.0  262.5
# 2021-06-14        42.7     1743.1     170.8  ...      47.2   11.0  269.1
# 2021-06-15        42.6     1772.2     171.0  ...      48.1   11.0  269.7
# 2021-06-16        42.7     1775.1     170.8  ...      48.4   11.0  263.7
# 2021-06-17        44.3     1770.2     174.9  ...      48.6   11.0  263.5
# ...                ...        ...       ...  ...       ...    ...    ...
# 2023-06-07        34.0     1788.4     146.2  ...      33.5   49.8  260.2
# 2023-06-08        34.0     1787.4     146.2  ...      33.5   48.9  260.2
# 2023-06-11        34.0     1776.4     146.2  ...      33.5   48.7  260.2
# 2023-06-12        34.0     1767.9     146.2  ...      33.5   47.7  260.2
# 2023-06-13        34.0     1770.1     146.2  ...      33.5   47.7  260.2
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-13       139.2      10.9         6.8         9.4        7.4
# 2021-06-14       144.4      11.0         6.7         9.2        7.1
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
# 2021-06-16       145.0      10.8         6.7         9.2        7.1
# 2021-06-17       143.0      10.8         6.7         9.1        7.2
# ...                ...       ...         ...         ...        ...
# 2023-06-07       157.5      10.4         6.4         7.3        5.8
# 2023-06-08       159.7      10.4         6.4         7.3        5.8
# 2023-06-11       159.7      10.4         6.4         7.3        5.8
# 2023-06-12       157.5      10.4         6.4         7.3        5.8
# 2023-06-13       156.5      10.4         6.4         7.3        5.8
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-13      4220.4    325.6
# 2021-06-14      4219.3    326.4
# 2021-06-15      4245.3    323.3
# 2021-06-16      4269.4    320.6
# 2021-06-17      4301.0    320.1
# ...                ...      ...
# 2023-06-07      4836.2    255.5
# 2023-06-08      4826.7    255.5
# 2023-06-11      4795.2    255.5
# 2023-06-12      4802.2    255.5
# 2023-06-13      4814.8    255.5
#
# [486 rows x 44 columns]

# %%
df.isnull().sum()
# Out:
# ISLAMIBANK    0
# RAKCERAMIC    0
# BATBC         0
# RENATA        0
# MARICO        0
# SINGERBD      0
# LINDEBD       0
# SUMITPOWER    0
# BERGERPBL     0
# BXPHARMA      0
# SQURPHARMA    0
# SAPORTL       0
# BSCCL         0
# GP            0
# SQUARETEXT    0
# OLYMPIC       0
# BEXIMCO       0
# HFL           0
# UPGDCL        0
# DELTALIFE     0
# BENGALWTL     0
# EHL           0
# IBNSINA       0
# WALTONHIL     0
# UNIQUEHRL     0
# UNILEVERCL    0
# KDSALTD       0
# JHRML         0
# ADNTEL        0
# ITC           0
# SIMTEX        0
# APEXFOODS     0
# FORTUNE       0
# INDEXAGRO     0
# AMANFEED      0
# SKICL         0
# ACI           0
# ACIFORMULA    0
# EXIMBANK      0
# IFILISLMF1    0
# AIBL1STIMF    0
# EXIM1STMF     0
# RECKITTBEN    0
# JMISMDL       0
# dtype: int64

# %%
port=pd.DataFrame(columns=[df.columns],index=df.index)
port
# Out:
#            ISLAMIBANK RAKCERAMIC BATBC RENATA MARICO SINGERBD LINDEBD  \
# date
# 2021-06-13        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-14        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-15        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-16        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-17        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# ...               ...        ...   ...    ...    ...      ...     ...
# 2023-06-07        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-08        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-11        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-12        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-13        NaN        NaN   NaN    NaN    NaN      NaN     NaN
#
#            SUMITPOWER BERGERPBL BXPHARMA  ... AMANFEED SKICL  ACI ACIFORMULA  \
# date                                      ...
# 2021-06-13        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2021-06-14        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2021-06-15        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2021-06-16        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2021-06-17        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# ...               ...       ...      ...  ...      ...   ...  ...        ...
# 2023-06-07        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2023-06-08        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2023-06-11        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2023-06-12        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
# 2023-06-13        NaN       NaN      NaN  ...      NaN   NaN  NaN        NaN
#
#            EXIMBANK IFILISLMF1 AIBL1STIMF EXIM1STMF RECKITTBEN JMISMDL
# date
# 2021-06-13      NaN        NaN        NaN       NaN        NaN     NaN
# 2021-06-14      NaN        NaN        NaN       NaN        NaN     NaN
# 2021-06-15      NaN        NaN        NaN       NaN        NaN     NaN
# 2021-06-16      NaN        NaN        NaN       NaN        NaN     NaN
# 2021-06-17      NaN        NaN        NaN       NaN        NaN     NaN
# ...             ...        ...        ...       ...        ...     ...
# 2023-06-07      NaN        NaN        NaN       NaN        NaN     NaN
# 2023-06-08      NaN        NaN        NaN       NaN        NaN     NaN
# 2023-06-11      NaN        NaN        NaN       NaN        NaN     NaN
# 2023-06-12      NaN        NaN        NaN       NaN        NaN     NaN
# 2023-06-13      NaN        NaN        NaN       NaN        NaN     NaN
#
# [486 rows x 44 columns]

# %%
for i in port.index:
    for j in df.columns:
        port.loc[i,j]=df.loc[i,j]*lists.loc[j]['Ouantity'][0]
port['Total']=port.iloc[:,0:len(df.columns)].sum(axis=1)

# %%
port.index=pd.to_datetime(port.index)

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')
plt.figure(figsize=(8, 6), dpi=200)
plt.title('My Portfolio Tow Years Performance')
plt.plot(np.array(port.index),np.array(port['Total'].values))
plt.xlabel('years')
plt.ylabel('BDT')
plt.xticks(rotation=45)
plt.show()

# %%
np.log(port['Total']/port['Total'].shift(1)).describe()
# Out:
#             Total
# count  485.000000
# mean     0.000599
# std      0.009327
# min     -0.035113
# 25%     -0.004583
# 50%      0.000567
# 75%      0.005457
# max      0.034125
