# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from bdshare import get_basic_hist_data

# %%
df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Port_folio_draft.xlsx", index_col='Unnamed: 0')
df
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# RAKCERAMIC                  RAK Ceramics (Bangladesh) Limited
# SALAMCRST                     S. Alam Cold Rolled Steels Ltd.
# POWERGRID               Power Grid Company of Bangladesh Ltd.
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# MARICO                              Marico Bangladesh Limited
# SINGERBD                                Singer Bangladesh Ltd
# LINDEBD                                  Linde Bangladesh Ltd
# SUMITPOWER                                   Summit Power Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# SAPORTL                              Summit Alliance Port Ltd
# ...

# %%
df[df['Evaluation']=='P']
# Out:
#                                         Full Name              Sector  \
# SALAMCRST         S. Alam Cold Rolled Steels Ltd.         Engineering
# POWERGRID   Power Grid Company of Bangladesh Ltd.        Fuel & Power
# HEIDELBCEM       Heidelberg Cement Bangladesh Ltd              Cement
# BSRMSTEEL                         BSRM Steels Ltd        Iron & Steel
# BATASHOE            Bata Shoe Co (Bangladesh) Ltd  Tannery Industries
#  APEXSPINN     Apex Spinning & Knitting Mills Ltd             Textile
# CROWNCEMNT                       Crown Cement PLC              Cement
# APEXFOOT                       Apex Footwear Ltd.  Tannery Industries
# BPML                 Bashundhara Paper Mills Ltd.    Paper & Printing
#
#            Evaluation
# SALAMCRST           P
# POWERGRID           P
# HEIDELBCEM          P
# BSRMSTEEL           P
# BATASHOE            P
#  APEXSPINN          P
# CROWNCEMNT          P
# APEXFOOT            P
# BPML                P

# %%
df=df[~(df['Evaluation']=='P')]
df
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# RAKCERAMIC                  RAK Ceramics (Bangladesh) Limited
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# MARICO                              Marico Bangladesh Limited
# SINGERBD                                Singer Bangladesh Ltd
# LINDEBD                                  Linde Bangladesh Ltd
# SUMITPOWER                                   Summit Power Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# SAPORTL                              Summit Alliance Port Ltd
# BSCCL                         Bangladesh Submarine Cables PLC
# GP                                           Grameenphone Ltd
# ...

# %%
df[df['Evaluation']=='G']
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# LINDEBD                                  Linde Bangladesh Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# GP                                           Grameenphone Ltd
# OLYMPIC                        Olympic Industries Ltd OLYMPIC
# UPGDCL         United Power Generation & Distribution Co. Ltd
# DELTALIFE                      Green Delta Insurance Co. Ltd.
# IBNSINA                  IBN SINA Pharmaceutical Industry PLC
# WALTONHIL                      Walton Hi-Tech Industries Ltd.
# UNIQUEHRL                         Unique Hotel & Resorts Ltd.
# ...

# %%
df[df['Evaluation']=='M']
# Out:
#                                             Full Name  \
# RAKCERAMIC          RAK Ceramics (Bangladesh) Limited
# MARICO                      Marico Bangladesh Limited
# SINGERBD                        Singer Bangladesh Ltd
# SUMITPOWER                           Summit Power Ltd
# SAPORTL                      Summit Alliance Port Ltd
# BSCCL                 Bangladesh Submarine Cables PLC
# SQUARETEXT                         Square Textile Ltd
# BEXIMCO                                   BEXIMCO Ltd
# NATLIFEINS             National Life Insurance Co Ltd
# HFL                                 Hamid Fabrics Ltd
# BENGALWTL          Bengal Windsor Thermoplastics Ltd.
# EHL                              Eastern Housing Ltd.
# UNILEVERCL                Unilever Consumer Care Ltd.
# KDSALTD                          KDS Accessories Ltd.
# JHRML       JMI Hospital Requisite Manufacturing Ltd.
# SIMTEX                         Simtex Industries Ltd.
# ...

# %%
df.groupby('Evaluation')['Evaluation'].agg('count').sort_values(ascending=False)
# Out:
# Evaluation
# G    25
# M    20
# Name: Evaluation, dtype: int64

# %%
df.groupby('Sector')['Sector'].agg('count').sort_values(ascending=False)
# Out:
# Sector
# Pharmaceuticals & Chemicals    10
# Engineering                     4
# FOOD & Allied                   4
# Miscellaneous                   4
# Fuel & Power                    3
# Insurance                       3
# Mutual Fund                     3
# Textile                         3
# Bank                            2
# IT Sector                       2
# Services & Real Estate          2
# Telecommunication               2
# Ceramic                         1
# Tannery Industries              1
# Travel and Leisure              1
# Name: Sector, dtype: int64

# %%
ticker=[i for i in df.index.values]
ticker
# Out:
# ['ISLAMIBANK',
#  'RAKCERAMIC',
#  'BATBC',
#  'RENATA',
#  'MARICO',
#  'SINGERBD',
#  'LINDEBD',
#  'SUMITPOWER',
#  'BERGERPBL',
#  'BXPHARMA',
#  'SQURPHARMA',
#  'SAPORTL',
#  'BSCCL',
#  'GP',
#  'SQUARETEXT',
#  'OLYMPIC',
#  'BEXIMCO',
#  'NATLIFEINS',
#  'HFL',
#  'UPGDCL',
#  'DELTALIFE',
#  'BENGALWTL',
#  'EHL',
#  'IBNSINA',
#  'WALTONHIL',
#  'UNIQUEHRL',
#  'UNILEVERCL',
#  'KDSALTD',
#  'JHRML',
#  'ADNTEL',
#  'ITC',
#  'SIMTEX',
#  'APEXFOODS',
#  'FORTUNE',
#  'INDEXAGRO',
#  'AMANFEED',
#  'SKICL',
#  'ACI',
#  'ACIFORMULA',
#  'EXIMBANK',
#  'IFILISLMF1',
#  'AIBL1STIMF',
#  'EXIM1STMF',
#  'RECKITTBEN',
#  'JMISMDL']

# %%
#sets=pd.DataFrame()
#for i in ticker:
#    print('Working on :',i)
#    date='2023-06-11'
#    try:
#        data=get_basic_hist_data('2020-01-1',date,i,index='date')['close']
#        sets[i]=data
#    except:
#        df=pd.read_html('https://www.dsebd.org/day_end_archive.php?startDate=2020-01-01&endDate='+date+'&inst='+i+'&archive=data')[348]
#        df.index=df['DATE']
#        sets[i]=df['CLOSEP*']
#        print('Exception')
#sets.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx")

def concat(x):
    sets=pd.DataFrame()
    for i in ticker:
        sets[i]=get_basic_hist_data(str(pd.to_datetime(x.index[-1])+timedelta(days=1))[0:10],str(datetime.today()-timedelta(days=1))[0:10],i,index='date')['close']
    return(pd.concat([x,sets],axis=0))
pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# 2021-06-20        27.9        37.4  535.4  1295.5  2165.3     180.1   1306.7
# 2021-06-21        28.4        36.9  546.3  1299.1  2224.3     180.1   1309.2
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-08        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-13        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-14        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
# ...

# %%
concat(pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')).to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx")

# %%
sets=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
sets
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# 2021-06-20        27.9        37.4  535.4  1295.5  2165.3     180.1   1306.7
# 2021-06-21        28.4        36.9  546.3  1299.1  2224.3     180.1   1309.2
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-13        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-14        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-15        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
# ...

# %%
sets.index[31]
# Out:
# '2021-08-10'

# %%
sets.loc[sets.index[31],'ISLAMIBANK']
# Out:
# 29.0

# %%
sets.index[49]
# Out:
# '2021-09-07'

# %%
sets.loc[sets.index[49],'ISLAMIBANK']
# Out:
# 29.8

# %%
sets.index=pd.to_datetime(sets.index)
sets.resample('1M').last()
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-30        29.7        35.2  539.1  1319.7  2229.2     179.7   1324.7
# 2021-07-31        28.8        40.8  567.2  1371.7  2380.0     181.4   1367.9
# 2021-08-31        29.2        45.9  582.5  1415.3  2322.8     183.2   1380.0
# 2021-09-30        30.1        47.8  651.0  1432.5  2333.7     194.2   1581.0
# 2021-10-31        30.1        47.2  640.7  1448.6  2295.1     173.2   1451.8
# 2021-11-30        31.3        43.8  620.4  1290.5  2280.5     168.6   1376.4
# 2021-12-31        32.0        44.4  635.6  1312.0  2301.0     169.9   1579.8
# 2022-01-31        32.5        57.3  649.2  1332.3  2356.1     167.4   1824.3
# 2022-02-28        32.6        47.1  614.1  1360.4  2399.4     158.2   1707.0
# 2022-03-31        32.8        45.3  584.5  1353.3  2355.2     170.0   1581.4
# 2022-04-30        32.6        43.2  581.7  1362.0  2353.1     169.5   1464.8
# ...

# %%
simple_return=sets['LINDEBD'].pct_change()
log_return=np.log(sets['LINDEBD']/sets['LINDEBD'].shift(1)).dropna()
simple_return.describe(),log_return.describe()
# Out:
# (count    485.000000
#  mean       0.000236
#  std        0.012695
#  min       -0.057060
#  25%       -0.002935
#  50%        0.000000
#  75%        0.001079
#  max        0.062438
#  Name: LINDEBD, dtype: float64,
#  count    485.000000
#  mean       0.000156
#  std        0.012615
#  min       -0.058753
#  25%       -0.002939
#  50%        0.000000
#  75%        0.001079
#  max        0.060566
#  Name: LINDEBD, dtype: float64)

# %%
log_return.mean()
# Out:
# 0.00015576377438895049

# %%
len(log_return)
1397.7-1421.4061975711857
# Out:
# -23.706197571185612

# %%
1324.7*(1+log_return.mean())**(len(log_return))
# Out:
# 1428.6437480278953

# %%
1324.7*(1+simple_return.mean())**(len(log_return))
# Out:
# 1484.970202114546

# %%
sets['ISLAMIBANK'].std()/sets['ISLAMIBANK'].mean()
# Out:
# 0.04414225608053301

# %%
stats=pd.DataFrame(columns=[sets.columns],index=['Log Return','Rsquared','Return Standard Deviation','COV'])
for i in ticker:
    print('Working on :',i)
    stats.loc['Log Return',i]=np.log(sets[i]/sets[i].shift(1)).dropna().mean()*100
    stats.loc['Return Standard Deviation',i]=np.log(sets[i]/sets[i].shift(1)).dropna().std()*100
    stats.loc['COV',i]=(sets[i].std()/sets[i].mean())
stats=stats.T
stats
# Out:
# Working on : ISLAMIBANK
# Working on : RAKCERAMIC
# Working on : BATBC
# Working on : RENATA
# Working on : MARICO
# Working on : SINGERBD
# Working on : LINDEBD
# Working on : SUMITPOWER
# Working on : BERGERPBL
# Working on : BXPHARMA
# Working on : SQURPHARMA
# Working on : SAPORTL
# Working on : BSCCL
# Working on : GP
# Working on : SQUARETEXT
# Working on : OLYMPIC
# Working on : BEXIMCO
# Working on : NATLIFEINS
# Working on : HFL
# Working on : UPGDCL
# Working on : DELTALIFE
# Working on : BENGALWTL
# Working on : EHL
# Working on : IBNSINA
# Working on : WALTONHIL
# Working on : UNIQUEHRL
# Working on : UNILEVERCL
# Working on : KDSALTD
# Working on : JHRML
# Working on : ADNTEL
# Working on : ITC
# Working on : SIMTEX
# Working on : APEXFOODS
# Working on : FORTUNE
# Working on : INDEXAGRO
# Working on : AMANFEED
# Working on : SKICL
# Working on : ACI
# Working on : ACIFORMULA
# Working on : EXIMBANK
# Working on : IFILISLMF1
# Working on : AIBL1STIMF
# ...

# %%
pct_change=pd.DataFrame()
for i in sets.columns:
    pct_change[i]=sets[i].pct_change(5)
pct_change=pct_change.fillna(0)

# %%
import statsmodels.api as sm
def VIF_score(df):
    VIF_score=[]
    ticker=[]
    for i in df.columns:
        model=sm.OLS(df[i],sm.add_constant(df.loc[:, df.columns!=i]),hasconst=True)
        results=model.fit()
        VIF_score.append(results.rsquared)
        ticker.append(i)
    return(VIF_score,ticker)

# %%
for i in pct_change.columns:
    print(i)
# Out:
# ISLAMIBANK
# RAKCERAMIC
# BATBC
# RENATA
# MARICO
# SINGERBD
# LINDEBD
# SUMITPOWER
# BERGERPBL
# BXPHARMA
# SQURPHARMA
# SAPORTL
# BSCCL
# GP
# SQUARETEXT
# OLYMPIC
# BEXIMCO
# NATLIFEINS
# HFL
# UPGDCL
# DELTALIFE
# BENGALWTL
# EHL
# IBNSINA
# WALTONHIL
# UNIQUEHRL
# UNILEVERCL
# KDSALTD
# JHRML
# ADNTEL
# ITC
# SIMTEX
# APEXFOODS
# FORTUNE
# INDEXAGRO
# AMANFEED
# SKICL
# ACI
# ACIFORMULA
# EXIMBANK
# IFILISLMF1
# AIBL1STIMF
# EXIM1STMF
# RECKITTBEN
# JMISMDL

# %%
stats['Rsquared']=VIF_score(pct_change)[0]

# %%
stats.sort_values('Rsquared', axis=0, ascending=False)
# Out:
#            Log Return  Rsquared Return Standard Deviation       COV
# UPGDCL      -0.032425  0.719002                  0.823798  0.083784
# LINDEBD      0.015576  0.702372                  1.261524  0.083224
# SQURPHARMA  -0.002734  0.657789                   0.68753  0.040739
# EXIM1STMF   -0.038774  0.638204                   1.61001  0.138759
# BXPHARMA    -0.032307  0.620641                  1.634079  0.159715
# EHL          0.140334  0.604574                  3.566972    0.3224
# RECKITTBEN   0.026549  0.598411                  0.999082  0.077645
# SINGERBD    -0.034997  0.596638                   0.77981   0.08004
# WALTONHIL   -0.049548  0.588677                  0.955372  0.097899
# BATBC       -0.004249  0.588041                  0.954773  0.098501
# SUMITPOWER  -0.046494  0.583514                  1.017123  0.115635
# UNIQUEHRL    0.142607  0.580258                  2.818701  0.161201
# BEXIMCO      0.042648  0.577588                  1.807798  0.154369
# ...

# %%
plt.scatter(pct_change['UPGDCL'],pct_change['BXPHARMA'])

# %%
stats.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Statistics.xlsx")

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).cumsum().plot(figsize=(12.2,6.4),legend=False)

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).mean()
# Out:
# ISLAMIBANK    0.000336
# RAKCERAMIC    0.000420
# BATBC        -0.000042
# RENATA       -0.000124
# MARICO        0.000283
# SINGERBD     -0.000350
# LINDEBD       0.000156
# SUMITPOWER   -0.000465
# BERGERPBL     0.000007
# BXPHARMA     -0.000323
# SQURPHARMA   -0.000027
# SAPORTL       0.000015
# BSCCL         0.000507
# GP           -0.000377
# SQUARETEXT    0.001089
# OLYMPIC      -0.000250
# BEXIMCO       0.000426
# NATLIFEINS   -0.000620
# HFL          -0.000012
# UPGDCL       -0.000324
# DELTALIFE     0.000781
# BENGALWTL     0.000625
# EHL           0.001403
# IBNSINA       0.000302
# WALTONHIL    -0.000495
# UNIQUEHRL     0.001426
# UNILEVERCL   -0.000576
# KDSALTD       0.000953
# JHRML         0.004240
# ADNTEL        0.001895
# ITC           0.000126
# SIMTEX        0.000388
# APEXFOODS     0.002478
# FORTUNE       0.001161
# INDEXAGRO    -0.000498
# AMANFEED     -0.000746
# SKICL         0.003681
# ACI          -0.000074
# ACIFORMULA    0.000169
# EXIMBANK     -0.000078
# ...

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).std()
# Out:
# ISLAMIBANK    0.008819
# RAKCERAMIC    0.019390
# BATBC         0.009548
# RENATA        0.006885
# MARICO        0.004834
# SINGERBD      0.007798
# LINDEBD       0.012615
# SUMITPOWER    0.010171
# BERGERPBL     0.008474
# BXPHARMA      0.016341
# SQURPHARMA    0.006875
# SAPORTL       0.026722
# BSCCL         0.015926
# GP            0.007283
# SQUARETEXT    0.016193
# OLYMPIC       0.019185
# BEXIMCO       0.018078
# NATLIFEINS    0.015584
# HFL           0.033010
# UPGDCL        0.008238
# DELTALIFE     0.027675
# BENGALWTL     0.028858
# EHL           0.035670
# IBNSINA       0.012078
# WALTONHIL     0.009554
# UNIQUEHRL     0.028187
# UNILEVERCL    0.025345
# KDSALTD       0.022933
# JHRML         0.041389
# ADNTEL        0.031905
# ITC           0.023620
# SIMTEX        0.026821
# APEXFOODS     0.036038
# FORTUNE       0.023701
# INDEXAGRO     0.025765
# AMANFEED      0.024086
# SKICL         0.034220
# ACI           0.012294
# ACIFORMULA    0.019940
# EXIMBANK      0.010437
# ...

# %%
plt.figure(figsize = (30,30))
pic=plt.imread("Modern portfolio theory.png")
plt.imshow(pic)
plt.axis('off')
plt.show()

# %%
# vector is weights
W=np.array([1/len(sets.columns) for i in range(len(sets.columns))])#creating equal weighted portfolio
W
# Out:
# array([0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
#        0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
#        0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
#        0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
#        0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
#        0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
#        0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
#        0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222,
#        0.02222222, 0.02222222, 0.02222222, 0.02222222, 0.02222222])

# %%
portfolio_ret=np.log(sets[sets.columns]/sets[sets.columns].shift(1))

# %%
portfolio_ret.mean()
# Out:
# ISLAMIBANK    0.000336
# RAKCERAMIC    0.000420
# BATBC        -0.000042
# RENATA       -0.000124
# MARICO        0.000283
# SINGERBD     -0.000350
# LINDEBD       0.000156
# SUMITPOWER   -0.000465
# BERGERPBL     0.000007
# BXPHARMA     -0.000323
# SQURPHARMA   -0.000027
# SAPORTL       0.000015
# BSCCL         0.000507
# GP           -0.000377
# SQUARETEXT    0.001089
# OLYMPIC      -0.000250
# BEXIMCO       0.000426
# NATLIFEINS   -0.000620
# HFL          -0.000012
# UPGDCL       -0.000324
# DELTALIFE     0.000781
# BENGALWTL     0.000625
# EHL           0.001403
# IBNSINA       0.000302
# WALTONHIL    -0.000495
# UNIQUEHRL     0.001426
# UNILEVERCL   -0.000576
# KDSALTD       0.000953
# JHRML         0.004240
# ADNTEL        0.001895
# ITC           0.000126
# SIMTEX        0.000388
# APEXFOODS     0.002478
# FORTUNE       0.001161
# INDEXAGRO    -0.000498
# AMANFEED     -0.000746
# SKICL         0.003681
# ACI          -0.000074
# ACIFORMULA    0.000169
# EXIMBANK     -0.000078
# ...

# %%
0.000336*0.02702703
# Out:
# 9.08108208e-06

# %%
(W*portfolio_ret.mean()).sum()*252
# Out:
# 0.09161290818299907

# %%
portfolio_ret.mean().dot(W)*252
# Out:
# 0.09161290818299907

# %%
W.dot(portfolio_ret.mean())
# Out:
# 0.0003635432864404725

# %%
len(portfolio_ret.mean())
# Out:
# 45

# %%
portfolio_ret.cov()
# Out:
#               ISLAMIBANK    RAKCERAMIC     BATBC        RENATA        MARICO  \
# ISLAMIBANK  7.776659e-05  2.624349e-07  0.000005 -1.300351e-05  3.795364e-06
# RAKCERAMIC  2.624349e-07  3.759556e-04  0.000040  9.873064e-06  1.412694e-05
# BATBC       4.789977e-06  3.975055e-05  0.000091  1.213867e-05  1.003539e-05
# RENATA     -1.300351e-05  9.873064e-06  0.000012  4.740734e-05  6.034942e-06
# MARICO      3.795364e-06  1.412694e-05  0.000010  6.034942e-06  2.336810e-05
# SINGERBD    5.622725e-06  1.363974e-05  0.000015  5.467854e-06  8.310282e-06
# LINDEBD     8.578047e-06  5.099832e-05  0.000036  7.838641e-06  9.280295e-06
# SUMITPOWER  3.029790e-06  4.870073e-05  0.000029  1.717774e-05  7.710954e-06
# BERGERPBL   1.920172e-07  5.873837e-06  0.000012  9.120343e-06  1.234709e-05
# BXPHARMA    1.324516e-05  7.082778e-05  0.000040  1.363148e-05  8.792255e-06
# SQURPHARMA  9.462934e-06  3.120001e-05  0.000022  3.527890e-06  6.917123e-06
# ...

# %%
(W.T.dot((portfolio_ret.cov()*252).dot(W)))**(1/2)
# Out:
# 0.1197720940198671

# %%
np.log(sets[sets.columns]/sets[sets.columns].shift(1)).std()
# Out:
# ISLAMIBANK    0.008819
# RAKCERAMIC    0.019390
# BATBC         0.009548
# RENATA        0.006885
# MARICO        0.004834
# SINGERBD      0.007798
# LINDEBD       0.012615
# SUMITPOWER    0.010171
# BERGERPBL     0.008474
# BXPHARMA      0.016341
# SQURPHARMA    0.006875
# SAPORTL       0.026722
# BSCCL         0.015926
# GP            0.007283
# SQUARETEXT    0.016193
# OLYMPIC       0.019185
# BEXIMCO       0.018078
# NATLIFEINS    0.015584
# HFL           0.033010
# UPGDCL        0.008238
# DELTALIFE     0.027675
# BENGALWTL     0.028858
# EHL           0.035670
# IBNSINA       0.012078
# WALTONHIL     0.009554
# UNIQUEHRL     0.028187
# UNILEVERCL    0.025345
# KDSALTD       0.022933
# JHRML         0.041389
# ADNTEL        0.031905
# ITC           0.023620
# SIMTEX        0.026821
# APEXFOODS     0.036038
# FORTUNE       0.023701
# INDEXAGRO     0.025765
# AMANFEED      0.024086
# SKICL         0.034220
# ACI           0.012294
# ACIFORMULA    0.019940
# EXIMBANK      0.010437
# ...

# %%
def sharpe_pf(W,portfolio_ret):
    pf_risk=(W.T.dot(portfolio_ret.cov().dot(W)))**(1/2)
    SR=W.dot(portfolio_ret.mean())/pf_risk
    return(SR)

# %%
sharpe_pf(W,portfolio_ret)
# Out:
# 0.04818376774321395

# %%
weights=np.random.random(len(sets.columns))
weights/=np.sum(weights)

# %%
weights[2]
# Out:
# 0.03375253712129343

# %%
len(weights)
# Out:
# 45

# %%
weights.sum()
# Out:
# 0.9999999999999997

# %%
returns=np.log(sets[sets.columns]/sets[sets.columns].shift(1))
mean_ret=portfolio_ret.mean()*252
mean_ret
# Out:
# ISLAMIBANK    0.084630
# RAKCERAMIC    0.105748
# BATBC        -0.010707
# RENATA       -0.031131
# MARICO        0.071227
# SINGERBD     -0.088192
# LINDEBD       0.039252
# SUMITPOWER   -0.117164
# BERGERPBL     0.001756
# BXPHARMA     -0.081413
# SQURPHARMA   -0.006889
# SAPORTL       0.003765
# BSCCL         0.127706
# GP           -0.095004
# SQUARETEXT    0.274478
# OLYMPIC      -0.063067
# BEXIMCO       0.107472
# NATLIFEINS   -0.156253
# HFL          -0.002961
# UPGDCL       -0.081712
# DELTALIFE     0.196838
# BENGALWTL     0.157409
# EHL           0.353642
# IBNSINA       0.076212
# WALTONHIL    -0.124862
# UNIQUEHRL     0.359370
# UNILEVERCL   -0.145236
# KDSALTD       0.240175
# JHRML         1.068479
# ADNTEL        0.477488
# ITC           0.031836
# SIMTEX        0.097710
# APEXFOODS     0.624513
# FORTUNE       0.292660
# INDEXAGRO    -0.125484
# AMANFEED     -0.187954
# SKICL         0.927489
# ACI          -0.018632
# ACIFORMULA    0.042596
# EXIMBANK     -0.019609
# ...

# %%
returns.cov()*252
# Out:
#             ISLAMIBANK  RAKCERAMIC     BATBC    RENATA    MARICO  SINGERBD  \
# ISLAMIBANK    0.019597    0.000066  0.001207 -0.003277  0.000956  0.001417
# RAKCERAMIC    0.000066    0.094741  0.010017  0.002488  0.003560  0.003437
# BATBC         0.001207    0.010017  0.022972  0.003059  0.002529  0.003850
# RENATA       -0.003277    0.002488  0.003059  0.011947  0.001521  0.001378
# MARICO        0.000956    0.003560  0.002529  0.001521  0.005889  0.002094
# SINGERBD      0.001417    0.003437  0.003850  0.001378  0.002094  0.015324
# LINDEBD       0.002162    0.012852  0.009005  0.001975  0.002339  0.005296
# SUMITPOWER    0.000764    0.012273  0.007403  0.004329  0.001943  0.004161
# BERGERPBL     0.000048    0.001480  0.002961  0.002298  0.003111  0.003076
# BXPHARMA      0.003338    0.017849  0.010152  0.003435  0.002216  0.004849
# SQURPHARMA    0.002385    0.007862  0.005468  0.000889  0.001743  0.002905
# ...

# %%
weights.dot(returns.mean())*252 #yearly return
# Out:
# 0.04254162697475962

# %%
np.sqrt(weights.T.dot((portfolio_ret.cov()*252).dot(weights)))#yearly risk
# Out:
# 0.10665311150880032

# %%
p_ret = []#Return list of our random portfolio
p_vol = []#Volatility list of our random portfolio
p_sr = []#sharp ration to maximize profit and minimize risk(rate of return- risk free rate)/standard deviation
p_wt = []#weights

for x in range(30000):
    p_weights=np.random.random(len(sets.columns))
    p_weights/=np.sum(p_weights)
    ret_1=p_weights.dot(returns.mean())*252
    p_ret.append(ret_1)
    vol_1 = np.sqrt(p_weights.T.dot((portfolio_ret.cov()*252).dot(p_weights)))
    p_vol.append(vol_1)
    SR_1 = (ret_1-0.06)/vol_1
    p_sr.append(SR_1)
    p_wt.append(p_weights)
p_ret = np.array(p_ret)
p_vol = np.array(p_vol)
p_SR = np.array(p_sr)
p_wt = np.array(p_wt)

    
p_ret,p_vol,p_SR,p_wt
# Out:
# (array([0.11465187, 0.07051352, 0.06271709, ..., 0.10365896, 0.1222423 ,
#         0.05921131]),
#  array([0.12079519, 0.1197106 , 0.11527107, ..., 0.1262917 , 0.13005268,
#         0.12385678]),
#  array([ 0.45243412,  0.08782447,  0.02357128, ...,  0.34569933,
#          0.47859298, -0.00636772]),
#  array([[0.02860474, 0.02444947, 0.01654884, ..., 0.01032269, 0.00757848,
#          0.01453552],
#         [0.0158216 , 0.00547121, 0.04353474, ..., 0.02321664, 0.00887907,
#          0.00185673],
#         [0.01601812, 0.0210611 , 0.01371283, ..., 0.0075829 , 0.04180377,
#          0.04109917],
#         ...,
#         [0.03046646, 0.0140492 , 0.00439499, ..., 0.00067904, 0.03340594,
#          0.03701099],
#         [0.03254742, 0.02809542, 0.01053697, ..., 0.00642156, 0.0080851 ,
#          0.04151323],
#         [0.02281092, 0.02014067, 0.00659575, ..., 0.03243535, 0.00285568,
#          0.0111613 ]]))

# %%
ports = pd.DataFrame({'Returns' : p_ret, 'volatility' :p_vol})
ports
# Out:
#         Returns  volatility
# 0      0.114652    0.120795
# 1      0.070514    0.119711
# 2      0.062717    0.115271
# 3      0.091893    0.117715
# 4      0.077997    0.122675
# ...         ...         ...
# 29995  0.093441    0.122046
# 29996  0.080299    0.114439
# 29997  0.103659    0.126292
# 29998  0.122242    0.130053
# 29999  0.059211    0.123857
#
# [30000 rows x 2 columns]

# %%
ports.plot(x='volatility', y ='Returns', kind='scatter',figsize=(16,9))
plt.scatter(x=0.1481084557273514,y=0.145404,color="Red",marker='+')
#plt.scatter(x=0.294,y=1.1,color="Red",marker='+')
plt.show()

# %%
SR_IDX=np.argmax(p_SR)
SR_IDX
# Out:
# 8773

# %%
i=0
while i < len(sets.columns):
    print('Stock : %s : %2.2f'%(sets.columns[i],(p_wt[SR_IDX][i]*100)))
    i+=1
print('\nVolatility :',p_vol[SR_IDX])
print('Return :',p_ret[SR_IDX])
# Out:
# Stock : ISLAMIBANK : 4.67
# Stock : RAKCERAMIC : 3.51
# Stock : BATBC : 2.94
# Stock : RENATA : 0.68
# Stock : MARICO : 0.12
# Stock : SINGERBD : 0.53
# Stock : LINDEBD : 2.54
# Stock : SUMITPOWER : 1.39
# Stock : BERGERPBL : 3.83
# Stock : BXPHARMA : 0.61
# Stock : SQURPHARMA : 5.31
# Stock : SAPORTL : 3.66
# Stock : BSCCL : 1.71
# Stock : GP : 0.41
# Stock : SQUARETEXT : 4.32
# Stock : OLYMPIC : 4.54
# Stock : BEXIMCO : 1.27
# Stock : NATLIFEINS : 1.24
# Stock : HFL : 0.38
# Stock : UPGDCL : 1.51
# Stock : DELTALIFE : 1.20
# Stock : BENGALWTL : 0.83
# Stock : EHL : 1.23
# Stock : IBNSINA : 2.16
# Stock : WALTONHIL : 1.10
# Stock : UNIQUEHRL : 3.02
# Stock : UNILEVERCL : 0.12
# Stock : KDSALTD : 0.29
# Stock : JHRML : 3.57
# Stock : ADNTEL : 4.81
# Stock : ITC : 1.86
# Stock : SIMTEX : 3.71
# Stock : APEXFOODS : 4.41
# Stock : FORTUNE : 4.01
# Stock : INDEXAGRO : 1.16
# Stock : AMANFEED : 0.07
# Stock : SKICL : 4.73
# Stock : ACI : 4.58
# Stock : ACIFORMULA : 0.03
# ...

# %%
p_wt[SR_IDX].sum()
# Out:
# 1.0

# %%
m=pd.DataFrame(columns=['Weights'],index=[sets.columns])
m['Weights']=p_wt[SR_IDX]*100

# %%
len(m['Weights'])
# Out:
# 45

# %%
m.loc['ISLAMIBANK','Weights']=2
m.loc['RAKCERAMIC','Weights']=1
m.loc['BATBC','Weights']=3
m.loc['RENATA','Weights']=3
m.loc['MARICO','Weights']=2
m.loc['SINGERBD','Weights']=1
m.loc['LINDEBD','Weights']=6
m.loc['SUMITPOWER','Weights']=1
m.loc['BERGERPBL','Weights']=5
m.loc['BXPHARMA','Weights']=1
m.loc['NATLIFEINS','Weights']=3
m.loc['SQURPHARMA','Weights']=3
m.loc['SAPORTL','Weights']=1
m.loc['BSCCL','Weights']=2
m.loc['GP','Weights']=3
m.loc['SQUARETEXT','Weights']=1
m.loc['OLYMPIC','Weights']=2
m.loc['BEXIMCO','Weights']=3
m.loc['HFL','Weights']=1
m.loc['UPGDCL','Weights']=4
m.loc['DELTALIFE','Weights']=3
m.loc['BENGALWTL','Weights']=2
m.loc['EHL','Weights']=3
m.loc['IBNSINA','Weights']=3
m.loc['WALTONHIL','Weights']=1
m.loc['UNIQUEHRL','Weights']=2
m.loc['UNILEVERCL','Weights']=3
m.loc['KDSALTD','Weights']=1
m.loc['JHRML','Weights']=1
m.loc['ADNTEL','Weights']=2
m.loc['ITC','Weights']=2
m.loc['SIMTEX','Weights']=1
m.loc['APEXFOODS','Weights']=2
m.loc['FORTUNE','Weights']=3
m.loc['INDEXAGRO','Weights']=1
m.loc['AMANFEED','Weights']=1
m.loc['SKICL','Weights']=3
m.loc['ACI','Weights']=1.5
m.loc['ACIFORMULA','Weights']=1.5
m.loc['EXIMBANK' ,'Weights']=3
m.loc['IFILISLMF1','Weights']=3
m.loc['AIBL1STIMF','Weights']=2
m.loc['EXIM1STMF','Weights']=2
m.loc['RECKITTBEN','Weights']=3
m.loc['JMISMDL','Weights']=2
m.loc['JMISMDL','Weights']=2

# %%
m['Weights'].sum()
# Out:
# 100.0

# %%
m
# Out:
#             Weights
# ISLAMIBANK      2.0
# RAKCERAMIC      1.0
# BATBC           3.0
# RENATA          3.0
# MARICO          2.0
# SINGERBD        1.0
# LINDEBD         6.0
# SUMITPOWER      1.0
# BERGERPBL       5.0
# BXPHARMA        1.0
# SQURPHARMA      3.0
# SAPORTL         1.0
# BSCCL           2.0
# GP              3.0
# SQUARETEXT      1.0
# OLYMPIC         2.0
# BEXIMCO         3.0
# NATLIFEINS      3.0
# HFL             1.0
# UPGDCL          4.0
# DELTALIFE       3.0
# BENGALWTL       2.0
# EHL             3.0
# IBNSINA         3.0
# WALTONHIL       1.0
# UNIQUEHRL       2.0
# UNILEVERCL      3.0
# KDSALTD         1.0
# JHRML           1.0
# ADNTEL          2.0
# ITC             2.0
# SIMTEX          1.0
# APEXFOODS       2.0
# FORTUNE         3.0
# INDEXAGRO       1.0
# AMANFEED        1.0
# SKICL           3.0
# ACI             1.5
# ACIFORMULA      1.5
# EXIMBANK        3.0
# IFILISLMF1      3.0
# AIBL1STIMF      2.0
# EXIM1STMF       2.0
# RECKITTBEN      3.0
# ...

# %%
np.sqrt((m['Weights'].values/100).T.dot((portfolio_ret.cov()*252).dot(m['Weights'].values/100)))
# Out:
# 0.10664771220967513

# %%
(m['Weights'].values/100).dot(returns.mean())*252 #yearly return
# Out:
# 0.08710108519726228

# %%
m.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Weights.xlsx")

# %%
def price(sdate,edate):
    df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
    mask = (df.index >= sdate) & (df.index <= edate)
    return(df.loc[mask])
price('2021-06-13','2021-06-13')
# Out:
# Empty DataFrame
# Columns: [ISLAMIBANK, RAKCERAMIC, BATBC, RENATA, MARICO, SINGERBD, LINDEBD, SUMITPOWER, BERGERPBL, BXPHARMA, SQURPHARMA, SAPORTL, BSCCL, GP, SQUARETEXT, OLYMPIC, BEXIMCO, NATLIFEINS, HFL, UPGDCL, DELTALIFE, BENGALWTL, EHL, IBNSINA, WALTONHIL, UNIQUEHRL, UNILEVERCL, KDSALTD, JHRML, ADNTEL, ITC, SIMTEX, APEXFOODS, FORTUNE, INDEXAGRO, AMANFEED, SKICL, ACI, ACIFORMULA, EXIMBANK, IFILISLMF1, AIBL1STIMF, EXIM1STMF, RECKITTBEN, JMISMDL]
# Index: []
#
# [0 rows x 45 columns]

# %%
sets
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# 2021-06-20        27.9        37.4  535.4  1295.5  2165.3     180.1   1306.7
# 2021-06-21        28.4        36.9  546.3  1299.1  2224.3     180.1   1309.2
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-13        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-14        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-15        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
# ...

# %%
wt=(500000/100)*(m.loc['ISLAMIBANK'].values)
quantity=float(wt)/float(price('2023-06-08','2023-06-08')['ISLAMIBANK'].values)
round(quantity)*float(price('2023-06-08','2023-06-08')['ISLAMIBANK'].values)
# Out:
# 10008.2

# %%
sdate,edate='2022-05-12','2022-05-12'
def price(sdate,edate):
    df=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx",index_col='date')
    df=df.fillna(method='bfill',axis='rows')
    mask = (df.index >= sdate) & (df.index <= edate)
    return(df.loc[mask])
price('2021-06-15','2021-06-15')
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
#
#             SUMITPOWER  BERGERPBL  BXPHARMA  ...  AMANFEED  SKICL    ACI  \
# date                                         ...
# 2021-06-15        42.6     1772.2     171.0  ...      48.1   11.0  269.7
#
#             ACIFORMULA  EXIMBANK  IFILISLMF1  AIBL1STIMF  EXIM1STMF  \
# date
# 2021-06-15       142.8      10.8         6.6         9.1        7.0
#
#             RECKITTBEN  JMISMDL
# date
# 2021-06-15      4245.3    323.3
#
# [1 rows x 45 columns]

# %%
sdate,edate='2021-06-15','2021-06-15'

# %%
def my_port(investment,m):
    Q=[]
    P=[]
    T=[]
    m=m
    pr=price(sdate,edate)
    for i in sets.columns:
        wt=(investment/ m['Weights'].sum())*(m.loc[i].values)
        Q.append(round(float(wt)/float(pr[i].values)))
        P.append(float(pr[i].values))
        T.append(round(float(wt)/float(pr[i].values))*float(pr[i].values))
    return(Q,P,T)

# %%
my_port(500000,m)
# Out:
# ([361,
#   143,
#   28,
#   12,
#   5,
#   28,
#   23,
#   117,
#   14,
#   29,
#   71,
#   182,
#   58,
#   44,
#   126,
#   59,
#   160,
#   62,
#   284,
#   73,
#   156,
#   513,
#   311,
#   61,
#   4,
#   300,
#   5,
#   103,
#   227,
#   192,
#   275,
#   287,
#   81,
#   348,
#   38,
#   104,
#   1364,
#   28,
#   53,
#   1389,
#   2273,
#   1099,
#   1429,
#   4,
#   31],
#  [27.7,
#   35.0,
#   529.5,
#   1293.1,
#   2111.3,
#   180.0,
#   1296.0,
#   42.6,
#   1772.2,
#   171.0,
#   212.6,
#   27.5,
#   171.2,
#   344.1,
#   39.8,
#   170.6,
#   94.0,
#   241.8,
#   17.6,
#   273.5,
#   96.4,
#   19.5,
#   48.2,
#   247.5,
#   1332.3,
#   33.3,
#   2741.8,
#   48.5,
#   22.0,
#   52.1,
#   36.4,
#   17.4,
#   123.1,
#   43.1,
#   131.9,
#   48.1,
#   11.0,
#   269.7,
#   142.8,
#   10.8,
#   6.6,
#   9.1,
#   7.0,
#   4245.3,
#   323.3],
#  [9999.699999999999,
#   5005.0,
#   14826.0,
#   15517.199999999999,
#   10556.5,
#   5040.0,
#   29808.0,
#   4984.2,
#   24810.8,
# ...

# %%
lists=pd.DataFrame()

# %%
lists=pd.DataFrame(columns=['Ouantity','Price','Total'],index=[sets.columns])
lists['Ouantity']=my_port(1000000,m)[0]
lists['Price']=my_port(1000000,m)[1]
lists['Total']=my_port(1000000,m)[2]
lists#['Total'].sum()
# Out:
#             Ouantity   Price    Total
# ISLAMIBANK       722    27.7  19999.4
# RAKCERAMIC       286    35.0  10010.0
# BATBC             57   529.5  30181.5
# RENATA            23  1293.1  29741.3
# MARICO             9  2111.3  19001.7
# SINGERBD          56   180.0  10080.0
# LINDEBD           46  1296.0  59616.0
# SUMITPOWER       235    42.6  10011.0
# BERGERPBL         28  1772.2  49621.6
# BXPHARMA          58   171.0   9918.0
# SQURPHARMA       141   212.6  29976.6
# SAPORTL          364    27.5  10010.0
# BSCCL            117   171.2  20030.4
# GP                87   344.1  29936.7
# SQUARETEXT       251    39.8   9989.8
# OLYMPIC          117   170.6  19960.2
# BEXIMCO          319    94.0  29986.0
# NATLIFEINS       124   241.8  29983.2
# HFL              568    17.6   9996.8
# UPGDCL           146   273.5  39931.0
# DELTALIFE        311    96.4  29980.4
# BENGALWTL       1026    19.5  20007.0
# EHL              622    48.2  29980.4
# IBNSINA          121   247.5  29947.5
# ...

# %%
n=((lists['Total']/997658.2999999999)*100).values
n
# Out:
# array([2.00463425, 1.00334954, 3.02523419, 2.98111087, 1.90463007,
#        1.01036597, 5.97559305, 1.00344978, 4.97380716, 0.99412795,
#        3.0046961 , 1.00334954, 2.00774153, 3.00069673, 1.0013248 ,
#        2.00070505, 3.0056383 , 3.00535765, 1.00202645, 4.00247259,
#        3.00507699, 2.00539604, 3.00507699, 3.00177927, 1.06834174,
#        2.00602751, 3.0230591 , 1.00144508, 1.00334954, 2.0053359 ,
#        2.00305054, 1.00284837, 1.99890083, 3.00680103, 1.00479292,
#        1.00282832, 3.00674089, 1.51386502, 1.50291939, 3.00728215,
#        3.00674089, 2.00487482, 2.00459416, 2.97868519, 2.00916486])

# %%
(n/100).dot(returns.mean())*252 #yearly return
# Out:
# 0.08706715482878197

# %%
np.sqrt((n/100).T.dot((portfolio_ret.cov()*252).dot(n/100)))
# Out:
# 0.1068541188035826

# %%
lists['Total'].sum()
# Out:
# 998549.1000000001

# %%
df=pd.read_excel('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\data_set.xlsx',index_col='date')

# %%
df.isnull().sum()
# Out:
# ISLAMIBANK      0
# RAKCERAMIC      0
# BATBC           0
# RENATA          0
# MARICO          0
# SINGERBD        0
# LINDEBD         0
# SUMITPOWER      0
# BERGERPBL       0
# BXPHARMA        0
# SQURPHARMA      0
# SAPORTL         0
# BSCCL           0
# GP              0
# SQUARETEXT      0
# OLYMPIC         0
# BEXIMCO         0
# NATLIFEINS      0
# HFL             0
# UPGDCL          0
# DELTALIFE       0
# BENGALWTL       0
# EHL             0
# IBNSINA         0
# WALTONHIL       0
# UNIQUEHRL       0
# UNILEVERCL      0
# KDSALTD         0
# JHRML         192
# ADNTEL          0
# ITC             0
# SIMTEX          0
# APEXFOODS       0
# FORTUNE         0
# INDEXAGRO       0
# AMANFEED        0
# SKICL          91
# ACI             0
# ACIFORMULA      0
# EXIMBANK        0
# IFILISLMF1      0
# AIBL1STIMF      0
# EXIM1STMF       0
# RECKITTBEN      0
# JMISMDL         0
# dtype: int64

# %%
df=df.fillna(method='bfill',axis='rows')
df
# Out:
#             ISLAMIBANK  RAKCERAMIC  BATBC  RENATA  MARICO  SINGERBD  LINDEBD  \
# date
# 2021-06-15        27.7        35.0  529.5  1293.1  2111.3     180.0   1296.0
# 2021-06-16        27.6        35.9  529.5  1292.2  2138.1     180.0   1301.3
# 2021-06-17        27.9        35.9  533.1  1292.2  2144.8     180.9   1300.0
# 2021-06-20        27.9        37.4  535.4  1295.5  2165.3     180.1   1306.7
# 2021-06-21        28.4        36.9  546.3  1299.1  2224.3     180.1   1309.2
# ...                ...         ...    ...     ...     ...       ...      ...
# 2023-06-11        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-12        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-13        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-14        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
# 2023-06-15        32.6        42.9  518.7  1217.9  2421.5     151.9   1397.7
#
# ...

# %%
df.isnull().sum()
# Out:
# ISLAMIBANK    0
# RAKCERAMIC    0
# BATBC         0
# RENATA        0
# MARICO        0
# SINGERBD      0
# LINDEBD       0
# SUMITPOWER    0
# BERGERPBL     0
# BXPHARMA      0
# SQURPHARMA    0
# SAPORTL       0
# BSCCL         0
# GP            0
# SQUARETEXT    0
# OLYMPIC       0
# BEXIMCO       0
# NATLIFEINS    0
# HFL           0
# UPGDCL        0
# DELTALIFE     0
# BENGALWTL     0
# EHL           0
# IBNSINA       0
# WALTONHIL     0
# UNIQUEHRL     0
# UNILEVERCL    0
# KDSALTD       0
# JHRML         0
# ADNTEL        0
# ITC           0
# SIMTEX        0
# APEXFOODS     0
# FORTUNE       0
# INDEXAGRO     0
# AMANFEED      0
# SKICL         0
# ACI           0
# ACIFORMULA    0
# EXIMBANK      0
# IFILISLMF1    0
# AIBL1STIMF    0
# EXIM1STMF     0
# RECKITTBEN    0
# JMISMDL       0
# dtype: int64

# %%
port=pd.DataFrame(columns=[df.columns],index=df.index)
port
# Out:
#            ISLAMIBANK RAKCERAMIC BATBC RENATA MARICO SINGERBD LINDEBD  \
# date
# 2021-06-15        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-16        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-17        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-20        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2021-06-21        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# ...               ...        ...   ...    ...    ...      ...     ...
# 2023-06-11        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-12        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-13        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-14        NaN        NaN   NaN    NaN    NaN      NaN     NaN
# 2023-06-15        NaN        NaN   NaN    NaN    NaN      NaN     NaN
#
#            SUMITPOWER BERGERPBL BXPHARMA  ... AMANFEED SKICL  ACI ACIFORMULA  \
# ...

# %%
for i in port.index:
    for j in df.columns:
        port.loc[i,j]=df.loc[i,j]*lists.loc[j]['Ouantity'][0]
port['Total']=port.iloc[:,0:len(df.columns)].sum(axis=1)

# %%
port.index=pd.to_datetime(port.index)
port
# Out:
#            ISLAMIBANK RAKCERAMIC    BATBC   RENATA   MARICO SINGERBD  LINDEBD  \
# date
# 2021-06-15    19999.4    10010.0  30181.5  29741.3  19001.7  10080.0  59616.0
# 2021-06-16    19927.2    10267.4  30181.5  29720.6  19242.9  10080.0  59859.8
# 2021-06-17    20143.8    10267.4  30386.7  29720.6  19303.2  10130.4  59800.0
# 2021-06-20    20143.8    10696.4  30517.8  29796.5  19487.7  10085.6  60108.2
# 2021-06-21    20504.8    10553.4  31139.1  29879.3  20018.7  10085.6  60223.2
# ...               ...        ...      ...      ...      ...      ...      ...
# 2023-06-11    23537.2    12269.4  29565.9  28011.7  21793.5   8506.4  64294.2
# 2023-06-12    23537.2    12269.4  29565.9  28011.7  21793.5   8506.4  64294.2
# 2023-06-13    23537.2    12269.4  29565.9  28011.7  21793.5   8506.4  64294.2
# 2023-06-14    23537.2    12269.4  29565.9  28011.7  21793.5   8506.4  64294.2
# 2023-06-15    23537.2    12269.4  29565.9  28011.7  21793.5   8506.4  64294.2
#
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')
plt.figure(figsize=(8, 6), dpi=200)
plt.title('My Portfolio Tow Years Performance')
plt.plot(np.array(port.index),np.array(port['Total'].values))
plt.xlabel('years')
plt.ylabel('BDT')
plt.xticks(rotation=45)
plt.show()

# %%
np.log(port['Total']/port['Total'].shift(1)).describe()
# Out:
#             Total
# count  485.000000
# mean     0.000520
# std      0.008525
# min     -0.033005
# 25%     -0.004075
# 50%      0.000548
# 75%      0.004959
# max      0.031547

# %%
round(998549.1*(1+np.log(port['Total']/port['Total'].shift(1)).mean())**(len(port)))
# Out:
# Total    1285559.0
# dtype: float64

# %%
port.to_excel('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\portfolio_performence.xlsx')

# %%
0.000520*252
# Out:
# 0.13104
