# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.figure(figsize = (30,30))
pic=plt.imread("Python-Remove-Whitespace-Function-Examples.png")
plt.imshow(pic)
plt.axis('off')
plt.show()

# %%
re.sub(" ", " ",'  i am        nafis ').strip().replace('  ',' ')
# Out:
# 'i am    nafis'

# %%
re.sub(" +", " ",'  i am        nafis ').strip().replace('  ',' ')
# Out:
# 'i am nafis'

# %%
Income_Statement=pd.read_excel('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\United Power Generation & Distribution Co. Ltd\\BooK.xlsx',sheet_name='Income_Statement',index_col=0)
Balance_Sheet=pd.read_excel('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\United Power Generation & Distribution Co. Ltd\\BooK.xlsx',sheet_name='Balance_Sheet',index_col=0)

# %%
Balance_Sheet.columns=Balance_Sheet.loc['Fiscal year is July-June. All values BDT Millions.'].values
Balance_Sheet.drop_duplicates(inplace=True)
Balance_Sheet.dropna(how='all',axis=0,inplace=True)
Balance_Sheet
# Out:
#                                                       2022    2021    2020  \
# Assets
# Fiscal year is July-June. All values BDT Millions.    2022    2021    2020
# Cash & Short Term Investments                         1384    1642     516
# Cash Only                                             1203    1459     423
# Cash & Short Term Investments Growth               -0.1571  2.1822 -0.8497
# Cash & ST Investments / Total Assets                0.0161  0.0243  0.0143
# ...                                                    ...     ...     ...
# Retained Earnings                                    24786   24666   21933
# Revaluation Reserves                                    56      57      57
# Common Equity / Total Assets                        0.3791  0.4812  0.8123
# Accumulated Minority Interest                          512     525     545
# Total Equity                                         33198   33091   29851
#
#                                                       2019    2018  \
# Assets
# Fiscal year is July-June. All values BDT Millions.    2019    2018
# Cash & Short Term Investments                         3433    1360
# Cash Only                                             3306    1279
# Cash & Short Term Investments Growth                1.5232       -
# Cash & ST Investments / Total Assets                0.0817  0.0828
# ...                                                    ...     ...
# Retained Earnings                                    22705   10252
# Revaluation Reserves                                    58       -
# Common Equity / Total Assets                        0.7042  0.9918
# Accumulated Minority Interest                          488       -
# Total Equity                                         30088   16291
#
#                                                     5-year trend
# Assets
# Fiscal year is July-June. All values BDT Millions.  5-year trend
# Cash & Short Term Investments                                NaN
# Cash Only                                                    NaN
# Cash & Short Term Investments Growth                         NaN
# Cash & ST Investments / Total Assets                         NaN
# ...                                                          ...
# Retained Earnings                                            NaN
# Revaluation Reserves                                         NaN
# Common Equity / Total Assets                                 NaN
# Accumulated Minority Interest                                NaN
# Total Equity                                                 NaN
#
# [64 rows x 6 columns]

# %%
Income_Statement.dropna(how='all',axis=0,inplace=True)
Income_Statement
# Out:
#                                                       2022    2021    2020  \
# Fiscal year is July-June. All values BDT Millions.
# Sales/Revenue                                        49435   30581   10094
# Sales Growth                                        0.6166  2.0296  -0.103
# Cost of Goods Sold (COGS) incl. D&A                  39290   18789    4251
# COGS excluding D&A                                   36792   16178    2914
# Depreciation & Amortization Expense                   2498    2611    1336
# Depreciation                                          2498    2611    1336
# Amortization of Deferred Charges                         -       -       -
# COGS Growth                                         1.0911  3.4202  0.0266
# Gross Income                                         10145   11792    5843
# Gross Income Growth                                -0.1396  1.0179 -0.1785
# Gross Profit Margin                                 0.2052       -       -
# SG&A Expense                                            73      81      60
# Other SG&A                                              73      81      60
# SGA Growth                                         -0.0949  0.3454 -0.3162
# Other Operating Expense                                -36     -25     -19
# EBIT                                                 10108   11736    5802
# Unusual Expense                                         24       3      22
# Non Operating Income/Expense                          -238     -47     -32
# Non-Operating Interest Income                          827     398     525
# Interest Expense                                       516     979     342
# Interest Expense Growth                            -0.4734  1.8644 -0.3146
# Gross Interest Expense                                 516     979     342
# Pretax Income                                        10157   11105    5932
# Pretax Income Growth                               -0.0853   0.872 -0.2473
# Pretax Margin                                       0.2055       -       -
# Income Tax                                               2      -9    -147
# Income Tax - Current Domestic                            2      -9    -147
# Consolidated Net Income                              10155   11114    6079
# Minority Interest Expense                              181     213     144
# Net Income                                            9974   10901    5935
# Net Income Growth                                   -0.085  0.8367 -0.2297
# Net Margin                                          0.2018       -       -
# Net Income After Extraordinaries                      9974   10901    5935
# Net Income Available to Common                        9974   10901    5935
# EPS (Basic)                                          17.21    18.8   10.24
# EPS (Basic) Growth                                  -0.085  0.8367 -0.2297
# Basic Shares Outstanding                               580     580     580
# EPS (Diluted)                                        17.21    18.8   10.24
# EPS (Diluted) Growth                                -0.085  0.8367 -0.2297
# Diluted Shares Outstanding                             580     580     580
# EBITDA                                               12606   14346    7138
# EBITDA Growth                                      -0.1213  1.0097 -0.1472
# EBITDA Margin                                        0.255       -       -
# EBIT                                                 10108   11736    5802
#
#                                                         2019  2018  \
# Fiscal year is July-June. All values BDT Millions.
# Sales/Revenue                                          11253  6145
# Sales Growth                                          0.8314     -
# Cost of Goods Sold (COGS) incl. D&A                     4141  1929
# COGS excluding D&A                                      2807  1575
# Depreciation & Amortization Expense                     1333   355
# Depreciation                                            1313   355
# Amortization of Deferred Charges                          20     -
# COGS Growth                                            1.146     -
# Gross Income                                            7113  4215
# Gross Income Growth                                   0.6874     -
# Gross Profit Margin                                        -     -
# SG&A Expense                                              88    50
# Other SG&A                                                88    50
# SGA Growth                                            0.7738     -
# Other Operating Expense                                  -13    -4
# EBIT                                                    7037  4170
# Unusual Expense                                            6    24
# Non Operating Income/Expense                             721    13
# Non-Operating Interest Income                            628   439
# Interest Expense                                         499     2
# Interest Expense Growth                             273.5597     -
# Gross Interest Expense                                   499     2
# Pretax Income                                           7881  4596
# Pretax Income Growth                                  0.7146     -
# Pretax Margin                                              -     -
# Income Tax                                                26     -
# Income Tax - Current Domestic                             26     -
# Consolidated Net Income                                 7855  4596
# Minority Interest Expense                                150     -
# Net Income                                              7705  4596
# Net Income Growth                                     0.6762     -
# Net Margin                                                 -     -
# Net Income After Extraordinaries                        7705  4596
# Net Income Available to Common                          7705  4596
# EPS (Basic)                                            13.29  7.93
# EPS (Basic) Growth                                    0.6766     -
# Basic Shares Outstanding                                 580   580
# EPS (Diluted)                                          13.29  7.93
# EPS (Diluted) Growth                                  0.6762     -
# Diluted Shares Outstanding                               580   580
# EBITDA                                                  8371  4525
# EBITDA Growth                                         0.8499     -
# EBITDA Margin                                              -     -
# EBIT                                                    7037  4170
#
#                                                     5-year trend
# Fiscal year is July-June. All values BDT Millions.
# Sales/Revenue                                                NaN
# Sales Growth                                                 NaN
# Cost of Goods Sold (COGS) incl. D&A                          NaN
# COGS excluding D&A                                           NaN
# Depreciation & Amortization Expense                          NaN
# Depreciation                                                 NaN
# Amortization of Deferred Charges                             NaN
# COGS Growth                                                  NaN
# Gross Income                                                 NaN
# Gross Income Growth                                          NaN
# Gross Profit Margin                                          NaN
# SG&A Expense                                                 NaN
# Other SG&A                                                   NaN
# SGA Growth                                                   NaN
# Other Operating Expense                                      NaN
# EBIT                                                         NaN
# Unusual Expense                                              NaN
# Non Operating Income/Expense                                 NaN
# Non-Operating Interest Income                                NaN
# Interest Expense                                             NaN
# Interest Expense Growth                                      NaN
# Gross Interest Expense                                       NaN
# Pretax Income                                                NaN
# Pretax Income Growth                                         NaN
# Pretax Margin                                                NaN
# Income Tax                                                   NaN
# Income Tax - Current Domestic                                NaN
# Consolidated Net Income                                      NaN
# Minority Interest Expense                                    NaN
# Net Income                                                   NaN
# Net Income Growth                                            NaN
# Net Margin                                                   NaN
# Net Income After Extraordinaries                             NaN
# Net Income Available to Common                               NaN
# EPS (Basic)                                                  NaN
# EPS (Basic) Growth                                           NaN
# Basic Shares Outstanding                                     NaN
# EPS (Diluted)                                                NaN
# EPS (Diluted) Growth                                         NaN
# Diluted Shares Outstanding                                   NaN
# EBITDA                                                       NaN
# EBITDA Growth                                                NaN
# EBITDA Margin                                                NaN
# EBIT                                                         NaN

# %%
with pd.ExcelWriter('C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\United Power Generation & Distribution Co. Ltd\\BooK.xlsx') as writer:
    Balance_Sheet.to_excel(writer, sheet_name='Balance_Sheet')
    Income_Statement.to_excel(writer, sheet_name='Income_Statement')

# %%
x=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Port_folio_draft.xlsx", index_col='Unnamed: 0')
x
# Out:
#                                                     Full Name  \
# ISLAMIBANK                     Islami Bank Bangladesh Limited
# RAKCERAMIC                  RAK Ceramics (Bangladesh) Limited
# SALAMCRST                     S. Alam Cold Rolled Steels Ltd.
# POWERGRID               Power Grid Company of Bangladesh Ltd.
# BATBC       British American Tobacco Bangladesh Company Li...
# RENATA                                            Renata Ltd.
# MARICO                              Marico Bangladesh Limited
# SINGERBD                                Singer Bangladesh Ltd
# LINDEBD                                  Linde Bangladesh Ltd
# SUMITPOWER                                   Summit Power Ltd
# BERGERPBL                             Berger Paints India Ltd
# BXPHARMA                          Beximco Pharmaceuticals Ltd
# SQURPHARMA                         Square Pharmaceuticals Ltd
# SAPORTL                              Summit Alliance Port Ltd
# BSCCL                         Bangladesh Submarine Cables PLC
# GP                                           Grameenphone Ltd
# SQUARETEXT                                 Square Textile Ltd
# UNIQUEHRL                          Unique Hotel & Resorts PLC
#  EXIMBANK                Export Import Bank of Bangladesh Ltd
# HEIDELBCEM                   Heidelberg Cement Bangladesh Ltd
#  OLYMPIC                       Olympic Industries Ltd OLYMPIC
# BSRMSTEEL                                     BSRM Steels Ltd
# BEXIMCO                                           BEXIMCO Ltd
# NATLIFEINS                     National Life Insurance Co Ltd
# HFL                                         Hamid Fabrics Ltd
# BATASHOE                        Bata Shoe Co (Bangladesh) Ltd
#  APEXSPINN                 Apex Spinning & Knitting Mills Ltd
# UPGDCL         United Power Generation & Distribution Co. Ltd
#
#                                  Sector Evaluation
# ISLAMIBANK                         Bank          M
# RAKCERAMIC                      Ceramic          M
# SALAMCRST                   Engineering          P
# POWERGRID                  Fuel & Power          P
# BATBC                     FOOD & Allied          G
# RENATA                    FOOD & Allied          G
# MARICO      Pharmaceuticals & Chemicals          M
# SINGERBD                    Engineering          P
# LINDEBD                     Engineering          G
# SUMITPOWER                 Fuel & Power          M
# BERGERPBL                 Miscellaneous          G
# BXPHARMA    Pharmaceuticals & Chemicals          G
# SQURPHARMA  Pharmaceuticals & Chemicals          G
# SAPORTL          Services & Real Estate          M
# BSCCL                 Telecommunication          G
# GP                    Telecommunication          M
# SQUARETEXT                      Textile          M
# UNIQUEHRL              Travel & Leisure          G
#  EXIMBANK                          Bank          M
# HEIDELBCEM                       Cement          p
#  OLYMPIC                  FOOD & Allied          G
# BSRMSTEEL                  Iron & Steel          P
# BEXIMCO                   Miscellaneous          M
# NATLIFEINS                    Insurance          P
# HFL                             Textile          M
# BATASHOE             Tannery Industries          P
#  APEXSPINN                      Textile          P
# UPGDCL                     Fuel & Power          M

# %%
ticker=re.sub(" +", " ",'UPGDCL').lstrip()
Analysis=pd.DataFrame(columns=['Full Name','Sector','Evaluation'],index=[ticker])
Analysis.loc[ticker,'Full Name']='United Power Generation & Distribution Co. Ltd'
Analysis.loc[ticker,'Sector']='Fuel & Power'
Analysis.loc[ticker,'Evaluation']='M'
Analysis=pd.concat([x,Analysis],axis=0)
Analysis=Analysis.drop_duplicates()#Drop Duplicate

# %%
folder=Analysis.loc[ticker,'Full Name']
folder
# Out:
# 'United Power Generation & Distribution Co. Ltd'

# %%
folder=Analysis.loc[ticker,'Full Name']
path = "C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\"+folder+"\\"
Balance_Sheet=pd.read_excel(path+'Book.xlsx',sheet_name='Balance_Sheet',index_col=0)
Income_Satetment=pd.read_excel(path+'BooK.xlsx',sheet_name='Income_Statement',index_col=0)
Income_Satetment
# Out:
#                                                       2022    2021    2020  \
# Fiscal year is July-June. All values BDT Millions.
# Sales/Revenue                                        49435   30581   10094
# Sales Growth                                        0.6166  2.0296  -0.103
# Cost of Goods Sold (COGS) incl. D&A                  39290   18789    4251
# COGS excluding D&A                                   36792   16178    2914
# Depreciation & Amortization Expense                   2498    2611    1336
# Depreciation                                          2498    2611    1336
# Amortization of Deferred Charges                         -       -       -
# COGS Growth                                         1.0911  3.4202  0.0266
# Gross Income                                         10145   11792    5843
# Gross Income Growth                                -0.1396  1.0179 -0.1785
# Gross Profit Margin                                 0.2052       -       -
# SG&A Expense                                            73      81      60
# Other SG&A                                              73      81      60
# SGA Growth                                         -0.0949  0.3454 -0.3162
# Other Operating Expense                                -36     -25     -19
# EBIT                                                 10108   11736    5802
# Unusual Expense                                         24       3      22
# Non Operating Income/Expense                          -238     -47     -32
# Non-Operating Interest Income                          827     398     525
# Interest Expense                                       516     979     342
# Interest Expense Growth                            -0.4734  1.8644 -0.3146
# Gross Interest Expense                                 516     979     342
# Pretax Income                                        10157   11105    5932
# Pretax Income Growth                               -0.0853   0.872 -0.2473
# Pretax Margin                                       0.2055       -       -
# Income Tax                                               2      -9    -147
# Income Tax - Current Domestic                            2      -9    -147
# Consolidated Net Income                              10155   11114    6079
# Minority Interest Expense                              181     213     144
# Net Income                                            9974   10901    5935
# Net Income Growth                                   -0.085  0.8367 -0.2297
# Net Margin                                          0.2018       -       -
# Net Income After Extraordinaries                      9974   10901    5935
# Net Income Available to Common                        9974   10901    5935
# EPS (Basic)                                          17.21    18.8   10.24
# EPS (Basic) Growth                                  -0.085  0.8367 -0.2297
# Basic Shares Outstanding                               580     580     580
# EPS (Diluted)                                        17.21    18.8   10.24
# EPS (Diluted) Growth                                -0.085  0.8367 -0.2297
# Diluted Shares Outstanding                             580     580     580
# EBITDA                                               12606   14346    7138
# EBITDA Growth                                      -0.1213  1.0097 -0.1472
# EBITDA Margin                                        0.255       -       -
# EBIT                                                 10108   11736    5802
#
#                                                         2019  2018  \
# Fiscal year is July-June. All values BDT Millions.
# Sales/Revenue                                          11253  6145
# Sales Growth                                          0.8314     -
# Cost of Goods Sold (COGS) incl. D&A                     4141  1929
# COGS excluding D&A                                      2807  1575
# Depreciation & Amortization Expense                     1333   355
# Depreciation                                            1313   355
# Amortization of Deferred Charges                          20     -
# COGS Growth                                            1.146     -
# Gross Income                                            7113  4215
# Gross Income Growth                                   0.6874     -
# Gross Profit Margin                                        -     -
# SG&A Expense                                              88    50
# Other SG&A                                                88    50
# SGA Growth                                            0.7738     -
# Other Operating Expense                                  -13    -4
# EBIT                                                    7037  4170
# Unusual Expense                                            6    24
# Non Operating Income/Expense                             721    13
# Non-Operating Interest Income                            628   439
# Interest Expense                                         499     2
# Interest Expense Growth                             273.5597     -
# Gross Interest Expense                                   499     2
# Pretax Income                                           7881  4596
# Pretax Income Growth                                  0.7146     -
# Pretax Margin                                              -     -
# Income Tax                                                26     -
# Income Tax - Current Domestic                             26     -
# Consolidated Net Income                                 7855  4596
# Minority Interest Expense                                150     -
# Net Income                                              7705  4596
# Net Income Growth                                     0.6762     -
# Net Margin                                                 -     -
# Net Income After Extraordinaries                        7705  4596
# Net Income Available to Common                          7705  4596
# EPS (Basic)                                            13.29  7.93
# EPS (Basic) Growth                                    0.6766     -
# Basic Shares Outstanding                                 580   580
# EPS (Diluted)                                          13.29  7.93
# EPS (Diluted) Growth                                  0.6762     -
# Diluted Shares Outstanding                               580   580
# EBITDA                                                  8371  4525
# EBITDA Growth                                         0.8499     -
# EBITDA Margin                                              -     -
# EBIT                                                    7037  4170
#
#                                                     5-year trend
# Fiscal year is July-June. All values BDT Millions.
# Sales/Revenue                                                NaN
# Sales Growth                                                 NaN
# Cost of Goods Sold (COGS) incl. D&A                          NaN
# COGS excluding D&A                                           NaN
# Depreciation & Amortization Expense                          NaN
# Depreciation                                                 NaN
# Amortization of Deferred Charges                             NaN
# COGS Growth                                                  NaN
# Gross Income                                                 NaN
# Gross Income Growth                                          NaN
# Gross Profit Margin                                          NaN
# SG&A Expense                                                 NaN
# Other SG&A                                                   NaN
# SGA Growth                                                   NaN
# Other Operating Expense                                      NaN
# EBIT                                                         NaN
# Unusual Expense                                              NaN
# Non Operating Income/Expense                                 NaN
# Non-Operating Interest Income                                NaN
# Interest Expense                                             NaN
# Interest Expense Growth                                      NaN
# Gross Interest Expense                                       NaN
# Pretax Income                                                NaN
# Pretax Income Growth                                         NaN
# Pretax Margin                                                NaN
# Income Tax                                                   NaN
# Income Tax - Current Domestic                                NaN
# Consolidated Net Income                                      NaN
# Minority Interest Expense                                    NaN
# Net Income                                                   NaN
# Net Income Growth                                            NaN
# Net Margin                                                   NaN
# Net Income After Extraordinaries                             NaN
# Net Income Available to Common                               NaN
# EPS (Basic)                                                  NaN
# EPS (Basic) Growth                                           NaN
# Basic Shares Outstanding                                     NaN
# EPS (Diluted)                                                NaN
# EPS (Diluted) Growth                                         NaN
# Diluted Shares Outstanding                                   NaN
# EBITDA                                                       NaN
# EBITDA Growth                                                NaN
# EBITDA Margin                                                NaN
# EBIT                                                         NaN

# %%
Balance_Sheet.drop(Balance_Sheet.index[0],inplace=True)

# %%
Balance_Sheet
# Out:
#                                         2022    2021    2020    2019    2018  \
# Assets
# Cash & Short Term Investments           1384    1642     516    3433    1360
# Cash Only                               1203    1459     423    3306    1279
# Cash & Short Term Investments Growth -0.1571  2.1822 -0.8497  1.5232       -
# Cash & ST Investments / Total Assets  0.0161  0.0243  0.0143  0.0817  0.0828
# Total Accounts Receivable              39845   19126   13145   16830    5710
# ...                                      ...     ...     ...     ...     ...
# Retained Earnings                      24786   24666   21933   22705   10252
# Revaluation Reserves                      56      57      57      58       -
# Common Equity / Total Assets          0.3791  0.4812  0.8123  0.7042  0.9918
# Accumulated Minority Interest            512     525     545     488       -
# Total Equity                           33198   33091   29851   30088   16291
#
#                                      5-year trend
# Assets
# Cash & Short Term Investments                 NaN
# Cash Only                                     NaN
# Cash & Short Term Investments Growth          NaN
# Cash & ST Investments / Total Assets          NaN
# Total Accounts Receivable                     NaN
# ...                                           ...
# Retained Earnings                             NaN
# Revaluation Reserves                          NaN
# Common Equity / Total Assets                  NaN
# Accumulated Minority Interest                 NaN
# Total Equity                                  NaN
#
# [63 rows x 6 columns]

# %%
Total_Current_Assets=Balance_Sheet.loc['Total Current Assets',Balance_Sheet.columns][0:5].apply(lambda x :float(x)).values
Total_Current_Liabilities=Balance_Sheet.loc['Total Current Liabilities',Balance_Sheet.columns][0:5].apply(lambda x :float(x)).values
Cash_and_Cash_Equivalents=Balance_Sheet.loc['Cash Only',Balance_Sheet.columns][0:5].apply(lambda x :float(x)).values
Net_sales=Income_Satetment.loc['Sales/Revenue',Income_Satetment.columns][0:5].apply(lambda x :float(x)).values
Total_Assets=Balance_Sheet.loc['Total Assets',Balance_Sheet.columns][0:5].apply(lambda x :float(x)).values
Total_Accounts_Receivable=Balance_Sheet.loc['Total Accounts Receivable',Balance_Sheet.columns][0:5].apply(lambda x :float(x)).values
Total_Liabilities=Balance_Sheet.loc['Total Liabilities',Balance_Sheet.columns][0:5].apply(lambda x :float(x)).values
total_equity=Balance_Sheet.loc['Total Equity',Balance_Sheet.columns][0:5].apply(lambda x :float(x)).values
net_income=Income_Satetment.loc['Net Income Available to Common',Balance_Sheet.columns][0:5].apply(lambda x :float(x)).values

# %%
current_ratio=Total_Current_Assets/Total_Current_Liabilities#1.2 to 2 is considered as ideal current ration,which means the company has 2 time asset than its liabelities
current_ratio
# Out:
# array([ 0.97159816,  0.85399393,  7.14487966,  4.4182712 , 58.76865672])

# %%
cash_ratio=Cash_and_Cash_Equivalents/Total_Current_Liabilities#for every tk the company owes creditors in the next 12 months it has 0.5 in cash. 1 is considered to be the ideal cash ratio.
cash_ratio
# Out:
# array([0.02559357, 0.04978333, 0.19962246, 0.67718148, 9.54477612])

# %%
Total_Asset_turnover=Net_sales/Total_Assets
Total_Asset_turnover#each tk of assets generates 0.51 poisha in sales. The higher the ratio, the more efficient the company is using its assets to make sales.
# Out:
# array([0.57342536, 0.45189367, 0.27978269, 0.26772459, 0.37412481])

# %%
Account_receivable_turnover=Net_sales/Total_Accounts_Receivable
Account_receivable_turnover#A high-efficiency ratio means that the company has high-quality customers who pay their debts in due time.
# Out:
# array([1.24068265, 1.59892293, 0.76789654, 0.66862745, 1.07618214])

# %%
Debt_Ratio=Total_Liabilities/Total_Assets
Debt_Ratio#Debt financing
# Out:
# array([0.61492866, 0.51101621, 0.17257054, 0.28416445, 0.0081583 ])

# %%
Equity_Ratio=total_equity/Total_Assets#Equity financed by owner. 0.5 tk means half of the firm financed by the owners and other half by creditors 
Equity_Ratio
# Out:
# array([0.38508294, 0.48898379, 0.82740174, 0.71583555, 0.9918417 ])

# %%
Profit_margin_ratio=net_income/Net_sales#availability to generate net income, 10% means avg ,20 means high ,5% mean poor
Profit_margin_ratio
# Out:
# array([0.20175989, 0.35646316, 0.58797305, 0.6847063 , 0.74792514])

# %%
ROE=net_income/total_equity
ROE
# Out:
# array([0.30043979, 0.32942492, 0.19882081, 0.25608216, 0.28211896])

# %%
ROA=net_income/Total_Assets
ROA
# Out:
# array([0.11569424, 0.16108345, 0.16450468, 0.18331271, 0.27981735])

# %%
fundamental=pd.DataFrame(columns=[Balance_Sheet.columns[0:5]],index=[[ ticker for i in range(9)],
                                                                ['current ratio','cash ratio','Total Asset turnover',
                                                                 'Account receivable turnover','Debt Ratio','Equity Ratio',
                                                                 'Profit margin ratio',
                                                                 'ROE','ROA']])
fundamental
# Out:
#                                    2022 2021 2020 2019 2018
# UPGDCL current ratio                NaN  NaN  NaN  NaN  NaN
#        cash ratio                   NaN  NaN  NaN  NaN  NaN
#        Total Asset turnover         NaN  NaN  NaN  NaN  NaN
#        Account receivable turnover  NaN  NaN  NaN  NaN  NaN
#        Debt Ratio                   NaN  NaN  NaN  NaN  NaN
#        Equity Ratio                 NaN  NaN  NaN  NaN  NaN
#        Profit margin ratio          NaN  NaN  NaN  NaN  NaN
#        ROE                          NaN  NaN  NaN  NaN  NaN
#        ROA                          NaN  NaN  NaN  NaN  NaN

# %%
fundamental.loc[ticker].loc['current ratio']=current_ratio
fundamental.loc[ticker].loc['cash ratio']=cash_ratio
fundamental.loc[ticker].loc['Total Asset turnover']=Total_Asset_turnover
fundamental.loc[ticker].loc['Account receivable turnover']=Account_receivable_turnover
fundamental.loc[ticker].loc['Debt Ratio']=Debt_Ratio
fundamental.loc[ticker].loc['Equity Ratio']=Equity_Ratio
fundamental.loc[ticker].loc['Profit margin ratio']=Profit_margin_ratio
fundamental.loc[ticker].loc['ROE']=ROE
fundamental.loc[ticker].loc['ROA']=ROA

# %%
fundamental
# Out:
#                                         2022      2021      2020      2019  \
# UPGDCL current ratio                0.971598  0.853994   7.14488  4.418271
#        cash ratio                   0.025594  0.049783  0.199622  0.677181
#        Total Asset turnover         0.573425  0.451894  0.279783  0.267725
#        Account receivable turnover  1.240683  1.598923  0.767897  0.668627
#        Debt Ratio                   0.614929  0.511016  0.172571  0.284164
#        Equity Ratio                 0.385083  0.488984  0.827402  0.715836
#        Profit margin ratio           0.20176  0.356463  0.587973  0.684706
#        ROE                           0.30044  0.329425  0.198821  0.256082
#        ROA                          0.115694  0.161083  0.164505  0.183313
#
#                                          2018
# UPGDCL current ratio                58.768657
#        cash ratio                    9.544776
#        Total Asset turnover          0.374125
#        Account receivable turnover   1.076182
#        Debt Ratio                    0.008158
#        Equity Ratio                  0.991842
#        Profit margin ratio           0.747925
#        ROE                           0.282119
#        ROA                           0.279817

# %%
df1=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\fundamental.xlsx",index_col=[0,1])
df1=df1.dropna(how='all',axis=0)
df1.columns=[i for i in fundamental.columns]
df1
# Out:
#                                          (2022,)   (2021,)   (2020,)  \
# RAKCERAMIC current ratio                1.661731  1.706442  1.671489
#            cash ratio                   0.159492  0.279715  0.357559
#            Total Asset turnover         0.519501  0.506578  0.422592
#            Account receivable turnover  7.262156  7.516461  5.242779
#            Debt Ratio                   0.426187  0.423613  0.438828
# ...                                          ...       ...       ...
# UPGDCL     Debt Ratio                   0.614929  0.511016  0.172571
#            Equity Ratio                 0.385083  0.488984  0.827402
#            Profit margin ratio          0.201760  0.356463  0.587973
#            ROE                          0.300440  0.329425  0.198821
#            ROA                          0.115694  0.161083  0.164505
#
#                                          (2019,)   (2018,)
# RAKCERAMIC current ratio                1.677189  1.560933
#            cash ratio                   0.354284  0.184449
#            Total Asset turnover         0.489099  0.512198
#            Account receivable turnover  5.583621  4.888884
#            Debt Ratio                   0.464541  0.475179
# ...                                          ...       ...
# UPGDCL     Debt Ratio                   0.284164  0.008158
#            Equity Ratio                 0.715836  0.991842
#            Profit margin ratio          0.684706  0.747925
#            ROE                          0.256082  0.282119
#            ROA                          0.183313  0.279817
#
# [254 rows x 5 columns]

# %%
df=pd.concat([df1,fundamental],axis=0)
df
# Out:
#                                          (2022,)   (2021,)   (2020,)  \
# RAKCERAMIC current ratio                1.661731  1.706442  1.671489
#            cash ratio                   0.159492  0.279715  0.357559
#            Total Asset turnover         0.519501  0.506578  0.422592
#            Account receivable turnover  7.262156  7.516461  5.242779
#            Debt Ratio                   0.426187  0.423613  0.438828
# ...                                          ...       ...       ...
# UPGDCL     Debt Ratio                   0.614929  0.511016  0.172571
#            Equity Ratio                 0.385083  0.488984  0.827402
#            Profit margin ratio           0.20176  0.356463  0.587973
#            ROE                           0.30044  0.329425  0.198821
#            ROA                          0.115694  0.161083  0.164505
#
#                                          (2019,)   (2018,)
# RAKCERAMIC current ratio                1.677189  1.560933
#            cash ratio                   0.354284  0.184449
#            Total Asset turnover         0.489099  0.512198
#            Account receivable turnover  5.583621  4.888884
#            Debt Ratio                   0.464541  0.475179
# ...                                          ...       ...
# UPGDCL     Debt Ratio                   0.284164  0.008158
#            Equity Ratio                 0.715836  0.991842
#            Profit margin ratio          0.684706  0.747925
#            ROE                          0.256082  0.282119
#            ROA                          0.183313  0.279817
#
# [263 rows x 5 columns]

# %%
#Analysis.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\Port_folio_draft.xlsx")
#df.to_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\fundamental.xlsx")

# %%
#clean Duplicate rows
df1=pd.read_excel("C:\\Users\\nafissaad\\Tutorial\\Fundamental analysis\\My Portfolio\\fundamental.xlsx",index_col=[0,1])
df1=df1.drop_duplicates()
df1.tail(30)
# Out:
#                                         (2022,)   (2021,)    (2020,)  \
# HFL       Profit margin ratio          0.078288  0.057668   0.023832
#           ROE                          0.051033  0.031099   0.010427
#           ROA                          0.035120  0.023481   0.007987
# BATASHOE  current ratio                2.014189  2.344801   2.017392
#           cash ratio                   0.215220  0.268325   0.068076
#           Total Asset turnover         1.082312  0.943261   0.766446
#           Account receivable turnover  4.724723  6.618823  26.462823
#           Debt Ratio                   0.460234  0.451177   0.443030
#           Equity Ratio                 0.539766  0.548823   0.556970
#           Profit margin ratio          0.104447  0.057616  -0.260536
#           ROE                          0.209431  0.099024  -0.358523
#           ROA                          0.113044  0.054346  -0.199687
# APEXSPINN current ratio                1.111174  1.163651   1.257833
#           cash ratio                   0.012692  0.024627   0.019019
#           Total Asset turnover         2.479968  2.548132   2.145376
#           Account receivable turnover  5.907301  6.266536   6.385301
#           Debt Ratio                   0.684398  0.662256   0.643782
#           Equity Ratio                 0.315602  0.337744   0.356218
#           Profit margin ratio          0.006611  0.007695   0.004518
#           ROE                          0.051947  0.058056   0.027208
#           ROA                          0.016394  0.019608   0.009692
# UPGDCL    current ratio                0.971598  0.853994   7.144880
#           cash ratio                   0.025594  0.049783   0.199622
#           Total Asset turnover         0.573425  0.451894   0.279783
#           Account receivable turnover  1.240683  1.598923   0.767897
#           Debt Ratio                   0.614929  0.511016   0.172571
#           Equity Ratio                 0.385083  0.488984   0.827402
#           Profit margin ratio          0.201760  0.356463   0.587973
#           ROE                          0.300440  0.329425   0.198821
#           ROA                          0.115694  0.161083   0.164505
#
#                                           (2019,)      (2018,)
# HFL       Profit margin ratio           -0.128099     0.024274
#           ROE                           -0.046574     0.017511
#           ROA                           -0.033823     0.011798
# BATASHOE  current ratio                  1.899441     1.598612
#           cash ratio                     0.323506     0.437030
#           Total Asset turnover           1.202657     1.318982
#           Account receivable turnover  192.138661  1117.778817
#           Debt Ratio                     0.463982     0.538324
#           Equity Ratio                   0.536018     0.461676
#           Profit margin ratio           -0.008842     0.041614
#           ROE                           -0.019838     0.118888
#           ROA                           -0.010634     0.054888
# APEXSPINN current ratio                  1.203391     1.148497
#           cash ratio                     0.151161     0.011452
#           Total Asset turnover           2.561303     2.949146
#           Account receivable turnover    8.038868     8.560187
#           Debt Ratio                     0.699939     0.682859
#           Equity Ratio                   0.300061     0.317141
#           Profit margin ratio            0.006147     0.006353
#           ROE                            0.052472     0.059082
#           ROA                            0.015745     0.018737
# UPGDCL    current ratio                  4.418271    58.768657
#           cash ratio                     0.677181     9.544776
#           Total Asset turnover           0.267725     0.374125
#           Account receivable turnover    0.668627     1.076182
#           Debt Ratio                     0.284164     0.008158
#           Equity Ratio                   0.715836     0.991842
#           Profit margin ratio            0.684706     0.747925
#           ROE                            0.256082     0.282119
#           ROA                            0.183313     0.279817

# %%
#ceack whether there are duplicate index or not
[df1.index[i][0] for i in range(1,len(df1),9)]
# Out:
# ['RAKCERAMIC',
#  'SALAMCRST',
#  'POWERGRID',
#  'AFTABAUTO',
#  'BATBC',
#  'RENATA',
#  'MARICO',
#  'SINGERBD',
#  'LINDEBD',
#  'SUMITPOWER',
#  'BERGERPBL',
#  'BXPHARMA',
#  'SQURPHARMA',
#  'SAPORTL',
#  'BSCCL',
#  'GP',
#  'SQUARETEXT',
#  'UNIQUEHRL',
#  'EXIMBANK',
#  'HEIDELBCEM',
#  'OLYMPIC',
#  'BSRMSTEEL',
#  'BEXIMCO',
#  'NATLIFEINS',
#  'HFL',
#  'BATASHOE',
#  'APEXSPINN',
#  'UPGDCL']

# %%
inx=idx = pd.Index([df1.index[i][0] for i in range(1,len(df1),9)])
idx.drop_duplicates(keep='first')
# Out:
# Index(['RAKCERAMIC', 'SALAMCRST', 'POWERGRID', 'AFTABAUTO', 'BATBC', 'RENATA',
#        'MARICO', 'SINGERBD', 'LINDEBD', 'SUMITPOWER', 'BERGERPBL', 'BXPHARMA',
#        'SQURPHARMA', 'SAPORTL', 'BSCCL', 'GP', 'SQUARETEXT', 'UNIQUEHRL',
#        'EXIMBANK', 'HEIDELBCEM', 'OLYMPIC', 'BSRMSTEEL', 'BEXIMCO',
#        'NATLIFEINS', 'HFL', 'BATASHOE', 'APEXSPINN', 'UPGDCL'],
#       dtype='object')

# %%
len(inx)
# Out:
# 28

# %%
len(idx.drop_duplicates(keep='first'))
# Out:
# 28
