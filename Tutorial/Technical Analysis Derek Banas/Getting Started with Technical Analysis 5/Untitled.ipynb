# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates#styling dates
# %matplotlib inline
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go
import time
import yfinance as yf
# Make Plotly work in your Jupyter Notebook
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Use Plotly locally
cf.go_offline()

from plotly.subplots import make_subplots

import warnings
warnings.simplefilter("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
path="C:\\Users\\nafissaad\Tutorial\\Technical Analysis Derek Banas\\Getting Started with Technical Analysis 5\\Stocks\\"

# %%
S_date='2016-12-12'
E_date ='2021-12-10'
S_date_dt = pd.to_datetime(S_date)
E_date_dt = pd.to_datetime(E_date)

# %%
stocks_not_downloaded=[]
missing_stocks=[]

# %%
def get_stock_df_from_csv(ticker):
    try:
        df=pd.read_csv(Path + ticker +'.csv',index_col=0)
    except FileNotFoundError:
            print('File Doesnt Exist')
    else:
        return df

# %%
def get_column_from_csv(file,col_name):
    try:
        df = pd.read_csv(file)
    except FileNotFoundError:
        print('File Doesnt Exist')
    else:
        return df[col_name]

# %%
tickers=get_column_from_csv('C:\\Users\\nafissaad\Tutorial\\Technical Analysis Derek Banas\\Getting Started with Technical Analysis 5\\Wilshire-5000-Stocks.csv','Ticker')
tickers
# Out:
# 0          A
# 1         AA
# 2        AAL
# 3       AAME
# 4        AAN
#         ...
# 3476    ZUMZ
# 3477     ZUO
# 3478    ZYNE
# 3479    ZYXI
# 3480    ZNGA
# Name: Ticker, Length: 3481, dtype: object

# %%
def save_to_csv_from_yahoo(folder, ticker):
    
    stock = yf.Ticker(ticker)
    
    try:
        print("Get Data for : ", ticker)
        # Get historical closing price data
        df = stock.history(period="5y")
    
        # Wait 2 seconds
        time.sleep(2)
        
        if df.empty:
            stocks_not_downloaded.append(ticker)
        else:
            # Remove the period for saving the file name
            # Save data to a CSV file
            # File to save to
            #print(folder + ticker +'.csv')
            the_file = folder + ticker.replace(".", "_") + '.csv'
            #print(the_file)
            print(the_file, " Saved")
            df.to_csv(path+ticker+'.csv')
    except Exception as ex:
        stocks_not_downloaded.append(ticker)
        print("Couldn't Get Data for :", ticker)

# %%
folder=path
for x in range(20):
    save_to_csv_from_yahoo(folder,tickers[x])
    print('Finished')
# Out:
# Get Data for :  A
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\A.csv  Saved
# Finished
# Get Data for :  AA
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AA.csv  Saved
# Finished
# Get Data for :  AAL
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAL.csv  Saved
# Finished
# Get Data for :  AAME
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAME.csv  Saved
# Finished
# Get Data for :  AAN
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAN.csv  Saved
# Finished
# Get Data for :  AAOI
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAOI.csv  Saved
# Finished
# Get Data for :  AAON
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAON.csv  Saved
# Finished
# Get Data for :  AAP
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAP.csv  Saved
# Finished
# Get Data for :  AAPL
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAPL.csv  Saved
# Finished
# Get Data for :  AAT
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAT.csv  Saved
# Finished
# Get Data for :  AAWW
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AAWW.csv  Saved
# Finished
# Get Data for :  AAXN
# - AAXN: No data found, symbol may be delisted
# Finished
# Get Data for :  ABBV
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABBV.csv  Saved
# Finished
# Get Data for :  ABC
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABC.csv  Saved
# Finished
# Get Data for :  ABCB
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABCB.csv  Saved
# Finished
# Get Data for :  ABEO
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABEO.csv  Saved
# Finished
# Get Data for :  ABG
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABG.csv  Saved
# Finished
# Get Data for :  ABIO
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABIO.csv  Saved
# Finished
# Get Data for :  ABM
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABM.csv  Saved
# Finished
# Get Data for :  ABMD
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABMD.csv  Saved
# Finished

# %%
stocks_not_downloaded
# Out:
# ['AAXN']

# %%
for x in range(20,100):
    save_to_csv_from_yahoo(folder,tickers[x])
print('Finished')
# Out:
# Get Data for :  ABR
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABR.csv  Saved
# Get Data for :  ABT
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABT.csv  Saved
# Get Data for :  ABTX
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ABTX.csv  Saved
# Get Data for :  AC
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AC.csv  Saved
# Get Data for :  ACA
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACA.csv  Saved
# Get Data for :  ACAD
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACAD.csv  Saved
# Get Data for :  ACBI
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACBI.csv  Saved
# Get Data for :  ACC
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACC.csv  Saved
# Get Data for :  ACCO
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACCO.csv  Saved
# Get Data for :  ACER
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACER.csv  Saved
# Get Data for :  ACGL
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACGL.csv  Saved
# Get Data for :  ACHC
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACHC.csv  Saved
# Get Data for :  ACHV
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACHV.csv  Saved
# Get Data for :  ACIA
# - ACIA: No data found, symbol may be delisted
# Get Data for :  ACIW
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACIW.csv  Saved
# Get Data for :  ACLS
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACLS.csv  Saved
# Get Data for :  ACM
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACM.csv  Saved
# Get Data for :  ACMR
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACMR.csv  Saved
# Get Data for :  ACN
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACN.csv  Saved
# Get Data for :  ACNB
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACNB.csv  Saved
# Get Data for :  ACOR
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACOR.csv  Saved
# Get Data for :  ACRE
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACRE.csv  Saved
# Get Data for :  ACRS
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACRS.csv  Saved
# Get Data for :  ACRX
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACRX.csv  Saved
# Get Data for :  ACTG
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACTG.csv  Saved
# Get Data for :  ACU
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ACU.csv  Saved
# Get Data for :  ACY
# - ACY: No data found, symbol may be delisted
# Get Data for :  ADBE
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADBE.csv  Saved
# Get Data for :  ADC
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADC.csv  Saved
# Get Data for :  ADES
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADES.csv  Saved
# Get Data for :  ADI
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADI.csv  Saved
# Get Data for :  ADM
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADM.csv  Saved
# Get Data for :  ADMA
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADMA.csv  Saved
# Get Data for :  ADMP
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADMP.csv  Saved
# Get Data for :  ADMS
# - ADMS: No data found, symbol may be delisted
# Get Data for :  ADNT
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADNT.csv  Saved
# Get Data for :  ADP
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADP.csv  Saved
# Get Data for :  ADRO
# - ADRO: No data found, symbol may be delisted
# Get Data for :  ADS
# - ADS: No data found, symbol may be delisted
# Get Data for :  ADSK
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADSK.csv  Saved
# Get Data for :  ADSW
# - ADSW: No data found, symbol may be delisted
# Get Data for :  ADT
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADT.csv  Saved
# Get Data for :  ADTN
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADTN.csv  Saved
# Get Data for :  ADUS
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADUS.csv  Saved
# Get Data for :  ADVM
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADVM.csv  Saved
# Get Data for :  ADXS
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\ADXS.csv  Saved
# Get Data for :  AE
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AE.csv  Saved
# Get Data for :  AEE
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AEE.csv  Saved
# Get Data for :  AEGN
# - AEGN: No data found, symbol may be delisted
# Get Data for :  AEHR
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AEHR.csv  Saved
# Get Data for :  AEIS
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AEIS.csv  Saved
# Get Data for :  AEL
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AEL.csv  Saved
# Get Data for :  AEMD
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AEMD.csv  Saved
# Get Data for :  AEO
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AEO.csv  Saved
# Get Data for :  AEP
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AEP.csv  Saved
# Get Data for :  AERI
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AERI.csv  Saved
# Get Data for :  AES
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AES.csv  Saved
# Get Data for :  AEY
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AEY.csv  Saved
# Get Data for :  AFG
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AFG.csv  Saved
# Get Data for :  AFH
# - AFH: No data found, symbol may be delisted
# Get Data for :  AFI
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AFI.csv  Saved
# Get Data for :  AFIN
# - AFIN: No data found, symbol may be delisted
# Get Data for :  AFL
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AFL.csv  Saved
# Get Data for :  AGCO
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGCO.csv  Saved
# Get Data for :  AGE
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGE.csv  Saved
# Get Data for :  AGEN
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGEN.csv  Saved
# Get Data for :  AGFS
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGFS.csv  Saved
# Get Data for :  AGIO
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGIO.csv  Saved
# Get Data for :  AGLE
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGLE.csv  Saved
# Get Data for :  AGM
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGM.csv  Saved
# Get Data for :  AGNC
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGNC.csv  Saved
# Get Data for :  AGO
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGO.csv  Saved
# Get Data for :  AGR
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGR.csv  Saved
# Get Data for :  AGRX
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGRX.csv  Saved
# Get Data for :  AGS
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGS.csv  Saved
# Get Data for :  AGTC
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGTC.csv  Saved
# Get Data for :  AGX
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGX.csv  Saved
# Get Data for :  AGYS
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AGYS.csv  Saved
# Get Data for :  AHC
# - AHC: No data found, symbol may be delisted
# Get Data for :  AHH
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AHH.csv  Saved
# Finished

# %%
stocks_not_downloaded
# Out:
# ['AAXN',
#  'ACIA',
#  'ACY',
#  'ADMS',
#  'ADRO',
#  'ADS',
#  'ADSW',
#  'AEGN',
#  'AFH',
#  'AFIN',
#  'AHC']

# %%
missing_stocks
# Out:
# []

# %%
#hen the file doesn't have 5 years of the data. the file is a garbage, we want to rid of the file 
def get_stock_df_from_csv(ticker):
    
    # Try to get the file and if it doesn't exist issue a warning
    try:
        df = pd.read_csv(path + ticker + '.csv', index_col=0)
    except FileNotFoundError:# if the file dont exist
        print("File Doesn't Exist")
    else:
        return df

# %%
ticker =["FB","AMZN","NFLX","GOOG"]
for i in ticker:
    save_to_csv_from_yahoo(path,i)
    print('Finished'+i)
# Out:
# Get Data for :  FB
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\FB.csv  Saved
# FinishedFB
# Get Data for :  AMZN
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\AMZN.csv  Saved
# FinishedAMZN
# Get Data for :  NFLX
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\NFLX.csv  Saved
# FinishedNFLX
# Get Data for :  GOOG
# C:\Users\nafissaad\Tutorial\Technical Analysis Derek Banas\Getting Started with Technical Analysis 5\Stocks\GOOG.csv  Saved
# FinishedGOOG

# %%
fig=go.Figure()
fb_df=get_stock_df_from_csv('FB')
amzn_df = get_stock_df_from_csv("AMZN")
aapl_df = get_stock_df_from_csv("AAPL")
nflx_df = get_stock_df_from_csv("NFLX")
goog_df = get_stock_df_from_csv("GOOG")
fb_df.head()
fb_plot=go.Scatter(x=fb_df.index,y=fb_df['Close'],name='Facebook')
amzn_plot = go.Scatter(x=amzn_df.index, y=amzn_df['Close'], name="Amazon")
aapl_plot = go.Scatter(x=aapl_df.index, y=aapl_df['Close'], name="Apple")
nflx_plot = go.Scatter(x=nflx_df.index, y=nflx_df['Close'], name="Netflix")
goog_plot = go.Scatter(x=goog_df.index, y=goog_df['Close'], name="Google")

# Plot price changes
fig.add_trace(fb_plot)
fig.add_trace(amzn_plot)
fig.add_trace(aapl_plot)
fig.add_trace(nflx_plot)
fig.add_trace(goog_plot)


fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=1200, width=1800, 
                  showlegend=True)
fig.show()
# Out:
# <div>                            <div id="c3469c89-88af-4da3-91c8-ea2cadd7ae78" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3469c89-88af-4da3-91c8-ea2cadd7ae78")) {                    Plotly.newPlot(                        "c3469c89-88af-4da3-91c8-ea2cadd7ae78",                        [{"name":"Facebook","x":["2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-12","2018-02-13","2018-02-14","2018-02-15","2018-02-16","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018-04-30","2018-05-01","2018-05-02","2018-05-03","2018-05-04","2018-05-07","2018-05-08","2018-05-09","2018-05-10","2018-05-11","2018-05-14","2018-05-15","2018-05-16","2018-05-17","2018-05-18","2018-05-21","2018-05-22","2018-05-23","2018-05-24","2018-05-25","2018-05-29","2018-05-30","2018-05-31","2018-06-01","2018-06-04","2018-06-05","2018-06-06","2018-06-07","2018-06-08","2018-06-11","2018-06-12","2018-06-13","2018-06-14","2018-06-15","2018-06-18","2018-06-19","2018-06-20","2018-06-21","2018-06-22","2018-06-25","2018-06-26","2018-06-27","2018-06-28","2018-06-29","2018-07-02","2018-07-03","2018-07-05","2018-07-06","2018-07-09","2018-07-10","2018-07-11","2018-07-12","2018-07-1 ...

# %%
#Daily_Return_to_df(df,ticker)
def add_daily_return_to_df(df,ticker):
    df['Daily_Return']=(df['Close']/df['Close'].shift(1))-1
    df.to_csv(path+ticker+'.csv')
    return df

# %%
add_daily_return_to_df(fb_df, "FB")
add_daily_return_to_df(amzn_df, "AMZN")
add_daily_return_to_df(aapl_df, "AAPL")
add_daily_return_to_df(nflx_df, "NFLX")
add_daily_return_to_df(goog_df, "GOOG")
goog_df.head()
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2017-06-26  969.900024  973.309998  950.789978  952.270020  1598400
# 2017-06-27  942.460022  948.289978  926.849976  927.330017  2579900
# 2017-06-28  929.000000  942.750000  916.000000  940.489990  2721400
# 2017-06-29  929.919983  931.260010  910.619995  917.789978  3299200
# 2017-06-30  926.049988  926.049988  908.309998  908.729980  2090200
#
#             Dividends  Stock Splits  Daily_Return
# Date
# 2017-06-26          0             0           NaN
# 2017-06-27          0             0     -0.026190
# 2017-06-28          0             0      0.014191
# 2017-06-29          0             0     -0.024136
# 2017-06-30          0             0     -0.009872

# %%
#Get Cumulative Return
def add_cum_return_to_df(df,ticker):
    df['cum_return']=(1+df['Daily_Return']).cumprod()
    df.to_csv(path+ticker+'.csv')
    return df

# %%
add_cum_return_to_df(fb_df, "FB")
add_cum_return_to_df(amzn_df, "AMZN")
add_cum_return_to_df(aapl_df, "AAPL")
add_cum_return_to_df(nflx_df, "NFLX")
add_cum_return_to_df(goog_df, "GOOG")
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2017-06-26   969.900024   973.309998   950.789978   952.270020  1598400
# 2017-06-27   942.460022   948.289978   926.849976   927.330017  2579900
# 2017-06-28   929.000000   942.750000   916.000000   940.489990  2721400
# 2017-06-29   929.919983   931.260010   910.619995   917.789978  3299200
# 2017-06-30   926.049988   926.049988   908.309998   908.729980  2090200
# ...                 ...          ...          ...          ...      ...
# 2022-06-16  2162.989990  2185.810059  2115.850098  2132.719971  1765700
# 2022-06-17  2130.699951  2184.989990  2112.571045  2157.310059  2163500
# 2022-06-21  2194.040039  2253.459961  2185.870117  2240.300049  1950500
# 2022-06-22  2223.260010  2275.389893  2214.486084  2240.679932  1196100
# 2022-06-23  2259.000000  2263.929932  2220.580078  2253.689941  1234400
#
#             Dividends  Stock Splits  Daily_Return  cum_return
# Date
# 2017-06-26          0             0           NaN         NaN
# 2017-06-27          0             0     -0.026190    0.973810
# 2017-06-28          0             0      0.014191    0.987630
# 2017-06-29          0             0     -0.024136    0.963792
# 2017-06-30          0             0     -0.009872    0.954278
# ...               ...           ...           ...         ...
# 2022-06-16          0             0     -0.034011    2.239617
# 2022-06-17          0             0      0.011530    2.265439
# 2022-06-21          0             0      0.038469    2.352589
# 2022-06-22          0             0      0.000170    2.352988
# 2022-06-23          0             0      0.005806    2.366650
#
# [1258 rows x 9 columns]

# %%
#Merge Multiple stocks in one Dataframe by column name
def merge_df_by_column_name(col_name,sdate,edate,*ticker):
    mult_df = pd.DataFrame()
    for x in ticker:
        df=get_stock_df_from_csv(x)
        if not df.index.is_unique:#it just verify if your data set has duplicate index or not,same date again and again
            df=df.iloc[~df.index.duplicate(),:]#it will remove duplicte dates from the data set
        mask=(df.index>=sdate)&(df.index<=edate)
        mult_df[x] =df.loc[mask][col_name]
    return mult_df

# %%
mult_df = merge_df_by_column_name('cum_return',S_date  , 
                                  E_date, *ticker)
mult_df
# Out:
#                   FB      AMZN      NFLX      GOOG
# Date
# 2017-06-26       NaN       NaN       NaN       NaN
# 2017-06-27  0.980402  0.982696  0.958921  0.973810
# 2017-06-28  0.997721  0.996328  0.974032  0.987630
# 2017-06-29  0.983397  0.981841  0.952952  0.963792
# 2017-06-30  0.983007  0.973863  0.948635  0.954278
# ...              ...       ...       ...       ...
# 2021-12-06  2.069601  3.448128  3.890095  3.020078
# 2021-12-07  2.101764  3.544629  3.971937  3.109129
# 2021-12-08  2.152223  3.544498  3.987810  3.123494
# 2021-12-09  2.147406  3.504517  3.879365  3.110588
# 2021-12-10  2.146950  3.465100  3.883555  3.122539
#
# [1125 rows x 4 columns]

# %%
fig = px.line(mult_df, x=mult_df.index, y=mult_df.columns)
fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=1200, width=1800, 
                  showlegend=True)
fig.show()
# Out:
# <div>                            <div id="bed4a962-7f84-471d-9809-ad2206de610d" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bed4a962-7f84-471d-9809-ad2206de610d")) {                    Plotly.newPlot(                        "bed4a962-7f84-471d-9809-ad2206de610d",                        [{"hovertemplate":"variable=FB<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"FB","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"FB","showlegend":true,"x":["2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-12","2018-02-13","2018-02-14","2018-02-15","2018-02-16","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018-04-30","2018-05-01","2018-05-02","2018-05-03","2018-05-04","2018-05-07","2018-05-08","2018-05-09","2018-05-10","2018-05-11","2018-05-14","2018-05-15","2018-05-16","2018-05-17","2018-05-18","2018-05-21","2018-05-22","2018-05-23","2018-05-24","2018-05-25","2018-05-29","2018-05-30","2018-05-31","2018-06-01","2018-06-04","2018-06-05","2018-06-06","2018-06-07","2018-06-08","2018-06-11","2018-06-12","2018-06-13","2018-06-14","2018-06-15","2018-06-18","2018-06-19","2018-06-20","2018-06-21","20 ...

# %%
fig = go.Figure()
nflx_plot = go.Scatter(x=nflx_df.index, y=nflx_df['Close'], name="Netflix")

#Plot price changes
fig.add_trace(nflx_plot)

# Plot volume as bar graph
fig.add_trace(go.Bar(x=nflx_df.index, y=nflx_df['Volume']/200000, name='Volume Traded'))

fig.update_xaxes(title="Date", rangeslider_visible=True)
fig.update_yaxes(title="Price")
fig.update_layout(height=1200, width=1800, 
                  showlegend=True)
fig.show()
# Out:
# <div>                            <div id="5bebfce7-0510-4906-a287-3cb4feca0e3d" class="plotly-graph-div" style="height:1200px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bebfce7-0510-4906-a287-3cb4feca0e3d")) {                    Plotly.newPlot(                        "5bebfce7-0510-4906-a287-3cb4feca0e3d",                        [{"name":"Netflix","x":["2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-12","2018-02-13","2018-02-14","2018-02-15","2018-02-16","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018-04-30","2018-05-01","2018-05-02","2018-05-03","2018-05-04","2018-05-07","2018-05-08","2018-05-09","2018-05-10","2018-05-11","2018-05-14","2018-05-15","2018-05-16","2018-05-17","2018-05-18","2018-05-21","2018-05-22","2018-05-23","2018-05-24","2018-05-25","2018-05-29","2018-05-30","2018-05-31","2018-06-01","2018-06-04","2018-06-05","2018-06-06","2018-06-07","2018-06-08","2018-06-11","2018-06-12","2018-06-13","2018-06-14","2018-06-15","2018-06-18","2018-06-19","2018-06-20","2018-06-21","2018-06-22","2018-06-25","2018-06-26","2018-06-27","2018-06-28","2018-06-29","2018-07-02","2018-07-03","2018-07-05","2018-07-06","2018-07-09","2018-07-10","2018-07-11","2018-07-12","2018-07-13 ...
